# %%
import sys
IN_COLAB = 'google.colab' in sys.modules

# %%
import json
from typing import NamedTuple
import base64
import requests
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set()

# %%
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor

# %%
def get_config_collab(url):
    return json.loads(requests.get(url).text)

def get_config_local(filename):
    with open(filename) as f:
        raw = json.load(f)
    return raw

def load_config(filename):
    if IN_COLAB:
        return get_config_collab(f'https://raw.githubusercontent.com/Quick-One/Learning_AI-ML/main/MNIST_NN/{filename}')
    return get_config_local(filename)

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using '{device}' device")
# Out:
# Using 'cuda' device

# %% [markdown]
# <hr>

# %% [markdown]
# ### Loading the MNIST Dataset

# %%
training_data = datasets.MNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor()
)

test_data = datasets.MNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor()
)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to data/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting data/MNIST/raw/train-images-idx3-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to data/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting data/MNIST/raw/train-labels-idx1-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to data/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting data/MNIST/raw/t10k-images-idx3-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to data/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting data/MNIST/raw/t10k-labels-idx1-ubyte.gz to data/MNIST/raw

# %%
figure = plt.figure(figsize=(12, 1))
cols, rows = 9, 1
for i in range(1, cols * rows + 1):
    sample_idx = torch.randint(len(training_data), size=(1,)).item()
    img, label = training_data[sample_idx]
    figure.add_subplot(rows, cols, i)
    plt.title(f'Number {label}')
    plt.axis("off")
    plt.imshow(img.squeeze(), cmap="gray")
plt.show()

# %% [markdown]
# <hr>

# %%
class NeuralNetwork(nn.Module):
    def __init__(self, linear_relu_stack : nn.Sequential):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = linear_relu_stack

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

# %%
def train_loop(dataloader, model, loss_fn, optimizer, m):  
    for batch, (X, y) in enumerate(dataloader):
        X = X.to(device)
        y = y.to(device)
        # Compute prediction and loss
        pred = model(X)
        loss = loss_fn(pred, y)
        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

def test_train_loop(dataloader, model, loss_fn, m):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, correct = 0, 0

    with torch.no_grad():
        for X, y in dataloader:
            X = X.to(device)
            y = y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()

    test_loss /= num_batches
    correct /= size
    print(f"Training Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")
    m.error_training.append(test_loss)



def test_loop(dataloader, model, loss_fn, m):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, correct = 0, 0

    with torch.no_grad():
        for X, y in dataloader:
            X = X.to(device)
            y = y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()

    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")
    m.error_test.append(test_loss)

# %% [markdown]
# <hr>

# %%
class Model(NamedTuple):
    name: str
    learning_rate: float
    batch_size: int
    epochs: int
    hidden_layers: list
    error_test : list
    error_training :list

    def constructor(self):
        layer_size = self.hidden_layers.copy()
        layer_size.insert(0, 28 * 28)
        layer_size.append(10)

        layers = []
        for i in range(len(layer_size)-2):
            layers.append(nn.Linear(layer_size[i], layer_size[i+1]))
            layers.append(nn.ReLU())
        layers.append(nn.Linear(layer_size[-2], layer_size[-1]))

        linear_stack = nn.Sequential(*layers)
        return NeuralNetwork(linear_stack)


def load_models(config_dict: str) -> list:
    l = []
    for model_name, param in config_dict.items():
        error_test = []
        error_training = []
        m = Model(
            name=model_name,
            learning_rate=param['learning_rate'],
            batch_size=param['batch_size'],
            epochs=param['epochs'],
            hidden_layers=param['hidden_layers'],
            error_test=error_test,
            error_training=error_training
        )
        l.append(m)
    return l

# %% [markdown]
# <hr>

# %%
def train_models(config_dict):
    models = []
    for m in load_models(config_dict):
        models.append(m)
    for m in models:
        print(f'Training {m.name}')
        model = m.constructor().to(device)
        train_dataloader = DataLoader(training_data, batch_size=m.batch_size)
        test_train_dataloader = DataLoader(training_data, batch_size=m.batch_size)
        test_dataloader = DataLoader(test_data, batch_size=m.batch_size)
        loss_fn = nn.CrossEntropyLoss()
        optimizer = torch.optim.SGD(model.parameters(), lr=m.learning_rate)

        for t in range(m.epochs):
            print(f"Epoch {t+1}\n-------------------------------")
            train_loop(train_dataloader, model, loss_fn, optimizer, m)
            test_train_loop(test_train_dataloader, model, loss_fn, m)
            test_loop(test_dataloader, model, loss_fn, m)
    return models

# %%
def visualise_model_perf(models : list, title = 'TITLE'):
    fig, ax = plt.subplots()
    fig.set_size_inches(18.5, 10.5)
    for m in models:
        epochs = m.epochs
        ax.plot(range(1, epochs+1), m.error_test, label = m.name)
    ax.set_title(title)
    ax.set_xlabel("Number of Epochs")
    ax.set_ylabel("Average Error")
    ax.legend()
    return fig, ax

# %% [markdown]
# <hr>

# %% [markdown]
# ### Experiment 1: Varying the number of layers

# %%
models = train_models(load_config('layers.json'))
# Out:
# Training 1layers
# Epoch 1
# -------------------------------
# Test Error:
#  Accuracy: 68.2%, Avg loss: 2.072157
#
# Epoch 2
# -------------------------------
# Test Error:
#  Accuracy: 74.8%, Avg loss: 1.771911
#
# Epoch 3
# -------------------------------
# Test Error:
#  Accuracy: 78.0%, Avg loss: 1.433217
#
# Epoch 4
# -------------------------------
# Test Error:
#  Accuracy: 80.7%, Avg loss: 1.147190
#
# Epoch 5
# -------------------------------
# Test Error:
#  Accuracy: 82.7%, Avg loss: 0.946314
#
# Epoch 6
# -------------------------------
# Test Error:
#  Accuracy: 84.0%, Avg loss: 0.810702
#
# Epoch 7
# -------------------------------
# Test Error:
#  Accuracy: 85.1%, Avg loss: 0.716640
#
# Epoch 8
# -------------------------------
# Test Error:
#  Accuracy: 86.0%, Avg loss: 0.648641
#
# Epoch 9
# -------------------------------
# Test Error:
#  Accuracy: 86.5%, Avg loss: 0.597546
#
# Epoch 10
# -------------------------------
# Test Error:
#  Accuracy: 87.1%, Avg loss: 0.557898
#
# Epoch 11
# -------------------------------
# Test Error:
#  Accuracy: 87.6%, Avg loss: 0.526309
#
# Epoch 12
# -------------------------------
# Test Error:
#  Accuracy: 87.9%, Avg loss: 0.500581
#
# Epoch 13
# -------------------------------
# Test Error:
#  Accuracy: 88.3%, Avg loss: 0.479247
#
# Epoch 14
# -------------------------------
# Test Error:
#  Accuracy: 88.6%, Avg loss: 0.461285
#
# Epoch 15
# -------------------------------
# Test Error:
#  Accuracy: 88.8%, Avg loss: 0.445959
#
# Epoch 16
# -------------------------------
# Test Error:
#  Accuracy: 88.9%, Avg loss: 0.432730
#
# Epoch 17
# -------------------------------
# Test Error:
#  Accuracy: 89.1%, Avg loss: 0.421191
#
# Epoch 18
# -------------------------------
# Test Error:
#  Accuracy: 89.4%, Avg loss: 0.411033
#
# Epoch 19
# -------------------------------
# Test Error:
#  Accuracy: 89.5%, Avg loss: 0.402016
#
# Epoch 20
# -------------------------------
# Test Error:
#  Accuracy: 89.6%, Avg loss: 0.393950
#
# Epoch 21
# -------------------------------
# Test Error:
#  Accuracy: 89.7%, Avg loss: 0.386682
#
# Epoch 22
# -------------------------------
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.380093
#
# Epoch 23
# -------------------------------
# Test Error:
#  Accuracy: 89.9%, Avg loss: 0.374085
#
# Epoch 24
# -------------------------------
# Test Error:
#  Accuracy: 89.9%, Avg loss: 0.368576
#
# Epoch 25
# -------------------------------
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.363501
#
# Epoch 26
# -------------------------------
# Test Error:
#  Accuracy: 90.1%, Avg loss: 0.358803
#
# Epoch 27
# -------------------------------
# Test Error:
#  Accuracy: 90.2%, Avg loss: 0.354435
#
# Epoch 28
# -------------------------------
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.350357
#
# Epoch 29
# -------------------------------
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.346537
#
# Epoch 30
# -------------------------------
# Test Error:
#  Accuracy: 90.4%, Avg loss: 0.342946
#
# Epoch 31
# -------------------------------
# Test Error:
#  Accuracy: 90.5%, Avg loss: 0.339561
#
# Epoch 32
# -------------------------------
# Test Error:
#  Accuracy: 90.6%, Avg loss: 0.336361
#
# Epoch 33
# -------------------------------
# Test Error:
#  Accuracy: 90.7%, Avg loss: 0.333326
#
# Epoch 34
# -------------------------------
# Test Error:
#  Accuracy: 90.7%, Avg loss: 0.330442
#
# Epoch 35
# -------------------------------
# Test Error:
#  Accuracy: 90.8%, Avg loss: 0.327693
#
# Epoch 36
# -------------------------------
# Test Error:
#  Accuracy: 90.9%, Avg loss: 0.325068
#
# Epoch 37
# -------------------------------
# Test Error:
#  Accuracy: 90.9%, Avg loss: 0.322556
#
# Epoch 38
# -------------------------------
# Test Error:
#  Accuracy: 91.0%, Avg loss: 0.320145
#
# Epoch 39
# -------------------------------
# Test Error:
#  Accuracy: 91.0%, Avg loss: 0.317830
#
# Epoch 40
# -------------------------------
# Test Error:
#  Accuracy: 91.0%, Avg loss: 0.315604
#
# Epoch 41
# -------------------------------
# Test Error:
#  Accuracy: 91.1%, Avg loss: 0.313459
#
# Epoch 42
# -------------------------------
# Test Error:
#  Accuracy: 91.2%, Avg loss: 0.311387
#
# Epoch 43
# -------------------------------
# Test Error:
#  Accuracy: 91.2%, Avg loss: 0.309385
#
# Epoch 44
# -------------------------------
# Test Error:
#  Accuracy: 91.3%, Avg loss: 0.307447
#
# Epoch 45
# -------------------------------
# Test Error:
#  Accuracy: 91.4%, Avg loss: 0.305567
#
# Epoch 46
# -------------------------------
# Test Error:
#  Accuracy: 91.4%, Avg loss: 0.303744
#
# Epoch 47
# -------------------------------
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.301971
#
# Epoch 48
# -------------------------------
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.300246
#
# Epoch 49
# -------------------------------
# Test Error:
#  Accuracy: 91.6%, Avg loss: 0.298567
#
# Epoch 50
# -------------------------------
# Test Error:
#  Accuracy: 91.6%, Avg loss: 0.296933
#
# Epoch 51
# -------------------------------
# Test Error:
#  Accuracy: 91.7%, Avg loss: 0.295339
#
# Epoch 52
# -------------------------------
# Test Error:
#  Accuracy: 91.8%, Avg loss: 0.293781
#
# Epoch 53
# -------------------------------
# Test Error:
#  Accuracy: 91.8%, Avg loss: 0.292256
#
# Epoch 54
# -------------------------------
# Test Error:
#  Accuracy: 91.8%, Avg loss: 0.290764
#
# Epoch 55
# -------------------------------
# Test Error:
#  Accuracy: 91.9%, Avg loss: 0.289305
#
# Epoch 56
# -------------------------------
# Test Error:
#  Accuracy: 91.9%, Avg loss: 0.287875
#
# Epoch 57
# -------------------------------
# Test Error:
#  Accuracy: 91.9%, Avg loss: 0.286473
#
# Epoch 58
# -------------------------------
# Test Error:
#  Accuracy: 92.0%, Avg loss: 0.285097
#
# Epoch 59
# -------------------------------
# Test Error:
#  Accuracy: 92.0%, Avg loss: 0.283743
#
# Epoch 60
# -------------------------------
# Test Error:
#  Accuracy: 92.1%, Avg loss: 0.282411
#
# Epoch 61
# -------------------------------
# Test Error:
#  Accuracy: 92.1%, Avg loss: 0.281101
#
# Epoch 62
# -------------------------------
# Test Error:
#  Accuracy: 92.1%, Avg loss: 0.279814
#
# Epoch 63
# -------------------------------
# Test Error:
#  Accuracy: 92.2%, Avg loss: 0.278546
#
# Epoch 64
# -------------------------------
# Test Error:
#  Accuracy: 92.2%, Avg loss: 0.277298
#
# Epoch 65
# -------------------------------
# Test Error:
#  Accuracy: 92.2%, Avg loss: 0.276069
#
# Epoch 66
# -------------------------------
# Test Error:
#  Accuracy: 92.2%, Avg loss: 0.274857
#
# Epoch 67
# -------------------------------
# Test Error:
#  Accuracy: 92.2%, Avg loss: 0.273663
#
# Epoch 68
# -------------------------------
# Test Error:
#  Accuracy: 92.3%, Avg loss: 0.272486
#
# Epoch 69
# -------------------------------
# Test Error:
#  Accuracy: 92.3%, Avg loss: 0.271321
#
# Epoch 70
# -------------------------------
# Test Error:
#  Accuracy: 92.3%, Avg loss: 0.270170
#
# Epoch 71
# -------------------------------
# Test Error:
#  Accuracy: 92.3%, Avg loss: 0.269033
#
# Epoch 72
# -------------------------------
# Test Error:
#  Accuracy: 92.4%, Avg loss: 0.267909
#
# Epoch 73
# -------------------------------
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.266796
#
# Epoch 74
# -------------------------------
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.265696
#
# Epoch 75
# -------------------------------
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.264609
#
# Epoch 76
# -------------------------------
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.263533
#
# Epoch 77
# -------------------------------
# Test Error:
#  Accuracy: 92.6%, Avg loss: 0.262468
#
# Epoch 78
# -------------------------------
# Test Error:
#  Accuracy: 92.6%, Avg loss: 0.261414
#
# Epoch 79
# -------------------------------
# Test Error:
#  Accuracy: 92.6%, Avg loss: 0.260372
#
# Epoch 80
# -------------------------------
# Test Error:
#  Accuracy: 92.7%, Avg loss: 0.259339
#
# Epoch 81
# -------------------------------
# Test Error:
#  Accuracy: 92.7%, Avg loss: 0.258315
#
# Epoch 82
# -------------------------------
# Test Error:
#  Accuracy: 92.7%, Avg loss: 0.257301
#
# Epoch 83
# -------------------------------
# Test Error:
#  Accuracy: 92.8%, Avg loss: 0.256296
#
# Epoch 84
# -------------------------------
# Test Error:
#  Accuracy: 92.8%, Avg loss: 0.255300
#
# Epoch 85
# -------------------------------
# Test Error:
#  Accuracy: 92.8%, Avg loss: 0.254312
#
# Epoch 86
# -------------------------------
# Test Error:
#  Accuracy: 92.8%, Avg loss: 0.253333
#
# Epoch 87
# -------------------------------
# Test Error:
#  Accuracy: 92.9%, Avg loss: 0.252361
#
# Epoch 88
# -------------------------------
# Test Error:
#  Accuracy: 92.9%, Avg loss: 0.251397
#
# Epoch 89
# -------------------------------
# Test Error:
#  Accuracy: 93.0%, Avg loss: 0.250443
#
# Epoch 90
# -------------------------------
# Test Error:
#  Accuracy: 93.0%, Avg loss: 0.249495
#
# Epoch 91
# -------------------------------
# Test Error:
#  Accuracy: 93.0%, Avg loss: 0.248554
#
# Epoch 92
# -------------------------------
# Test Error:
#  Accuracy: 93.0%, Avg loss: 0.247619
#
# Epoch 93
# -------------------------------
# Test Error:
#  Accuracy: 93.0%, Avg loss: 0.246691
#
# Epoch 94
# -------------------------------
# Test Error:
#  Accuracy: 93.0%, Avg loss: 0.245771
#
# Epoch 95
# -------------------------------
# Test Error:
#  Accuracy: 93.0%, Avg loss: 0.244858
#
# Epoch 96
# -------------------------------
# Test Error:
#  Accuracy: 93.0%, Avg loss: 0.243952
#
# Epoch 97
# -------------------------------
# Test Error:
#  Accuracy: 93.1%, Avg loss: 0.243052
#
# Epoch 98
# -------------------------------
# Test Error:
#  Accuracy: 93.1%, Avg loss: 0.242158
#
# Epoch 99
# -------------------------------
# Test Error:
#  Accuracy: 93.1%, Avg loss: 0.241270
#
# Epoch 100
# -------------------------------
# Test Error:
#  Accuracy: 93.1%, Avg loss: 0.240388
#
# Training 2layers
# Epoch 1
# -------------------------------
# Test Error:
#  Accuracy: 51.1%, Avg loss: 2.256984
#
# Epoch 2
# -------------------------------
# Test Error:
#  Accuracy: 65.4%, Avg loss: 2.191751
#
# Epoch 3
# -------------------------------
# Test Error:
#  Accuracy: 69.4%, Avg loss: 2.080540
#
# Epoch 4
# -------------------------------
# Test Error:
#  Accuracy: 71.9%, Avg loss: 1.887154
#
# Epoch 5
# -------------------------------
# Test Error:
#  Accuracy: 74.3%, Avg loss: 1.593612
#
# Epoch 6
# -------------------------------
# Test Error:
#  Accuracy: 76.9%, Avg loss: 1.271545
#
# Epoch 7
# -------------------------------
# Test Error:
#  Accuracy: 79.7%, Avg loss: 1.020237
#
# Epoch 8
# -------------------------------
# Test Error:
#  Accuracy: 81.6%, Avg loss: 0.850478
#
# Epoch 9
# -------------------------------
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.735149
#
# Epoch 10
# -------------------------------
# Test Error:
#  Accuracy: 84.3%, Avg loss: 0.653483
#
# Epoch 11
# -------------------------------
# Test Error:
#  Accuracy: 85.3%, Avg loss: 0.593262
#
# Epoch 12
# -------------------------------
# Test Error:
#  Accuracy: 86.2%, Avg loss: 0.547297
#
# Epoch 13
# -------------------------------
# Test Error:
#  Accuracy: 87.0%, Avg loss: 0.511184
#
# Epoch 14
# -------------------------------
# Test Error:
#  Accuracy: 87.5%, Avg loss: 0.482146
#
# Epoch 15
# -------------------------------
# Test Error:
#  Accuracy: 87.9%, Avg loss: 0.458379
#
# Epoch 16
# -------------------------------
# Test Error:
#  Accuracy: 88.4%, Avg loss: 0.438647
#
# Epoch 17
# -------------------------------
# Test Error:
#  Accuracy: 88.7%, Avg loss: 0.422067
#
# Epoch 18
# -------------------------------
# Test Error:
#  Accuracy: 88.9%, Avg loss: 0.407988
#
# Epoch 19
# -------------------------------
# Test Error:
#  Accuracy: 89.1%, Avg loss: 0.395909
#
# Epoch 20
# -------------------------------
# Test Error:
#  Accuracy: 89.3%, Avg loss: 0.385442
#
# Epoch 21
# -------------------------------
# Test Error:
#  Accuracy: 89.5%, Avg loss: 0.376285
#
# Epoch 22
# -------------------------------
# Test Error:
#  Accuracy: 89.6%, Avg loss: 0.368198
#
# Epoch 23
# -------------------------------
# Test Error:
#  Accuracy: 89.7%, Avg loss: 0.360992
#
# Epoch 24
# -------------------------------
# Test Error:
#  Accuracy: 89.9%, Avg loss: 0.354522
#
# Epoch 25
# -------------------------------
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.348664
#
# Epoch 26
# -------------------------------
# Test Error:
#  Accuracy: 90.2%, Avg loss: 0.343326
#
# Epoch 27
# -------------------------------
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.338428
#
# Epoch 28
# -------------------------------
# Test Error:
#  Accuracy: 90.4%, Avg loss: 0.333906
#
# Epoch 29
# -------------------------------
# Test Error:
#  Accuracy: 90.6%, Avg loss: 0.329714
#
# Epoch 30
# -------------------------------
# Test Error:
#  Accuracy: 90.6%, Avg loss: 0.325800
#
# Epoch 31
# -------------------------------
# Test Error:
#  Accuracy: 90.7%, Avg loss: 0.322132
#
# Epoch 32
# -------------------------------
# Test Error:
#  Accuracy: 90.7%, Avg loss: 0.318679
#
# Epoch 33
# -------------------------------
# Test Error:
#  Accuracy: 90.8%, Avg loss: 0.315413
#
# Epoch 34
# -------------------------------
# Test Error:
#  Accuracy: 90.9%, Avg loss: 0.312314
#
# Epoch 35
# -------------------------------
# Test Error:
#  Accuracy: 91.1%, Avg loss: 0.309360
#
# Epoch 36
# -------------------------------
# Test Error:
#  Accuracy: 91.2%, Avg loss: 0.306542
#
# Epoch 37
# -------------------------------
# Test Error:
#  Accuracy: 91.2%, Avg loss: 0.303849
#
# Epoch 38
# -------------------------------
# Test Error:
#  Accuracy: 91.2%, Avg loss: 0.301262
#
# Epoch 39
# -------------------------------
# Test Error:
#  Accuracy: 91.3%, Avg loss: 0.298775
#
# Epoch 40
# -------------------------------
# Test Error:
#  Accuracy: 91.4%, Avg loss: 0.296373
#
# Epoch 41
# -------------------------------
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.294051
#
# Epoch 42
# -------------------------------
# Test Error:
#  Accuracy: 91.6%, Avg loss: 0.291801
#
# Epoch 43
# -------------------------------
# Test Error:
#  Accuracy: 91.7%, Avg loss: 0.289618
#
# Epoch 44
# -------------------------------
# Test Error:
#  Accuracy: 91.8%, Avg loss: 0.287493
#
# Epoch 45
# -------------------------------
# Test Error:
#  Accuracy: 91.8%, Avg loss: 0.285426
#
# Epoch 46
# -------------------------------
# Test Error:
#  Accuracy: 91.9%, Avg loss: 0.283405
#
# Epoch 47
# -------------------------------
# Test Error:
#  Accuracy: 92.0%, Avg loss: 0.281430
#
# Epoch 48
# -------------------------------
# Test Error:
#  Accuracy: 92.1%, Avg loss: 0.279496
#
# Epoch 49
# -------------------------------
# Test Error:
#  Accuracy: 92.1%, Avg loss: 0.277601
#
# Epoch 50
# -------------------------------
# Test Error:
#  Accuracy: 92.2%, Avg loss: 0.275743
#
# Epoch 51
# -------------------------------
# Test Error:
#  Accuracy: 92.2%, Avg loss: 0.273921
#
# Epoch 52
# -------------------------------
# Test Error:
#  Accuracy: 92.3%, Avg loss: 0.272132
#
# Epoch 53
# -------------------------------
# Test Error:
#  Accuracy: 92.3%, Avg loss: 0.270371
#
# Epoch 54
# -------------------------------
# Test Error:
#  Accuracy: 92.4%, Avg loss: 0.268643
#
# Epoch 55
# -------------------------------
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.266946
#
# Epoch 56
# -------------------------------
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.265276
#
# Epoch 57
# -------------------------------
# Test Error:
#  Accuracy: 92.6%, Avg loss: 0.263631
#
# Epoch 58
# -------------------------------
# Test Error:
#  Accuracy: 92.6%, Avg loss: 0.262012
#
# Epoch 59
# -------------------------------
# Test Error:
#  Accuracy: 92.7%, Avg loss: 0.260413
#
# Epoch 60
# -------------------------------
# Test Error:
#  Accuracy: 92.7%, Avg loss: 0.258836
#
# Epoch 61
# -------------------------------
# Test Error:
#  Accuracy: 92.7%, Avg loss: 0.257285
#
# Epoch 62
# -------------------------------
# Test Error:
#  Accuracy: 92.8%, Avg loss: 0.255749
#
# Epoch 63
# -------------------------------
# Test Error:
#  Accuracy: 92.8%, Avg loss: 0.254228
#
# Epoch 64
# -------------------------------
# Test Error:
#  Accuracy: 92.8%, Avg loss: 0.252724
#
# Epoch 65
# -------------------------------
# Test Error:
#  Accuracy: 92.9%, Avg loss: 0.251233
#
# Epoch 66
# -------------------------------
# Test Error:
#  Accuracy: 92.9%, Avg loss: 0.249756
#
# Epoch 67
# -------------------------------
# Test Error:
#  Accuracy: 93.0%, Avg loss: 0.248292
#
# Epoch 68
# -------------------------------
# Test Error:
#  Accuracy: 93.0%, Avg loss: 0.246840
#
# Epoch 69
# -------------------------------
# Test Error:
#  Accuracy: 93.1%, Avg loss: 0.245403
#
# Epoch 70
# -------------------------------
# Test Error:
#  Accuracy: 93.1%, Avg loss: 0.243981
#
# Epoch 71
# -------------------------------
# Test Error:
#  Accuracy: 93.1%, Avg loss: 0.242570
#
# Epoch 72
# -------------------------------
# Test Error:
#  Accuracy: 93.1%, Avg loss: 0.241172
#
# Epoch 73
# -------------------------------
# Test Error:
#  Accuracy: 93.2%, Avg loss: 0.239788
#
# Epoch 74
# -------------------------------
# Test Error:
#  Accuracy: 93.2%, Avg loss: 0.238413
#
# Epoch 75
# -------------------------------
# Test Error:
#  Accuracy: 93.2%, Avg loss: 0.237051
#
# Epoch 76
# -------------------------------
# Test Error:
#  Accuracy: 93.3%, Avg loss: 0.235699
#
# Epoch 77
# -------------------------------
# Test Error:
#  Accuracy: 93.3%, Avg loss: 0.234361
#
# Epoch 78
# -------------------------------
# Test Error:
#  Accuracy: 93.4%, Avg loss: 0.233035
#
# Epoch 79
# -------------------------------
# Test Error:
#  Accuracy: 93.4%, Avg loss: 0.231720
#
# Epoch 80
# -------------------------------
# Test Error:
#  Accuracy: 93.5%, Avg loss: 0.230416
#
# Epoch 81
# -------------------------------
# Test Error:
#  Accuracy: 93.5%, Avg loss: 0.229119
#
# Epoch 82
# -------------------------------
# Test Error:
#  Accuracy: 93.6%, Avg loss: 0.227830
#
# Epoch 83
# -------------------------------
# Test Error:
#  Accuracy: 93.5%, Avg loss: 0.226552
#
# Epoch 84
# -------------------------------
# Test Error:
#  Accuracy: 93.6%, Avg loss: 0.225282
#
# Epoch 85
# -------------------------------
# Test Error:
#  Accuracy: 93.6%, Avg loss: 0.224023
#
# Epoch 86
# -------------------------------
# Test Error:
#  Accuracy: 93.7%, Avg loss: 0.222774
#
# Epoch 87
# -------------------------------
# Test Error:
#  Accuracy: 93.7%, Avg loss: 0.221533
#
# Epoch 88
# -------------------------------
# Test Error:
#  Accuracy: 93.7%, Avg loss: 0.220302
#
# Epoch 89
# -------------------------------
# Test Error:
#  Accuracy: 93.7%, Avg loss: 0.219083
#
# Epoch 90
# -------------------------------
# Test Error:
#  Accuracy: 93.7%, Avg loss: 0.217874
#
# Epoch 91
# -------------------------------
# Test Error:
#  Accuracy: 93.8%, Avg loss: 0.216679
#
# Epoch 92
# -------------------------------
# Test Error:
#  Accuracy: 93.8%, Avg loss: 0.215493
#
# Epoch 93
# -------------------------------
# Test Error:
#  Accuracy: 93.8%, Avg loss: 0.214315
#
# Epoch 94
# -------------------------------
# Test Error:
#  Accuracy: 93.9%, Avg loss: 0.213149
#
# Epoch 95
# -------------------------------
# Test Error:
#  Accuracy: 93.9%, Avg loss: 0.211993
#
# Epoch 96
# -------------------------------
# Test Error:
#  Accuracy: 93.9%, Avg loss: 0.210851
#
# Epoch 97
# -------------------------------
# Test Error:
#  Accuracy: 93.9%, Avg loss: 0.209717
#
# Epoch 98
# -------------------------------
# Test Error:
#  Accuracy: 94.0%, Avg loss: 0.208593
#
# Epoch 99
# -------------------------------
# Test Error:
#  Accuracy: 94.0%, Avg loss: 0.207476
#
# Epoch 100
# -------------------------------
# Test Error:
#  Accuracy: 94.0%, Avg loss: 0.206369
#
# Training 3layers
# Epoch 1
# -------------------------------
# Test Error:
#  Accuracy: 15.9%, Avg loss: 2.293942
#
# Epoch 2
# -------------------------------
# Test Error:
#  Accuracy: 33.1%, Avg loss: 2.284732
#
# Epoch 3
# -------------------------------
# Test Error:
#  Accuracy: 45.7%, Avg loss: 2.273306
#
# Epoch 4
# -------------------------------
# Test Error:
#  Accuracy: 58.3%, Avg loss: 2.257669
#
# Epoch 5
# -------------------------------
# Test Error:
#  Accuracy: 65.5%, Avg loss: 2.234496
#
# Epoch 6
# -------------------------------
# Test Error:
#  Accuracy: 67.9%, Avg loss: 2.197555
#
# Epoch 7
# -------------------------------
# Test Error:
#  Accuracy: 67.5%, Avg loss: 2.133742
#
# Epoch 8
# -------------------------------
# Test Error:
#  Accuracy: 66.0%, Avg loss: 2.015168
#
# Epoch 9
# -------------------------------
# Test Error:
#  Accuracy: 65.7%, Avg loss: 1.800600
#
# Epoch 10
# -------------------------------
# Test Error:
#  Accuracy: 68.7%, Avg loss: 1.493204
#
# Epoch 11
# -------------------------------
# Test Error:
#  Accuracy: 73.1%, Avg loss: 1.189736
#
# Epoch 12
# -------------------------------
# Test Error:
#  Accuracy: 76.6%, Avg loss: 0.966871
#
# Epoch 13
# -------------------------------
# Test Error:
#  Accuracy: 79.1%, Avg loss: 0.815234
#
# Epoch 14
# -------------------------------
# Test Error:
#  Accuracy: 81.1%, Avg loss: 0.708512
#
# Epoch 15
# -------------------------------
# Test Error:
#  Accuracy: 82.8%, Avg loss: 0.631589
#
# Epoch 16
# -------------------------------
# Test Error:
#  Accuracy: 83.9%, Avg loss: 0.575284
#
# Epoch 17
# -------------------------------
# Test Error:
#  Accuracy: 84.9%, Avg loss: 0.532994
#
# Epoch 18
# -------------------------------
# Test Error:
#  Accuracy: 85.9%, Avg loss: 0.500126
#
# Epoch 19
# -------------------------------
# Test Error:
#  Accuracy: 86.4%, Avg loss: 0.473712
#
# Epoch 20
# -------------------------------
# Test Error:
#  Accuracy: 86.9%, Avg loss: 0.451951
#
# Epoch 21
# -------------------------------
# Test Error:
#  Accuracy: 87.3%, Avg loss: 0.433703
#
# Epoch 22
# -------------------------------
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.418210
#
# Epoch 23
# -------------------------------
# Test Error:
#  Accuracy: 88.1%, Avg loss: 0.404938
#
# Epoch 24
# -------------------------------
# Test Error:
#  Accuracy: 88.5%, Avg loss: 0.393461
#
# Epoch 25
# -------------------------------
# Test Error:
#  Accuracy: 88.7%, Avg loss: 0.383461
#
# Epoch 26
# -------------------------------
# Test Error:
#  Accuracy: 89.0%, Avg loss: 0.374644
#
# Epoch 27
# -------------------------------
# Test Error:
#  Accuracy: 89.2%, Avg loss: 0.366795
#
# Epoch 28
# -------------------------------
# Test Error:
#  Accuracy: 89.5%, Avg loss: 0.359739
#
# Epoch 29
# -------------------------------
# Test Error:
#  Accuracy: 89.6%, Avg loss: 0.353329
#
# Epoch 30
# -------------------------------
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.347457
#
# Epoch 31
# -------------------------------
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.342033
#
# Epoch 32
# -------------------------------
# Test Error:
#  Accuracy: 90.1%, Avg loss: 0.336987
#
# Epoch 33
# -------------------------------
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.332255
#
# Epoch 34
# -------------------------------
# Test Error:
#  Accuracy: 90.4%, Avg loss: 0.327792
#
# Epoch 35
# -------------------------------
# Test Error:
#  Accuracy: 90.5%, Avg loss: 0.323546
#
# Epoch 36
# -------------------------------
# Test Error:
#  Accuracy: 90.7%, Avg loss: 0.319500
#
# Epoch 37
# -------------------------------
# Test Error:
#  Accuracy: 90.8%, Avg loss: 0.315609
#
# Epoch 38
# -------------------------------
# Test Error:
#  Accuracy: 90.9%, Avg loss: 0.311859
#
# Epoch 39
# -------------------------------
# Test Error:
#  Accuracy: 91.0%, Avg loss: 0.308227
#
# Epoch 40
# -------------------------------
# Test Error:
#  Accuracy: 91.2%, Avg loss: 0.304709
#
# Epoch 41
# -------------------------------
# Test Error:
#  Accuracy: 91.3%, Avg loss: 0.301280
#
# Epoch 42
# -------------------------------
# Test Error:
#  Accuracy: 91.4%, Avg loss: 0.297938
#
# Epoch 43
# -------------------------------
# Test Error:
#  Accuracy: 91.4%, Avg loss: 0.294661
#
# Epoch 44
# -------------------------------
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.291462
#
# Epoch 45
# -------------------------------
# Test Error:
#  Accuracy: 91.6%, Avg loss: 0.288330
#
# Epoch 46
# -------------------------------
# Test Error:
#  Accuracy: 91.7%, Avg loss: 0.285249
#
# Epoch 47
# -------------------------------
# Test Error:
#  Accuracy: 91.8%, Avg loss: 0.282222
#
# Epoch 48
# -------------------------------
# Test Error:
#  Accuracy: 91.9%, Avg loss: 0.279229
#
# Epoch 49
# -------------------------------
# Test Error:
#  Accuracy: 91.9%, Avg loss: 0.276282
#
# Epoch 50
# -------------------------------
# Test Error:
#  Accuracy: 92.0%, Avg loss: 0.273386
#
# Epoch 51
# -------------------------------
# Test Error:
#  Accuracy: 92.2%, Avg loss: 0.270519
#
# Epoch 52
# -------------------------------
# Test Error:
#  Accuracy: 92.2%, Avg loss: 0.267697
#
# Epoch 53
# -------------------------------
# Test Error:
#  Accuracy: 92.3%, Avg loss: 0.264922
#
# Epoch 54
# -------------------------------
# Test Error:
#  Accuracy: 92.4%, Avg loss: 0.262180
#
# Epoch 55
# -------------------------------
# Test Error:
#  Accuracy: 92.6%, Avg loss: 0.259470
#
# Epoch 56
# -------------------------------
# Test Error:
#  Accuracy: 92.6%, Avg loss: 0.256793
#
# Epoch 57
# -------------------------------
# Test Error:
#  Accuracy: 92.7%, Avg loss: 0.254153
#
# Epoch 58
# -------------------------------
# Test Error:
#  Accuracy: 92.8%, Avg loss: 0.251543
#
# Epoch 59
# -------------------------------
# Test Error:
#  Accuracy: 92.9%, Avg loss: 0.248961
#
# Epoch 60
# -------------------------------
# Test Error:
#  Accuracy: 93.0%, Avg loss: 0.246419
#
# Epoch 61
# -------------------------------
# Test Error:
#  Accuracy: 93.0%, Avg loss: 0.243905
#
# Epoch 62
# -------------------------------
# Test Error:
#  Accuracy: 93.1%, Avg loss: 0.241427
#
# Epoch 63
# -------------------------------
# Test Error:
#  Accuracy: 93.2%, Avg loss: 0.238987
#
# Epoch 64
# -------------------------------
# Test Error:
#  Accuracy: 93.3%, Avg loss: 0.236583
#
# Epoch 65
# -------------------------------
# Test Error:
#  Accuracy: 93.3%, Avg loss: 0.234215
#
# Epoch 66
# -------------------------------
# Test Error:
#  Accuracy: 93.5%, Avg loss: 0.231886
#
# Epoch 67
# -------------------------------
# Test Error:
#  Accuracy: 93.5%, Avg loss: 0.229590
#
# Epoch 68
# -------------------------------
# Test Error:
#  Accuracy: 93.6%, Avg loss: 0.227328
#
# Epoch 69
# -------------------------------
# Test Error:
#  Accuracy: 93.7%, Avg loss: 0.225102
#
# Epoch 70
# -------------------------------
# Test Error:
#  Accuracy: 93.7%, Avg loss: 0.222909
#
# Epoch 71
# -------------------------------
# Test Error:
#  Accuracy: 93.7%, Avg loss: 0.220750
#
# Epoch 72
# -------------------------------
# Test Error:
#  Accuracy: 93.8%, Avg loss: 0.218627
#
# Epoch 73
# -------------------------------
# Test Error:
#  Accuracy: 93.8%, Avg loss: 0.216535
#
# Epoch 74
# -------------------------------
# Test Error:
#  Accuracy: 93.8%, Avg loss: 0.214477
#
# Epoch 75
# -------------------------------
# Test Error:
#  Accuracy: 93.9%, Avg loss: 0.212457
#
# Epoch 76
# -------------------------------
# Test Error:
#  Accuracy: 93.9%, Avg loss: 0.210464
#
# Epoch 77
# -------------------------------
# Test Error:
#  Accuracy: 94.0%, Avg loss: 0.208498
#
# Epoch 78
# -------------------------------
# Test Error:
#  Accuracy: 94.0%, Avg loss: 0.206566
#
# Epoch 79
# -------------------------------
# Test Error:
#  Accuracy: 94.1%, Avg loss: 0.204664
#
# Epoch 80
# -------------------------------
# Test Error:
#  Accuracy: 94.1%, Avg loss: 0.202800
#
# Epoch 81
# -------------------------------
# Test Error:
#  Accuracy: 94.2%, Avg loss: 0.200967
#
# Epoch 82
# -------------------------------
# Test Error:
#  Accuracy: 94.2%, Avg loss: 0.199165
#
# Epoch 83
# -------------------------------
# Test Error:
#  Accuracy: 94.2%, Avg loss: 0.197396
#
# Epoch 84
# -------------------------------
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.195655
#
# Epoch 85
# -------------------------------
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.193943
#
# Epoch 86
# -------------------------------
# Test Error:
#  Accuracy: 94.4%, Avg loss: 0.192268
#
# Epoch 87
# -------------------------------
# Test Error:
#  Accuracy: 94.5%, Avg loss: 0.190623
#
# Epoch 88
# -------------------------------
# Test Error:
#  Accuracy: 94.6%, Avg loss: 0.189004
#
# Epoch 89
# -------------------------------
# Test Error:
#  Accuracy: 94.6%, Avg loss: 0.187414
#
# Epoch 90
# -------------------------------
# Test Error:
#  Accuracy: 94.6%, Avg loss: 0.185848
#
# Epoch 91
# -------------------------------
# Test Error:
#  Accuracy: 94.7%, Avg loss: 0.184312
#
# Epoch 92
# -------------------------------
# Test Error:
#  Accuracy: 94.7%, Avg loss: 0.182803
#
# Epoch 93
# -------------------------------
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.181322
#
# Epoch 94
# -------------------------------
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.179869
#
# Epoch 95
# -------------------------------
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.178442
#
# Epoch 96
# -------------------------------
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.177040
#
# Epoch 97
# -------------------------------
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.175663
#
# Epoch 98
# -------------------------------
# Test Error:
#  Accuracy: 94.9%, Avg loss: 0.174304
#
# Epoch 99
# -------------------------------
# Test Error:
#  Accuracy: 94.9%, Avg loss: 0.172970
#
# Epoch 100
# -------------------------------
# Test Error:
#  Accuracy: 95.0%, Avg loss: 0.171662
#
# Training 4layers
# Epoch 1
# -------------------------------
# Test Error:
#  Accuracy: 9.6%, Avg loss: 2.302393
#
# Epoch 2
# -------------------------------
# Test Error:
#  Accuracy: 9.6%, Avg loss: 2.300241
#
# Epoch 3
# -------------------------------
# Test Error:
#  Accuracy: 13.9%, Avg loss: 2.298140
#
# Epoch 4
# -------------------------------
# Test Error:
#  Accuracy: 18.5%, Avg loss: 2.295956
#
# Epoch 5
# -------------------------------
# Test Error:
#  Accuracy: 14.1%, Avg loss: 2.293563
#
# Epoch 6
# -------------------------------
# Test Error:
#  Accuracy: 12.9%, Avg loss: 2.290819
#
# Epoch 7
# -------------------------------
# Test Error:
#  Accuracy: 13.9%, Avg loss: 2.287532
#
# Epoch 8
# -------------------------------
# Test Error:
#  Accuracy: 17.5%, Avg loss: 2.283448
#
# Epoch 9
# -------------------------------
# Test Error:
#  Accuracy: 23.6%, Avg loss: 2.278214
#
# Epoch 10
# -------------------------------
# Test Error:
#  Accuracy: 31.0%, Avg loss: 2.271251
#
# Epoch 11
# -------------------------------
# Test Error:
#  Accuracy: 37.9%, Avg loss: 2.261716
#
# Epoch 12
# -------------------------------
# Test Error:
#  Accuracy: 43.0%, Avg loss: 2.248176
#
# Epoch 13
# -------------------------------
# Test Error:
#  Accuracy: 46.2%, Avg loss: 2.227876
#
# Epoch 14
# -------------------------------
# Test Error:
#  Accuracy: 48.4%, Avg loss: 2.195170
#
# Epoch 15
# -------------------------------
# Test Error:
#  Accuracy: 48.8%, Avg loss: 2.138490
#
# Epoch 16
# -------------------------------
# Test Error:
#  Accuracy: 48.6%, Avg loss: 2.035692
#
# Epoch 17
# -------------------------------
# Test Error:
#  Accuracy: 51.4%, Avg loss: 1.853792
#
# Epoch 18
# -------------------------------
# Test Error:
#  Accuracy: 57.4%, Avg loss: 1.568623
#
# Epoch 19
# -------------------------------
# Test Error:
#  Accuracy: 63.7%, Avg loss: 1.245237
#
# Epoch 20
# -------------------------------
# Test Error:
#  Accuracy: 69.6%, Avg loss: 1.007272
#
# Epoch 21
# -------------------------------
# Test Error:
#  Accuracy: 73.3%, Avg loss: 0.861865
#
# Epoch 22
# -------------------------------
# Test Error:
#  Accuracy: 76.6%, Avg loss: 0.768741
#
# Epoch 23
# -------------------------------
# Test Error:
#  Accuracy: 78.6%, Avg loss: 0.704513
#
# Epoch 24
# -------------------------------
# Test Error:
#  Accuracy: 80.2%, Avg loss: 0.656541
#
# Epoch 25
# -------------------------------
# Test Error:
#  Accuracy: 81.4%, Avg loss: 0.617440
#
# Epoch 26
# -------------------------------
# Test Error:
#  Accuracy: 82.7%, Avg loss: 0.583186
#
# Epoch 27
# -------------------------------
# Test Error:
#  Accuracy: 83.7%, Avg loss: 0.551976
#
# Epoch 28
# -------------------------------
# Test Error:
#  Accuracy: 84.5%, Avg loss: 0.523478
#
# Epoch 29
# -------------------------------
# Test Error:
#  Accuracy: 85.3%, Avg loss: 0.498020
#
# Epoch 30
# -------------------------------
# Test Error:
#  Accuracy: 85.9%, Avg loss: 0.475771
#
# Epoch 31
# -------------------------------
# Test Error:
#  Accuracy: 86.6%, Avg loss: 0.456597
#
# Epoch 32
# -------------------------------
# Test Error:
#  Accuracy: 86.9%, Avg loss: 0.440089
#
# Epoch 33
# -------------------------------
# Test Error:
#  Accuracy: 87.3%, Avg loss: 0.425772
#
# Epoch 34
# -------------------------------
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.413214
#
# Epoch 35
# -------------------------------
# Test Error:
#  Accuracy: 88.2%, Avg loss: 0.402039
#
# Epoch 36
# -------------------------------
# Test Error:
#  Accuracy: 88.5%, Avg loss: 0.391990
#
# Epoch 37
# -------------------------------
# Test Error:
#  Accuracy: 88.7%, Avg loss: 0.382860
#
# Epoch 38
# -------------------------------
# Test Error:
#  Accuracy: 89.0%, Avg loss: 0.374487
#
# Epoch 39
# -------------------------------
# Test Error:
#  Accuracy: 89.1%, Avg loss: 0.366750
#
# Epoch 40
# -------------------------------
# Test Error:
#  Accuracy: 89.4%, Avg loss: 0.359519
#
# Epoch 41
# -------------------------------
# Test Error:
#  Accuracy: 89.6%, Avg loss: 0.352721
#
# Epoch 42
# -------------------------------
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.346270
#
# Epoch 43
# -------------------------------
# Test Error:
#  Accuracy: 89.9%, Avg loss: 0.340140
#
# Epoch 44
# -------------------------------
# Test Error:
#  Accuracy: 90.1%, Avg loss: 0.334311
#
# Epoch 45
# -------------------------------
# Test Error:
#  Accuracy: 90.4%, Avg loss: 0.328715
#
# Epoch 46
# -------------------------------
# Test Error:
#  Accuracy: 90.5%, Avg loss: 0.323347
#
# Epoch 47
# -------------------------------
# Test Error:
#  Accuracy: 90.7%, Avg loss: 0.318183
#
# Epoch 48
# -------------------------------
# Test Error:
#  Accuracy: 90.8%, Avg loss: 0.313196
#
# Epoch 49
# -------------------------------
# Test Error:
#  Accuracy: 90.9%, Avg loss: 0.308361
#
# Epoch 50
# -------------------------------
# Test Error:
#  Accuracy: 91.1%, Avg loss: 0.303681
#
# Epoch 51
# -------------------------------
# Test Error:
#  Accuracy: 91.2%, Avg loss: 0.299142
#
# Epoch 52
# -------------------------------
# Test Error:
#  Accuracy: 91.3%, Avg loss: 0.294712
#
# Epoch 53
# -------------------------------
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.290383
#
# Epoch 54
# -------------------------------
# Test Error:
#  Accuracy: 91.7%, Avg loss: 0.286152
#
# Epoch 55
# -------------------------------
# Test Error:
#  Accuracy: 91.8%, Avg loss: 0.281998
#
# Epoch 56
# -------------------------------
# Test Error:
#  Accuracy: 91.9%, Avg loss: 0.277920
#
# Epoch 57
# -------------------------------
# Test Error:
#  Accuracy: 92.0%, Avg loss: 0.273914
#
# Epoch 58
# -------------------------------
# Test Error:
#  Accuracy: 92.2%, Avg loss: 0.269949
#
# Epoch 59
# -------------------------------
# Test Error:
#  Accuracy: 92.2%, Avg loss: 0.266030
#
# Epoch 60
# -------------------------------
# Test Error:
#  Accuracy: 92.4%, Avg loss: 0.262174
#
# Epoch 61
# -------------------------------
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.258370
#
# Epoch 62
# -------------------------------
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.254628
#
# Epoch 63
# -------------------------------
# Test Error:
#  Accuracy: 92.6%, Avg loss: 0.250936
#
# Epoch 64
# -------------------------------
# Test Error:
#  Accuracy: 92.7%, Avg loss: 0.247307
#
# Epoch 65
# -------------------------------
# Test Error:
#  Accuracy: 92.7%, Avg loss: 0.243731
#
# Epoch 66
# -------------------------------
# Test Error:
#  Accuracy: 92.8%, Avg loss: 0.240204
#
# Epoch 67
# -------------------------------
# Test Error:
#  Accuracy: 92.9%, Avg loss: 0.236742
#
# Epoch 68
# -------------------------------
# Test Error:
#  Accuracy: 93.1%, Avg loss: 0.233340
#
# Epoch 69
# -------------------------------
# Test Error:
#  Accuracy: 93.2%, Avg loss: 0.230004
#
# Epoch 70
# -------------------------------
# Test Error:
#  Accuracy: 93.3%, Avg loss: 0.226727
#
# Epoch 71
# -------------------------------
# Test Error:
#  Accuracy: 93.5%, Avg loss: 0.223500
#
# Epoch 72
# -------------------------------
# Test Error:
#  Accuracy: 93.6%, Avg loss: 0.220312
#
# Epoch 73
# -------------------------------
# Test Error:
#  Accuracy: 93.7%, Avg loss: 0.217194
#
# Epoch 74
# -------------------------------
# Test Error:
#  Accuracy: 93.8%, Avg loss: 0.214129
#
# Epoch 75
# -------------------------------
# Test Error:
#  Accuracy: 93.8%, Avg loss: 0.211123
#
# Epoch 76
# -------------------------------
# Test Error:
#  Accuracy: 93.9%, Avg loss: 0.208181
#
# Epoch 77
# -------------------------------
# Test Error:
#  Accuracy: 94.0%, Avg loss: 0.205289
#
# Epoch 78
# -------------------------------
# Test Error:
#  Accuracy: 94.1%, Avg loss: 0.202466
#
# Epoch 79
# -------------------------------
# Test Error:
#  Accuracy: 94.2%, Avg loss: 0.199713
#
# Epoch 80
# -------------------------------
# Test Error:
#  Accuracy: 94.2%, Avg loss: 0.197013
#
# Epoch 81
# -------------------------------
# Test Error:
#  Accuracy: 94.4%, Avg loss: 0.194373
#
# Epoch 82
# -------------------------------
# Test Error:
#  Accuracy: 94.5%, Avg loss: 0.191802
#
# Epoch 83
# -------------------------------
# Test Error:
#  Accuracy: 94.5%, Avg loss: 0.189289
#
# Epoch 84
# -------------------------------
# Test Error:
#  Accuracy: 94.6%, Avg loss: 0.186838
#
# Epoch 85
# -------------------------------
# Test Error:
#  Accuracy: 94.7%, Avg loss: 0.184452
#
# Epoch 86
# -------------------------------
# Test Error:
#  Accuracy: 94.7%, Avg loss: 0.182115
#
# Epoch 87
# -------------------------------
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.179834
#
# Epoch 88
# -------------------------------
# Test Error:
#  Accuracy: 94.9%, Avg loss: 0.177607
#
# Epoch 89
# -------------------------------
# Test Error:
#  Accuracy: 95.0%, Avg loss: 0.175436
#
# Epoch 90
# -------------------------------
# Test Error:
#  Accuracy: 95.0%, Avg loss: 0.173325
#
# Epoch 91
# -------------------------------
# Test Error:
#  Accuracy: 95.1%, Avg loss: 0.171274
#
# Epoch 92
# -------------------------------
# Test Error:
#  Accuracy: 95.1%, Avg loss: 0.169260
#
# Epoch 93
# -------------------------------
# Test Error:
#  Accuracy: 95.2%, Avg loss: 0.167306
#
# Epoch 94
# -------------------------------
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.165409
#
# Epoch 95
# -------------------------------
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.163558
#
# Epoch 96
# -------------------------------
# Test Error:
#  Accuracy: 95.4%, Avg loss: 0.161753
#
# Epoch 97
# -------------------------------
# Test Error:
#  Accuracy: 95.4%, Avg loss: 0.160000
#
# Epoch 98
# -------------------------------
# Test Error:
#  Accuracy: 95.5%, Avg loss: 0.158288
#
# Epoch 99
# -------------------------------
# Test Error:
#  Accuracy: 95.5%, Avg loss: 0.156613
#
# Epoch 100
# -------------------------------
# Test Error:
#  Accuracy: 95.6%, Avg loss: 0.154984

# %%
visualise_model_perf(models, title='Avg error vs Number of Epochs');

# %% [markdown]
# <hr>

# %% [markdown]
# ### Experiments 2: Changing the batch size

# %%
models = train_models(load_config('batch_size.json'))
# Out:
# Training b32
# Epoch 1
# -------------------------------
# Training Error:
#  Accuracy: 11.2%, Avg loss: 2.298357
#
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.298303
#
# Epoch 2
# -------------------------------
# Training Error:
#  Accuracy: 11.2%, Avg loss: 2.293903
#
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.293669
#
# Epoch 3
# -------------------------------
# Training Error:
#  Accuracy: 12.5%, Avg loss: 2.287853
#
# Test Error:
#  Accuracy: 12.8%, Avg loss: 2.287405
#
# Epoch 4
# -------------------------------
# Training Error:
#  Accuracy: 21.4%, Avg loss: 2.278303
#
# Test Error:
#  Accuracy: 21.7%, Avg loss: 2.277591
#
# Epoch 5
# -------------------------------
# Training Error:
#  Accuracy: 33.5%, Avg loss: 2.260622
#
# Test Error:
#  Accuracy: 34.2%, Avg loss: 2.259517
#
# Epoch 6
# -------------------------------
# Training Error:
#  Accuracy: 37.5%, Avg loss: 2.220468
#
# Test Error:
#  Accuracy: 37.3%, Avg loss: 2.218602
#
# Epoch 7
# -------------------------------
# Training Error:
#  Accuracy: 38.2%, Avg loss: 2.103802
#
# Test Error:
#  Accuracy: 38.7%, Avg loss: 2.100053
#
# Epoch 8
# -------------------------------
# Training Error:
#  Accuracy: 49.2%, Avg loss: 1.800220
#
# Test Error:
#  Accuracy: 49.0%, Avg loss: 1.791699
#
# Epoch 9
# -------------------------------
# Training Error:
#  Accuracy: 61.6%, Avg loss: 1.330345
#
# Test Error:
#  Accuracy: 61.8%, Avg loss: 1.315995
#
# Epoch 10
# -------------------------------
# Training Error:
#  Accuracy: 70.0%, Avg loss: 0.966941
#
# Test Error:
#  Accuracy: 70.1%, Avg loss: 0.953783
#
# Epoch 11
# -------------------------------
# Training Error:
#  Accuracy: 76.4%, Avg loss: 0.763374
#
# Test Error:
#  Accuracy: 77.0%, Avg loss: 0.749091
#
# Epoch 12
# -------------------------------
# Training Error:
#  Accuracy: 80.5%, Avg loss: 0.648450
#
# Test Error:
#  Accuracy: 81.2%, Avg loss: 0.632436
#
# Epoch 13
# -------------------------------
# Training Error:
#  Accuracy: 83.0%, Avg loss: 0.571309
#
# Test Error:
#  Accuracy: 83.5%, Avg loss: 0.554355
#
# Epoch 14
# -------------------------------
# Training Error:
#  Accuracy: 85.0%, Avg loss: 0.515052
#
# Test Error:
#  Accuracy: 85.1%, Avg loss: 0.498412
#
# Epoch 15
# -------------------------------
# Training Error:
#  Accuracy: 86.2%, Avg loss: 0.474457
#
# Test Error:
#  Accuracy: 86.5%, Avg loss: 0.459186
#
# Epoch 16
# -------------------------------
# Training Error:
#  Accuracy: 87.1%, Avg loss: 0.443695
#
# Test Error:
#  Accuracy: 87.4%, Avg loss: 0.430231
#
# Epoch 17
# -------------------------------
# Training Error:
#  Accuracy: 87.8%, Avg loss: 0.418921
#
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.407278
#
# Epoch 18
# -------------------------------
# Training Error:
#  Accuracy: 88.5%, Avg loss: 0.398186
#
# Test Error:
#  Accuracy: 88.5%, Avg loss: 0.388158
#
# Epoch 19
# -------------------------------
# Training Error:
#  Accuracy: 88.9%, Avg loss: 0.380477
#
# Test Error:
#  Accuracy: 89.0%, Avg loss: 0.371796
#
# Epoch 20
# -------------------------------
# Training Error:
#  Accuracy: 89.4%, Avg loss: 0.365027
#
# Test Error:
#  Accuracy: 89.4%, Avg loss: 0.357449
#
# Epoch 21
# -------------------------------
# Training Error:
#  Accuracy: 89.8%, Avg loss: 0.351359
#
# Test Error:
#  Accuracy: 89.9%, Avg loss: 0.344616
#
# Epoch 22
# -------------------------------
# Training Error:
#  Accuracy: 90.2%, Avg loss: 0.339154
#
# Test Error:
#  Accuracy: 90.2%, Avg loss: 0.333061
#
# Epoch 23
# -------------------------------
# Training Error:
#  Accuracy: 90.5%, Avg loss: 0.328119
#
# Test Error:
#  Accuracy: 90.5%, Avg loss: 0.322587
#
# Epoch 24
# -------------------------------
# Training Error:
#  Accuracy: 90.8%, Avg loss: 0.318024
#
# Test Error:
#  Accuracy: 90.7%, Avg loss: 0.312909
#
# Epoch 25
# -------------------------------
# Training Error:
#  Accuracy: 91.1%, Avg loss: 0.308639
#
# Test Error:
#  Accuracy: 91.0%, Avg loss: 0.303878
#
# Epoch 26
# -------------------------------
# Training Error:
#  Accuracy: 91.4%, Avg loss: 0.299748
#
# Test Error:
#  Accuracy: 91.4%, Avg loss: 0.295350
#
# Epoch 27
# -------------------------------
# Training Error:
#  Accuracy: 91.6%, Avg loss: 0.291216
#
# Test Error:
#  Accuracy: 91.6%, Avg loss: 0.287196
#
# Epoch 28
# -------------------------------
# Training Error:
#  Accuracy: 91.9%, Avg loss: 0.283045
#
# Test Error:
#  Accuracy: 91.8%, Avg loss: 0.279396
#
# Epoch 29
# -------------------------------
# Training Error:
#  Accuracy: 92.1%, Avg loss: 0.275125
#
# Test Error:
#  Accuracy: 92.0%, Avg loss: 0.271858
#
# Epoch 30
# -------------------------------
# Training Error:
#  Accuracy: 92.3%, Avg loss: 0.267487
#
# Test Error:
#  Accuracy: 92.3%, Avg loss: 0.264581
#
# Epoch 31
# -------------------------------
# Training Error:
#  Accuracy: 92.5%, Avg loss: 0.260077
#
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.257561
#
# Epoch 32
# -------------------------------
# Training Error:
#  Accuracy: 92.7%, Avg loss: 0.252852
#
# Test Error:
#  Accuracy: 92.8%, Avg loss: 0.250735
#
# Epoch 33
# -------------------------------
# Training Error:
#  Accuracy: 93.0%, Avg loss: 0.245774
#
# Test Error:
#  Accuracy: 92.9%, Avg loss: 0.244072
#
# Epoch 34
# -------------------------------
# Training Error:
#  Accuracy: 93.1%, Avg loss: 0.238916
#
# Test Error:
#  Accuracy: 93.1%, Avg loss: 0.237672
#
# Epoch 35
# -------------------------------
# Training Error:
#  Accuracy: 93.3%, Avg loss: 0.232229
#
# Test Error:
#  Accuracy: 93.4%, Avg loss: 0.231407
#
# Epoch 36
# -------------------------------
# Training Error:
#  Accuracy: 93.5%, Avg loss: 0.225719
#
# Test Error:
#  Accuracy: 93.5%, Avg loss: 0.225295
#
# Epoch 37
# -------------------------------
# Training Error:
#  Accuracy: 93.7%, Avg loss: 0.219412
#
# Test Error:
#  Accuracy: 93.7%, Avg loss: 0.219401
#
# Epoch 38
# -------------------------------
# Training Error:
#  Accuracy: 93.9%, Avg loss: 0.213310
#
# Test Error:
#  Accuracy: 93.9%, Avg loss: 0.213710
#
# Epoch 39
# -------------------------------
# Training Error:
#  Accuracy: 94.1%, Avg loss: 0.207390
#
# Test Error:
#  Accuracy: 94.1%, Avg loss: 0.208200
#
# Epoch 40
# -------------------------------
# Training Error:
#  Accuracy: 94.2%, Avg loss: 0.201667
#
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.202882
#
# Epoch 41
# -------------------------------
# Training Error:
#  Accuracy: 94.4%, Avg loss: 0.196108
#
# Test Error:
#  Accuracy: 94.5%, Avg loss: 0.197758
#
# Epoch 42
# -------------------------------
# Training Error:
#  Accuracy: 94.6%, Avg loss: 0.190787
#
# Test Error:
#  Accuracy: 94.6%, Avg loss: 0.192887
#
# Epoch 43
# -------------------------------
# Training Error:
#  Accuracy: 94.7%, Avg loss: 0.185683
#
# Test Error:
#  Accuracy: 94.7%, Avg loss: 0.188236
#
# Epoch 44
# -------------------------------
# Training Error:
#  Accuracy: 94.9%, Avg loss: 0.180772
#
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.183808
#
# Epoch 45
# -------------------------------
# Training Error:
#  Accuracy: 95.0%, Avg loss: 0.176017
#
# Test Error:
#  Accuracy: 95.0%, Avg loss: 0.179537
#
# Epoch 46
# -------------------------------
# Training Error:
#  Accuracy: 95.1%, Avg loss: 0.171467
#
# Test Error:
#  Accuracy: 95.1%, Avg loss: 0.175476
#
# Epoch 47
# -------------------------------
# Training Error:
#  Accuracy: 95.3%, Avg loss: 0.167096
#
# Test Error:
#  Accuracy: 95.2%, Avg loss: 0.171606
#
# Epoch 48
# -------------------------------
# Training Error:
#  Accuracy: 95.4%, Avg loss: 0.162855
#
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.167875
#
# Epoch 49
# -------------------------------
# Training Error:
#  Accuracy: 95.5%, Avg loss: 0.158787
#
# Test Error:
#  Accuracy: 95.4%, Avg loss: 0.164348
#
# Epoch 50
# -------------------------------
# Training Error:
#  Accuracy: 95.6%, Avg loss: 0.154867
#
# Test Error:
#  Accuracy: 95.4%, Avg loss: 0.160990
#
# Epoch 51
# -------------------------------
# Training Error:
#  Accuracy: 95.7%, Avg loss: 0.151085
#
# Test Error:
#  Accuracy: 95.5%, Avg loss: 0.157785
#
# Epoch 52
# -------------------------------
# Training Error:
#  Accuracy: 95.8%, Avg loss: 0.147449
#
# Test Error:
#  Accuracy: 95.5%, Avg loss: 0.154730
#
# Epoch 53
# -------------------------------
# Training Error:
#  Accuracy: 95.9%, Avg loss: 0.143966
#
# Test Error:
#  Accuracy: 95.6%, Avg loss: 0.151841
#
# Epoch 54
# -------------------------------
# Training Error:
#  Accuracy: 96.0%, Avg loss: 0.140592
#
# Test Error:
#  Accuracy: 95.7%, Avg loss: 0.149080
#
# Epoch 55
# -------------------------------
# Training Error:
#  Accuracy: 96.1%, Avg loss: 0.137315
#
# Test Error:
#  Accuracy: 95.8%, Avg loss: 0.146427
#
# Epoch 56
# -------------------------------
# Training Error:
#  Accuracy: 96.2%, Avg loss: 0.134144
#
# Test Error:
#  Accuracy: 95.8%, Avg loss: 0.143890
#
# Epoch 57
# -------------------------------
# Training Error:
#  Accuracy: 96.3%, Avg loss: 0.131082
#
# Test Error:
#  Accuracy: 95.9%, Avg loss: 0.141489
#
# Epoch 58
# -------------------------------
# Training Error:
#  Accuracy: 96.4%, Avg loss: 0.128147
#
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.139200
#
# Epoch 59
# -------------------------------
# Training Error:
#  Accuracy: 96.5%, Avg loss: 0.125304
#
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.137013
#
# Epoch 60
# -------------------------------
# Training Error:
#  Accuracy: 96.6%, Avg loss: 0.122547
#
# Test Error:
#  Accuracy: 96.1%, Avg loss: 0.134918
#
# Epoch 61
# -------------------------------
# Training Error:
#  Accuracy: 96.7%, Avg loss: 0.119888
#
# Test Error:
#  Accuracy: 96.2%, Avg loss: 0.132915
#
# Epoch 62
# -------------------------------
# Training Error:
#  Accuracy: 96.7%, Avg loss: 0.117311
#
# Test Error:
#  Accuracy: 96.2%, Avg loss: 0.130993
#
# Epoch 63
# -------------------------------
# Training Error:
#  Accuracy: 96.8%, Avg loss: 0.114807
#
# Test Error:
#  Accuracy: 96.3%, Avg loss: 0.129167
#
# Epoch 64
# -------------------------------
# Training Error:
#  Accuracy: 96.9%, Avg loss: 0.112398
#
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.127410
#
# Epoch 65
# -------------------------------
# Training Error:
#  Accuracy: 96.9%, Avg loss: 0.110035
#
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.125717
#
# Epoch 66
# -------------------------------
# Training Error:
#  Accuracy: 97.0%, Avg loss: 0.107750
#
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.124074
#
# Epoch 67
# -------------------------------
# Training Error:
#  Accuracy: 97.1%, Avg loss: 0.105508
#
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.122506
#
# Epoch 68
# -------------------------------
# Training Error:
#  Accuracy: 97.1%, Avg loss: 0.103352
#
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.121040
#
# Epoch 69
# -------------------------------
# Training Error:
#  Accuracy: 97.2%, Avg loss: 0.101264
#
# Test Error:
#  Accuracy: 96.6%, Avg loss: 0.119645
#
# Epoch 70
# -------------------------------
# Training Error:
#  Accuracy: 97.3%, Avg loss: 0.099241
#
# Test Error:
#  Accuracy: 96.6%, Avg loss: 0.118337
#
# Epoch 71
# -------------------------------
# Training Error:
#  Accuracy: 97.3%, Avg loss: 0.097251
#
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.117038
#
# Epoch 72
# -------------------------------
# Training Error:
#  Accuracy: 97.4%, Avg loss: 0.095311
#
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.115791
#
# Epoch 73
# -------------------------------
# Training Error:
#  Accuracy: 97.4%, Avg loss: 0.093438
#
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.114616
#
# Epoch 74
# -------------------------------
# Training Error:
#  Accuracy: 97.4%, Avg loss: 0.091601
#
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.113479
#
# Epoch 75
# -------------------------------
# Training Error:
#  Accuracy: 97.5%, Avg loss: 0.089827
#
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.112391
#
# Epoch 76
# -------------------------------
# Training Error:
#  Accuracy: 97.5%, Avg loss: 0.088106
#
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.111346
#
# Epoch 77
# -------------------------------
# Training Error:
#  Accuracy: 97.6%, Avg loss: 0.086420
#
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.110332
#
# Epoch 78
# -------------------------------
# Training Error:
#  Accuracy: 97.6%, Avg loss: 0.084780
#
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.109362
#
# Epoch 79
# -------------------------------
# Training Error:
#  Accuracy: 97.7%, Avg loss: 0.083161
#
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.108434
#
# Epoch 80
# -------------------------------
# Training Error:
#  Accuracy: 97.7%, Avg loss: 0.081599
#
# Test Error:
#  Accuracy: 97.0%, Avg loss: 0.107548
#
# Epoch 81
# -------------------------------
# Training Error:
#  Accuracy: 97.8%, Avg loss: 0.080059
#
# Test Error:
#  Accuracy: 97.0%, Avg loss: 0.106695
#
# Epoch 82
# -------------------------------
# Training Error:
#  Accuracy: 97.8%, Avg loss: 0.078551
#
# Test Error:
#  Accuracy: 97.0%, Avg loss: 0.105826
#
# Epoch 83
# -------------------------------
# Training Error:
#  Accuracy: 97.9%, Avg loss: 0.077070
#
# Test Error:
#  Accuracy: 97.0%, Avg loss: 0.105021
#
# Epoch 84
# -------------------------------
# Training Error:
#  Accuracy: 97.9%, Avg loss: 0.075612
#
# Test Error:
#  Accuracy: 97.0%, Avg loss: 0.104251
#
# Epoch 85
# -------------------------------
# Training Error:
#  Accuracy: 97.9%, Avg loss: 0.074182
#
# Test Error:
#  Accuracy: 97.0%, Avg loss: 0.103483
#
# Epoch 86
# -------------------------------
# Training Error:
#  Accuracy: 98.0%, Avg loss: 0.072796
#
# Test Error:
#  Accuracy: 97.1%, Avg loss: 0.102775
#
# Epoch 87
# -------------------------------
# Training Error:
#  Accuracy: 98.0%, Avg loss: 0.071423
#
# Test Error:
#  Accuracy: 97.1%, Avg loss: 0.102031
#
# Epoch 88
# -------------------------------
# Training Error:
#  Accuracy: 98.1%, Avg loss: 0.070103
#
# Test Error:
#  Accuracy: 97.1%, Avg loss: 0.101364
#
# Epoch 89
# -------------------------------
# Training Error:
#  Accuracy: 98.1%, Avg loss: 0.068793
#
# Test Error:
#  Accuracy: 97.1%, Avg loss: 0.100697
#
# Epoch 90
# -------------------------------
# Training Error:
#  Accuracy: 98.1%, Avg loss: 0.067517
#
# Test Error:
#  Accuracy: 97.1%, Avg loss: 0.100046
#
# Epoch 91
# -------------------------------
# Training Error:
#  Accuracy: 98.2%, Avg loss: 0.066271
#
# Test Error:
#  Accuracy: 97.1%, Avg loss: 0.099421
#
# Epoch 92
# -------------------------------
# Training Error:
#  Accuracy: 98.2%, Avg loss: 0.065045
#
# Test Error:
#  Accuracy: 97.1%, Avg loss: 0.098835
#
# Epoch 93
# -------------------------------
# Training Error:
#  Accuracy: 98.3%, Avg loss: 0.063842
#
# Test Error:
#  Accuracy: 97.1%, Avg loss: 0.098253
#
# Epoch 94
# -------------------------------
# Training Error:
#  Accuracy: 98.3%, Avg loss: 0.062664
#
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.097704
#
# Epoch 95
# -------------------------------
# Training Error:
#  Accuracy: 98.3%, Avg loss: 0.061501
#
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.097183
#
# Epoch 96
# -------------------------------
# Training Error:
#  Accuracy: 98.4%, Avg loss: 0.060372
#
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.096674
#
# Epoch 97
# -------------------------------
# Training Error:
#  Accuracy: 98.4%, Avg loss: 0.059254
#
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.096193
#
# Epoch 98
# -------------------------------
# Training Error:
#  Accuracy: 98.4%, Avg loss: 0.058151
#
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.095688
#
# Epoch 99
# -------------------------------
# Training Error:
#  Accuracy: 98.5%, Avg loss: 0.057091
#
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.095247
#
# Epoch 100
# -------------------------------
# Training Error:
#  Accuracy: 98.5%, Avg loss: 0.056022
#
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.094752
#
# Training b64
# Epoch 1
# -------------------------------
# Training Error:
#  Accuracy: 10.4%, Avg loss: 2.300470
#
# Test Error:
#  Accuracy: 10.3%, Avg loss: 2.300645
#
# Epoch 2
# -------------------------------
# Training Error:
#  Accuracy: 10.4%, Avg loss: 2.298335
#
# Test Error:
#  Accuracy: 10.3%, Avg loss: 2.298421
#
# Epoch 3
# -------------------------------
# Training Error:
#  Accuracy: 10.5%, Avg loss: 2.296101
#
# Test Error:
#  Accuracy: 10.5%, Avg loss: 2.296099
#
# Epoch 4
# -------------------------------
# Training Error:
#  Accuracy: 19.6%, Avg loss: 2.293619
#
# Test Error:
#  Accuracy: 19.8%, Avg loss: 2.293531
#
# Epoch 5
# -------------------------------
# Training Error:
#  Accuracy: 25.3%, Avg loss: 2.290714
#
# Test Error:
#  Accuracy: 25.5%, Avg loss: 2.290536
#
# Epoch 6
# -------------------------------
# Training Error:
#  Accuracy: 28.1%, Avg loss: 2.287174
#
# Test Error:
#  Accuracy: 28.1%, Avg loss: 2.286900
#
# Epoch 7
# -------------------------------
# Training Error:
#  Accuracy: 30.3%, Avg loss: 2.282703
#
# Test Error:
#  Accuracy: 30.2%, Avg loss: 2.282318
#
# Epoch 8
# -------------------------------
# Training Error:
#  Accuracy: 32.8%, Avg loss: 2.276839
#
# Test Error:
#  Accuracy: 33.0%, Avg loss: 2.276315
#
# Epoch 9
# -------------------------------
# Training Error:
#  Accuracy: 36.0%, Avg loss: 2.268908
#
# Test Error:
#  Accuracy: 36.6%, Avg loss: 2.268208
#
# Epoch 10
# -------------------------------
# Training Error:
#  Accuracy: 39.5%, Avg loss: 2.257805
#
# Test Error:
#  Accuracy: 40.1%, Avg loss: 2.256875
#
# Epoch 11
# -------------------------------
# Training Error:
#  Accuracy: 42.1%, Avg loss: 2.241545
#
# Test Error:
#  Accuracy: 42.4%, Avg loss: 2.240291
#
# Epoch 12
# -------------------------------
# Training Error:
#  Accuracy: 43.3%, Avg loss: 2.216088
#
# Test Error:
#  Accuracy: 43.0%, Avg loss: 2.214329
#
# Epoch 13
# -------------------------------
# Training Error:
#  Accuracy: 43.6%, Avg loss: 2.173086
#
# Test Error:
#  Accuracy: 42.7%, Avg loss: 2.170514
#
# Epoch 14
# -------------------------------
# Training Error:
#  Accuracy: 44.1%, Avg loss: 2.094019
#
# Test Error:
#  Accuracy: 43.4%, Avg loss: 2.090037
#
# Epoch 15
# -------------------------------
# Training Error:
#  Accuracy: 46.5%, Avg loss: 1.945154
#
# Test Error:
#  Accuracy: 46.0%, Avg loss: 1.938767
#
# Epoch 16
# -------------------------------
# Training Error:
#  Accuracy: 53.5%, Avg loss: 1.703000
#
# Test Error:
#  Accuracy: 53.3%, Avg loss: 1.693131
#
# Epoch 17
# -------------------------------
# Training Error:
#  Accuracy: 61.0%, Avg loss: 1.404846
#
# Test Error:
#  Accuracy: 61.8%, Avg loss: 1.391773
#
# Epoch 18
# -------------------------------
# Training Error:
#  Accuracy: 66.4%, Avg loss: 1.138450
#
# Test Error:
#  Accuracy: 66.5%, Avg loss: 1.124336
#
# Epoch 19
# -------------------------------
# Training Error:
#  Accuracy: 70.7%, Avg loss: 0.955306
#
# Test Error:
#  Accuracy: 71.1%, Avg loss: 0.940646
#
# Epoch 20
# -------------------------------
# Training Error:
#  Accuracy: 74.0%, Avg loss: 0.837464
#
# Test Error:
#  Accuracy: 74.3%, Avg loss: 0.821986
#
# Epoch 21
# -------------------------------
# Training Error:
#  Accuracy: 76.3%, Avg loss: 0.758748
#
# Test Error:
#  Accuracy: 76.9%, Avg loss: 0.742526
#
# Epoch 22
# -------------------------------
# Training Error:
#  Accuracy: 78.1%, Avg loss: 0.702773
#
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.686045
#
# Epoch 23
# -------------------------------
# Training Error:
#  Accuracy: 79.7%, Avg loss: 0.659806
#
# Test Error:
#  Accuracy: 80.5%, Avg loss: 0.642744
#
# Epoch 24
# -------------------------------
# Training Error:
#  Accuracy: 81.0%, Avg loss: 0.624217
#
# Test Error:
#  Accuracy: 81.6%, Avg loss: 0.606911
#
# Epoch 25
# -------------------------------
# Training Error:
#  Accuracy: 82.0%, Avg loss: 0.593066
#
# Test Error:
#  Accuracy: 82.9%, Avg loss: 0.575639
#
# Epoch 26
# -------------------------------
# Training Error:
#  Accuracy: 83.1%, Avg loss: 0.565047
#
# Test Error:
#  Accuracy: 83.8%, Avg loss: 0.547688
#
# Epoch 27
# -------------------------------
# Training Error:
#  Accuracy: 84.0%, Avg loss: 0.539722
#
# Test Error:
#  Accuracy: 84.4%, Avg loss: 0.522679
#
# Epoch 28
# -------------------------------
# Training Error:
#  Accuracy: 84.8%, Avg loss: 0.517135
#
# Test Error:
#  Accuracy: 85.1%, Avg loss: 0.500637
#
# Epoch 29
# -------------------------------
# Training Error:
#  Accuracy: 85.4%, Avg loss: 0.497295
#
# Test Error:
#  Accuracy: 85.7%, Avg loss: 0.481510
#
# Epoch 30
# -------------------------------
# Training Error:
#  Accuracy: 86.0%, Avg loss: 0.479988
#
# Test Error:
#  Accuracy: 86.1%, Avg loss: 0.465020
#
# Epoch 31
# -------------------------------
# Training Error:
#  Accuracy: 86.5%, Avg loss: 0.464839
#
# Test Error:
#  Accuracy: 86.5%, Avg loss: 0.450714
#
# Epoch 32
# -------------------------------
# Training Error:
#  Accuracy: 86.9%, Avg loss: 0.451424
#
# Test Error:
#  Accuracy: 87.1%, Avg loss: 0.438112
#
# Epoch 33
# -------------------------------
# Training Error:
#  Accuracy: 87.2%, Avg loss: 0.439372
#
# Test Error:
#  Accuracy: 87.5%, Avg loss: 0.426822
#
# Epoch 34
# -------------------------------
# Training Error:
#  Accuracy: 87.6%, Avg loss: 0.428396
#
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.416513
#
# Epoch 35
# -------------------------------
# Training Error:
#  Accuracy: 87.9%, Avg loss: 0.418267
#
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.406993
#
# Epoch 36
# -------------------------------
# Training Error:
#  Accuracy: 88.2%, Avg loss: 0.408811
#
# Test Error:
#  Accuracy: 88.3%, Avg loss: 0.398110
#
# Epoch 37
# -------------------------------
# Training Error:
#  Accuracy: 88.5%, Avg loss: 0.399928
#
# Test Error:
#  Accuracy: 88.5%, Avg loss: 0.389769
#
# Epoch 38
# -------------------------------
# Training Error:
#  Accuracy: 88.7%, Avg loss: 0.391548
#
# Test Error:
#  Accuracy: 88.8%, Avg loss: 0.381885
#
# Epoch 39
# -------------------------------
# Training Error:
#  Accuracy: 89.0%, Avg loss: 0.383608
#
# Test Error:
#  Accuracy: 89.2%, Avg loss: 0.374403
#
# Epoch 40
# -------------------------------
# Training Error:
#  Accuracy: 89.2%, Avg loss: 0.376039
#
# Test Error:
#  Accuracy: 89.3%, Avg loss: 0.367252
#
# Epoch 41
# -------------------------------
# Training Error:
#  Accuracy: 89.4%, Avg loss: 0.368800
#
# Test Error:
#  Accuracy: 89.6%, Avg loss: 0.360390
#
# Epoch 42
# -------------------------------
# Training Error:
#  Accuracy: 89.6%, Avg loss: 0.361860
#
# Test Error:
#  Accuracy: 89.9%, Avg loss: 0.353780
#
# Epoch 43
# -------------------------------
# Training Error:
#  Accuracy: 89.8%, Avg loss: 0.355200
#
# Test Error:
#  Accuracy: 90.1%, Avg loss: 0.347414
#
# Epoch 44
# -------------------------------
# Training Error:
#  Accuracy: 90.0%, Avg loss: 0.348797
#
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.341300
#
# Epoch 45
# -------------------------------
# Training Error:
#  Accuracy: 90.2%, Avg loss: 0.342634
#
# Test Error:
#  Accuracy: 90.5%, Avg loss: 0.335416
#
# Epoch 46
# -------------------------------
# Training Error:
#  Accuracy: 90.4%, Avg loss: 0.336670
#
# Test Error:
#  Accuracy: 90.6%, Avg loss: 0.329716
#
# Epoch 47
# -------------------------------
# Training Error:
#  Accuracy: 90.5%, Avg loss: 0.330906
#
# Test Error:
#  Accuracy: 90.7%, Avg loss: 0.324212
#
# Epoch 48
# -------------------------------
# Training Error:
#  Accuracy: 90.7%, Avg loss: 0.325322
#
# Test Error:
#  Accuracy: 90.8%, Avg loss: 0.318888
#
# Epoch 49
# -------------------------------
# Training Error:
#  Accuracy: 90.9%, Avg loss: 0.319892
#
# Test Error:
#  Accuracy: 91.1%, Avg loss: 0.313703
#
# Epoch 50
# -------------------------------
# Training Error:
#  Accuracy: 91.0%, Avg loss: 0.314599
#
# Test Error:
#  Accuracy: 91.2%, Avg loss: 0.308647
#
# Epoch 51
# -------------------------------
# Training Error:
#  Accuracy: 91.2%, Avg loss: 0.309428
#
# Test Error:
#  Accuracy: 91.3%, Avg loss: 0.303728
#
# Epoch 52
# -------------------------------
# Training Error:
#  Accuracy: 91.4%, Avg loss: 0.304362
#
# Test Error:
#  Accuracy: 91.4%, Avg loss: 0.298939
#
# Epoch 53
# -------------------------------
# Training Error:
#  Accuracy: 91.5%, Avg loss: 0.299406
#
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.294260
#
# Epoch 54
# -------------------------------
# Training Error:
#  Accuracy: 91.7%, Avg loss: 0.294559
#
# Test Error:
#  Accuracy: 91.6%, Avg loss: 0.289696
#
# Epoch 55
# -------------------------------
# Training Error:
#  Accuracy: 91.8%, Avg loss: 0.289815
#
# Test Error:
#  Accuracy: 91.8%, Avg loss: 0.285245
#
# Epoch 56
# -------------------------------
# Training Error:
#  Accuracy: 91.9%, Avg loss: 0.285159
#
# Test Error:
#  Accuracy: 91.9%, Avg loss: 0.280893
#
# Epoch 57
# -------------------------------
# Training Error:
#  Accuracy: 92.1%, Avg loss: 0.280590
#
# Test Error:
#  Accuracy: 92.0%, Avg loss: 0.276620
#
# Epoch 58
# -------------------------------
# Training Error:
#  Accuracy: 92.2%, Avg loss: 0.276104
#
# Test Error:
#  Accuracy: 92.2%, Avg loss: 0.272445
#
# Epoch 59
# -------------------------------
# Training Error:
#  Accuracy: 92.3%, Avg loss: 0.271695
#
# Test Error:
#  Accuracy: 92.2%, Avg loss: 0.268357
#
# Epoch 60
# -------------------------------
# Training Error:
#  Accuracy: 92.4%, Avg loss: 0.267366
#
# Test Error:
#  Accuracy: 92.3%, Avg loss: 0.264341
#
# Epoch 61
# -------------------------------
# Training Error:
#  Accuracy: 92.6%, Avg loss: 0.263109
#
# Test Error:
#  Accuracy: 92.4%, Avg loss: 0.260409
#
# Epoch 62
# -------------------------------
# Training Error:
#  Accuracy: 92.7%, Avg loss: 0.258929
#
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.256559
#
# Epoch 63
# -------------------------------
# Training Error:
#  Accuracy: 92.8%, Avg loss: 0.254811
#
# Test Error:
#  Accuracy: 92.7%, Avg loss: 0.252768
#
# Epoch 64
# -------------------------------
# Training Error:
#  Accuracy: 92.9%, Avg loss: 0.250761
#
# Test Error:
#  Accuracy: 92.8%, Avg loss: 0.249042
#
# Epoch 65
# -------------------------------
# Training Error:
#  Accuracy: 93.0%, Avg loss: 0.246788
#
# Test Error:
#  Accuracy: 92.9%, Avg loss: 0.245384
#
# Epoch 66
# -------------------------------
# Training Error:
#  Accuracy: 93.1%, Avg loss: 0.242883
#
# Test Error:
#  Accuracy: 93.0%, Avg loss: 0.241796
#
# Epoch 67
# -------------------------------
# Training Error:
#  Accuracy: 93.3%, Avg loss: 0.239042
#
# Test Error:
#  Accuracy: 93.2%, Avg loss: 0.238272
#
# Epoch 68
# -------------------------------
# Training Error:
#  Accuracy: 93.4%, Avg loss: 0.235274
#
# Test Error:
#  Accuracy: 93.2%, Avg loss: 0.234827
#
# Epoch 69
# -------------------------------
# Training Error:
#  Accuracy: 93.5%, Avg loss: 0.231584
#
# Test Error:
#  Accuracy: 93.3%, Avg loss: 0.231454
#
# Epoch 70
# -------------------------------
# Training Error:
#  Accuracy: 93.6%, Avg loss: 0.227952
#
# Test Error:
#  Accuracy: 93.4%, Avg loss: 0.228122
#
# Epoch 71
# -------------------------------
# Training Error:
#  Accuracy: 93.7%, Avg loss: 0.224397
#
# Test Error:
#  Accuracy: 93.4%, Avg loss: 0.224882
#
# Epoch 72
# -------------------------------
# Training Error:
#  Accuracy: 93.8%, Avg loss: 0.220915
#
# Test Error:
#  Accuracy: 93.6%, Avg loss: 0.221707
#
# Epoch 73
# -------------------------------
# Training Error:
#  Accuracy: 93.9%, Avg loss: 0.217508
#
# Test Error:
#  Accuracy: 93.7%, Avg loss: 0.218615
#
# Epoch 74
# -------------------------------
# Training Error:
#  Accuracy: 93.9%, Avg loss: 0.214167
#
# Test Error:
#  Accuracy: 93.7%, Avg loss: 0.215585
#
# Epoch 75
# -------------------------------
# Training Error:
#  Accuracy: 94.0%, Avg loss: 0.210907
#
# Test Error:
#  Accuracy: 93.8%, Avg loss: 0.212645
#
# Epoch 76
# -------------------------------
# Training Error:
#  Accuracy: 94.1%, Avg loss: 0.207722
#
# Test Error:
#  Accuracy: 93.9%, Avg loss: 0.209779
#
# Epoch 77
# -------------------------------
# Training Error:
#  Accuracy: 94.2%, Avg loss: 0.204606
#
# Test Error:
#  Accuracy: 94.0%, Avg loss: 0.206986
#
# Epoch 78
# -------------------------------
# Training Error:
#  Accuracy: 94.3%, Avg loss: 0.201556
#
# Test Error:
#  Accuracy: 94.0%, Avg loss: 0.204256
#
# Epoch 79
# -------------------------------
# Training Error:
#  Accuracy: 94.4%, Avg loss: 0.198565
#
# Test Error:
#  Accuracy: 94.1%, Avg loss: 0.201571
#
# Epoch 80
# -------------------------------
# Training Error:
#  Accuracy: 94.5%, Avg loss: 0.195634
#
# Test Error:
#  Accuracy: 94.2%, Avg loss: 0.198931
#
# Epoch 81
# -------------------------------
# Training Error:
#  Accuracy: 94.6%, Avg loss: 0.192768
#
# Test Error:
#  Accuracy: 94.2%, Avg loss: 0.196347
#
# Epoch 82
# -------------------------------
# Training Error:
#  Accuracy: 94.7%, Avg loss: 0.189970
#
# Test Error:
#  Accuracy: 94.4%, Avg loss: 0.193825
#
# Epoch 83
# -------------------------------
# Training Error:
#  Accuracy: 94.7%, Avg loss: 0.187225
#
# Test Error:
#  Accuracy: 94.5%, Avg loss: 0.191361
#
# Epoch 84
# -------------------------------
# Training Error:
#  Accuracy: 94.8%, Avg loss: 0.184542
#
# Test Error:
#  Accuracy: 94.6%, Avg loss: 0.188964
#
# Epoch 85
# -------------------------------
# Training Error:
#  Accuracy: 94.9%, Avg loss: 0.181925
#
# Test Error:
#  Accuracy: 94.7%, Avg loss: 0.186632
#
# Epoch 86
# -------------------------------
# Training Error:
#  Accuracy: 94.9%, Avg loss: 0.179370
#
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.184368
#
# Epoch 87
# -------------------------------
# Training Error:
#  Accuracy: 95.0%, Avg loss: 0.176876
#
# Test Error:
#  Accuracy: 94.9%, Avg loss: 0.182165
#
# Epoch 88
# -------------------------------
# Training Error:
#  Accuracy: 95.1%, Avg loss: 0.174444
#
# Test Error:
#  Accuracy: 94.9%, Avg loss: 0.180016
#
# Epoch 89
# -------------------------------
# Training Error:
#  Accuracy: 95.1%, Avg loss: 0.172068
#
# Test Error:
#  Accuracy: 94.9%, Avg loss: 0.177927
#
# Epoch 90
# -------------------------------
# Training Error:
#  Accuracy: 95.2%, Avg loss: 0.169752
#
# Test Error:
#  Accuracy: 95.0%, Avg loss: 0.175908
#
# Epoch 91
# -------------------------------
# Training Error:
#  Accuracy: 95.2%, Avg loss: 0.167484
#
# Test Error:
#  Accuracy: 95.1%, Avg loss: 0.173940
#
# Epoch 92
# -------------------------------
# Training Error:
#  Accuracy: 95.3%, Avg loss: 0.165269
#
# Test Error:
#  Accuracy: 95.1%, Avg loss: 0.172030
#
# Epoch 93
# -------------------------------
# Training Error:
#  Accuracy: 95.4%, Avg loss: 0.163100
#
# Test Error:
#  Accuracy: 95.2%, Avg loss: 0.170164
#
# Epoch 94
# -------------------------------
# Training Error:
#  Accuracy: 95.5%, Avg loss: 0.160981
#
# Test Error:
#  Accuracy: 95.2%, Avg loss: 0.168351
#
# Epoch 95
# -------------------------------
# Training Error:
#  Accuracy: 95.5%, Avg loss: 0.158900
#
# Test Error:
#  Accuracy: 95.2%, Avg loss: 0.166589
#
# Epoch 96
# -------------------------------
# Training Error:
#  Accuracy: 95.6%, Avg loss: 0.156864
#
# Test Error:
#  Accuracy: 95.2%, Avg loss: 0.164878
#
# Epoch 97
# -------------------------------
# Training Error:
#  Accuracy: 95.6%, Avg loss: 0.154875
#
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.163209
#
# Epoch 98
# -------------------------------
# Training Error:
#  Accuracy: 95.7%, Avg loss: 0.152921
#
# Test Error:
#  Accuracy: 95.4%, Avg loss: 0.161587
#
# Epoch 99
# -------------------------------
# Training Error:
#  Accuracy: 95.8%, Avg loss: 0.151014
#
# Test Error:
#  Accuracy: 95.5%, Avg loss: 0.160011
#
# Epoch 100
# -------------------------------
# Training Error:
#  Accuracy: 95.8%, Avg loss: 0.149142
#
# Test Error:
#  Accuracy: 95.5%, Avg loss: 0.158470
#
# Training b128
# Epoch 1
# -------------------------------
# Training Error:
#  Accuracy: 10.0%, Avg loss: 2.302071
#
# Test Error:
#  Accuracy: 10.0%, Avg loss: 2.302414
#
# Epoch 2
# -------------------------------
# Training Error:
#  Accuracy: 10.4%, Avg loss: 2.300943
#
# Test Error:
#  Accuracy: 10.3%, Avg loss: 2.301228
#
# Epoch 3
# -------------------------------
# Training Error:
#  Accuracy: 12.0%, Avg loss: 2.299809
#
# Test Error:
#  Accuracy: 11.5%, Avg loss: 2.300039
#
# Epoch 4
# -------------------------------
# Training Error:
#  Accuracy: 16.8%, Avg loss: 2.298658
#
# Test Error:
#  Accuracy: 16.3%, Avg loss: 2.298836
#
# Epoch 5
# -------------------------------
# Training Error:
#  Accuracy: 23.3%, Avg loss: 2.297482
#
# Test Error:
#  Accuracy: 22.9%, Avg loss: 2.297607
#
# Epoch 6
# -------------------------------
# Training Error:
#  Accuracy: 28.8%, Avg loss: 2.296263
#
# Test Error:
#  Accuracy: 28.8%, Avg loss: 2.296336
#
# Epoch 7
# -------------------------------
# Training Error:
#  Accuracy: 29.7%, Avg loss: 2.294979
#
# Test Error:
#  Accuracy: 29.7%, Avg loss: 2.295000
#
# Epoch 8
# -------------------------------
# Training Error:
#  Accuracy: 27.6%, Avg loss: 2.293602
#
# Test Error:
#  Accuracy: 27.9%, Avg loss: 2.293570
#
# Epoch 9
# -------------------------------
# Training Error:
#  Accuracy: 26.1%, Avg loss: 2.292103
#
# Test Error:
#  Accuracy: 26.4%, Avg loss: 2.292016
#
# Epoch 10
# -------------------------------
# Training Error:
#  Accuracy: 25.3%, Avg loss: 2.290450
#
# Test Error:
#  Accuracy: 25.5%, Avg loss: 2.290306
#
# Epoch 11
# -------------------------------
# Training Error:
#  Accuracy: 25.2%, Avg loss: 2.288607
#
# Test Error:
#  Accuracy: 25.3%, Avg loss: 2.288404
#
# Epoch 12
# -------------------------------
# Training Error:
#  Accuracy: 25.5%, Avg loss: 2.286530
#
# Test Error:
#  Accuracy: 25.7%, Avg loss: 2.286265
#
# Epoch 13
# -------------------------------
# Training Error:
#  Accuracy: 26.3%, Avg loss: 2.284160
#
# Test Error:
#  Accuracy: 26.5%, Avg loss: 2.283829
#
# Epoch 14
# -------------------------------
# Training Error:
#  Accuracy: 27.2%, Avg loss: 2.281423
#
# Test Error:
#  Accuracy: 27.3%, Avg loss: 2.281017
#
# Epoch 15
# -------------------------------
# Training Error:
#  Accuracy: 28.3%, Avg loss: 2.278220
#
# Test Error:
#  Accuracy: 28.5%, Avg loss: 2.277728
#
# Epoch 16
# -------------------------------
# Training Error:
#  Accuracy: 29.5%, Avg loss: 2.274424
#
# Test Error:
#  Accuracy: 29.9%, Avg loss: 2.273833
#
# Epoch 17
# -------------------------------
# Training Error:
#  Accuracy: 30.7%, Avg loss: 2.269881
#
# Test Error:
#  Accuracy: 31.2%, Avg loss: 2.269176
#
# Epoch 18
# -------------------------------
# Training Error:
#  Accuracy: 31.8%, Avg loss: 2.264403
#
# Test Error:
#  Accuracy: 31.9%, Avg loss: 2.263567
#
# Epoch 19
# -------------------------------
# Training Error:
#  Accuracy: 32.6%, Avg loss: 2.257730
#
# Test Error:
#  Accuracy: 33.1%, Avg loss: 2.256739
#
# Epoch 20
# -------------------------------
# Training Error:
#  Accuracy: 33.3%, Avg loss: 2.249479
#
# Test Error:
#  Accuracy: 33.9%, Avg loss: 2.248296
#
# Epoch 21
# -------------------------------
# Training Error:
#  Accuracy: 33.7%, Avg loss: 2.239102
#
# Test Error:
#  Accuracy: 34.3%, Avg loss: 2.237685
#
# Epoch 22
# -------------------------------
# Training Error:
#  Accuracy: 34.0%, Avg loss: 2.225819
#
# Test Error:
#  Accuracy: 34.6%, Avg loss: 2.224109
#
# Epoch 23
# -------------------------------
# Training Error:
#  Accuracy: 34.4%, Avg loss: 2.208495
#
# Test Error:
#  Accuracy: 35.0%, Avg loss: 2.206412
#
# Epoch 24
# -------------------------------
# Training Error:
#  Accuracy: 34.8%, Avg loss: 2.185538
#
# Test Error:
#  Accuracy: 35.4%, Avg loss: 2.182988
#
# Epoch 25
# -------------------------------
# Training Error:
#  Accuracy: 35.3%, Avg loss: 2.155069
#
# Test Error:
#  Accuracy: 35.9%, Avg loss: 2.151940
#
# Epoch 26
# -------------------------------
# Training Error:
#  Accuracy: 36.0%, Avg loss: 2.115220
#
# Test Error:
#  Accuracy: 36.6%, Avg loss: 2.111409
#
# Epoch 27
# -------------------------------
# Training Error:
#  Accuracy: 37.1%, Avg loss: 2.065111
#
# Test Error:
#  Accuracy: 37.9%, Avg loss: 2.060528
#
# Epoch 28
# -------------------------------
# Training Error:
#  Accuracy: 39.0%, Avg loss: 2.004891
#
# Test Error:
#  Accuracy: 39.9%, Avg loss: 1.999384
#
# Epoch 29
# -------------------------------
# Training Error:
#  Accuracy: 42.2%, Avg loss: 1.933826
#
# Test Error:
#  Accuracy: 42.8%, Avg loss: 1.927091
#
# Epoch 30
# -------------------------------
# Training Error:
#  Accuracy: 46.7%, Avg loss: 1.848874
#
# Test Error:
#  Accuracy: 47.5%, Avg loss: 1.840482
#
# Epoch 31
# -------------------------------
# Training Error:
#  Accuracy: 51.8%, Avg loss: 1.746854
#
# Test Error:
#  Accuracy: 52.5%, Avg loss: 1.736435
#
# Epoch 32
# -------------------------------
# Training Error:
#  Accuracy: 56.1%, Avg loss: 1.628305
#
# Test Error:
#  Accuracy: 56.4%, Avg loss: 1.615730
#
# Epoch 33
# -------------------------------
# Training Error:
#  Accuracy: 58.8%, Avg loss: 1.498247
#
# Test Error:
#  Accuracy: 59.1%, Avg loss: 1.483618
#
# Epoch 34
# -------------------------------
# Training Error:
#  Accuracy: 61.1%, Avg loss: 1.366549
#
# Test Error:
#  Accuracy: 61.4%, Avg loss: 1.350284
#
# Epoch 35
# -------------------------------
# Training Error:
#  Accuracy: 63.2%, Avg loss: 1.245621
#
# Test Error:
#  Accuracy: 63.7%, Avg loss: 1.228601
#
# Epoch 36
# -------------------------------
# Training Error:
#  Accuracy: 65.3%, Avg loss: 1.141281
#
# Test Error:
#  Accuracy: 65.8%, Avg loss: 1.124448
#
# Epoch 37
# -------------------------------
# Training Error:
#  Accuracy: 67.4%, Avg loss: 1.052869
#
# Test Error:
#  Accuracy: 67.7%, Avg loss: 1.036753
#
# Epoch 38
# -------------------------------
# Training Error:
#  Accuracy: 69.4%, Avg loss: 0.978433
#
# Test Error:
#  Accuracy: 69.5%, Avg loss: 0.963077
#
# Epoch 39
# -------------------------------
# Training Error:
#  Accuracy: 71.0%, Avg loss: 0.916222
#
# Test Error:
#  Accuracy: 71.5%, Avg loss: 0.901390
#
# Epoch 40
# -------------------------------
# Training Error:
#  Accuracy: 72.6%, Avg loss: 0.864272
#
# Test Error:
#  Accuracy: 73.0%, Avg loss: 0.849646
#
# Epoch 41
# -------------------------------
# Training Error:
#  Accuracy: 74.1%, Avg loss: 0.820656
#
# Test Error:
#  Accuracy: 74.5%, Avg loss: 0.805951
#
# Epoch 42
# -------------------------------
# Training Error:
#  Accuracy: 75.3%, Avg loss: 0.783701
#
# Test Error:
#  Accuracy: 75.9%, Avg loss: 0.768710
#
# Epoch 43
# -------------------------------
# Training Error:
#  Accuracy: 76.4%, Avg loss: 0.752085
#
# Test Error:
#  Accuracy: 77.0%, Avg loss: 0.736710
#
# Epoch 44
# -------------------------------
# Training Error:
#  Accuracy: 77.3%, Avg loss: 0.724840
#
# Test Error:
#  Accuracy: 78.2%, Avg loss: 0.709063
#
# Epoch 45
# -------------------------------
# Training Error:
#  Accuracy: 78.2%, Avg loss: 0.701152
#
# Test Error:
#  Accuracy: 79.1%, Avg loss: 0.685015
#
# Epoch 46
# -------------------------------
# Training Error:
#  Accuracy: 79.0%, Avg loss: 0.680345
#
# Test Error:
#  Accuracy: 79.7%, Avg loss: 0.663935
#
# Epoch 47
# -------------------------------
# Training Error:
#  Accuracy: 79.6%, Avg loss: 0.661853
#
# Test Error:
#  Accuracy: 80.4%, Avg loss: 0.645269
#
# Epoch 48
# -------------------------------
# Training Error:
#  Accuracy: 80.1%, Avg loss: 0.645223
#
# Test Error:
#  Accuracy: 80.9%, Avg loss: 0.628557
#
# Epoch 49
# -------------------------------
# Training Error:
#  Accuracy: 80.7%, Avg loss: 0.630076
#
# Test Error:
#  Accuracy: 81.5%, Avg loss: 0.613403
#
# Epoch 50
# -------------------------------
# Training Error:
#  Accuracy: 81.3%, Avg loss: 0.616120
#
# Test Error:
#  Accuracy: 82.0%, Avg loss: 0.599512
#
# Epoch 51
# -------------------------------
# Training Error:
#  Accuracy: 81.7%, Avg loss: 0.603121
#
# Test Error:
#  Accuracy: 82.3%, Avg loss: 0.586642
#
# Epoch 52
# -------------------------------
# Training Error:
#  Accuracy: 82.2%, Avg loss: 0.590893
#
# Test Error:
#  Accuracy: 82.8%, Avg loss: 0.574587
#
# Epoch 53
# -------------------------------
# Training Error:
#  Accuracy: 82.6%, Avg loss: 0.579296
#
# Test Error:
#  Accuracy: 83.2%, Avg loss: 0.563206
#
# Epoch 54
# -------------------------------
# Training Error:
#  Accuracy: 83.0%, Avg loss: 0.568218
#
# Test Error:
#  Accuracy: 83.6%, Avg loss: 0.552381
#
# Epoch 55
# -------------------------------
# Training Error:
#  Accuracy: 83.4%, Avg loss: 0.557581
#
# Test Error:
#  Accuracy: 84.0%, Avg loss: 0.542034
#
# Epoch 56
# -------------------------------
# Training Error:
#  Accuracy: 83.8%, Avg loss: 0.547319
#
# Test Error:
#  Accuracy: 84.3%, Avg loss: 0.532085
#
# Epoch 57
# -------------------------------
# Training Error:
#  Accuracy: 84.2%, Avg loss: 0.537398
#
# Test Error:
#  Accuracy: 84.7%, Avg loss: 0.522494
#
# Epoch 58
# -------------------------------
# Training Error:
#  Accuracy: 84.5%, Avg loss: 0.527780
#
# Test Error:
#  Accuracy: 84.9%, Avg loss: 0.513234
#
# Epoch 59
# -------------------------------
# Training Error:
#  Accuracy: 84.8%, Avg loss: 0.518438
#
# Test Error:
#  Accuracy: 85.1%, Avg loss: 0.504275
#
# Epoch 60
# -------------------------------
# Training Error:
#  Accuracy: 85.1%, Avg loss: 0.509363
#
# Test Error:
#  Accuracy: 85.4%, Avg loss: 0.495595
#
# Epoch 61
# -------------------------------
# Training Error:
#  Accuracy: 85.4%, Avg loss: 0.500548
#
# Test Error:
#  Accuracy: 85.8%, Avg loss: 0.487179
#
# Epoch 62
# -------------------------------
# Training Error:
#  Accuracy: 85.7%, Avg loss: 0.491983
#
# Test Error:
#  Accuracy: 86.0%, Avg loss: 0.479019
#
# Epoch 63
# -------------------------------
# Training Error:
#  Accuracy: 86.0%, Avg loss: 0.483666
#
# Test Error:
#  Accuracy: 86.2%, Avg loss: 0.471105
#
# Epoch 64
# -------------------------------
# Training Error:
#  Accuracy: 86.3%, Avg loss: 0.475608
#
# Test Error:
#  Accuracy: 86.4%, Avg loss: 0.463447
#
# Epoch 65
# -------------------------------
# Training Error:
#  Accuracy: 86.5%, Avg loss: 0.467807
#
# Test Error:
#  Accuracy: 86.7%, Avg loss: 0.456042
#
# Epoch 66
# -------------------------------
# Training Error:
#  Accuracy: 86.7%, Avg loss: 0.460249
#
# Test Error:
#  Accuracy: 86.8%, Avg loss: 0.448882
#
# Epoch 67
# -------------------------------
# Training Error:
#  Accuracy: 87.0%, Avg loss: 0.452933
#
# Test Error:
#  Accuracy: 87.0%, Avg loss: 0.441951
#
# Epoch 68
# -------------------------------
# Training Error:
#  Accuracy: 87.2%, Avg loss: 0.445856
#
# Test Error:
#  Accuracy: 87.1%, Avg loss: 0.435259
#
# Epoch 69
# -------------------------------
# Training Error:
#  Accuracy: 87.4%, Avg loss: 0.439015
#
# Test Error:
#  Accuracy: 87.4%, Avg loss: 0.428793
#
# Epoch 70
# -------------------------------
# Training Error:
#  Accuracy: 87.6%, Avg loss: 0.432404
#
# Test Error:
#  Accuracy: 87.6%, Avg loss: 0.422546
#
# Epoch 71
# -------------------------------
# Training Error:
#  Accuracy: 87.8%, Avg loss: 0.426019
#
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.416506
#
# Epoch 72
# -------------------------------
# Training Error:
#  Accuracy: 88.0%, Avg loss: 0.419842
#
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.410653
#
# Epoch 73
# -------------------------------
# Training Error:
#  Accuracy: 88.1%, Avg loss: 0.413866
#
# Test Error:
#  Accuracy: 88.2%, Avg loss: 0.404983
#
# Epoch 74
# -------------------------------
# Training Error:
#  Accuracy: 88.3%, Avg loss: 0.408080
#
# Test Error:
#  Accuracy: 88.3%, Avg loss: 0.399475
#
# Epoch 75
# -------------------------------
# Training Error:
#  Accuracy: 88.5%, Avg loss: 0.402485
#
# Test Error:
#  Accuracy: 88.6%, Avg loss: 0.394142
#
# Epoch 76
# -------------------------------
# Training Error:
#  Accuracy: 88.6%, Avg loss: 0.397065
#
# Test Error:
#  Accuracy: 88.7%, Avg loss: 0.388968
#
# Epoch 77
# -------------------------------
# Training Error:
#  Accuracy: 88.8%, Avg loss: 0.391813
#
# Test Error:
#  Accuracy: 88.8%, Avg loss: 0.383941
#
# Epoch 78
# -------------------------------
# Training Error:
#  Accuracy: 89.0%, Avg loss: 0.386712
#
# Test Error:
#  Accuracy: 89.0%, Avg loss: 0.379050
#
# Epoch 79
# -------------------------------
# Training Error:
#  Accuracy: 89.1%, Avg loss: 0.381783
#
# Test Error:
#  Accuracy: 89.1%, Avg loss: 0.374313
#
# Epoch 80
# -------------------------------
# Training Error:
#  Accuracy: 89.3%, Avg loss: 0.377014
#
# Test Error:
#  Accuracy: 89.3%, Avg loss: 0.369724
#
# Epoch 81
# -------------------------------
# Training Error:
#  Accuracy: 89.4%, Avg loss: 0.372396
#
# Test Error:
#  Accuracy: 89.4%, Avg loss: 0.365276
#
# Epoch 82
# -------------------------------
# Training Error:
#  Accuracy: 89.5%, Avg loss: 0.367925
#
# Test Error:
#  Accuracy: 89.5%, Avg loss: 0.360968
#
# Epoch 83
# -------------------------------
# Training Error:
#  Accuracy: 89.7%, Avg loss: 0.363592
#
# Test Error:
#  Accuracy: 89.6%, Avg loss: 0.356789
#
# Epoch 84
# -------------------------------
# Training Error:
#  Accuracy: 89.8%, Avg loss: 0.359395
#
# Test Error:
#  Accuracy: 89.7%, Avg loss: 0.352738
#
# Epoch 85
# -------------------------------
# Training Error:
#  Accuracy: 89.9%, Avg loss: 0.355330
#
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.348809
#
# Epoch 86
# -------------------------------
# Training Error:
#  Accuracy: 90.0%, Avg loss: 0.351390
#
# Test Error:
#  Accuracy: 89.9%, Avg loss: 0.344999
#
# Epoch 87
# -------------------------------
# Training Error:
#  Accuracy: 90.1%, Avg loss: 0.347567
#
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.341300
#
# Epoch 88
# -------------------------------
# Training Error:
#  Accuracy: 90.2%, Avg loss: 0.343856
#
# Test Error:
#  Accuracy: 90.2%, Avg loss: 0.337712
#
# Epoch 89
# -------------------------------
# Training Error:
#  Accuracy: 90.3%, Avg loss: 0.340255
#
# Test Error:
#  Accuracy: 90.2%, Avg loss: 0.334227
#
# Epoch 90
# -------------------------------
# Training Error:
#  Accuracy: 90.4%, Avg loss: 0.336759
#
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.330842
#
# Epoch 91
# -------------------------------
# Training Error:
#  Accuracy: 90.5%, Avg loss: 0.333361
#
# Test Error:
#  Accuracy: 90.4%, Avg loss: 0.327555
#
# Epoch 92
# -------------------------------
# Training Error:
#  Accuracy: 90.7%, Avg loss: 0.330052
#
# Test Error:
#  Accuracy: 90.5%, Avg loss: 0.324352
#
# Epoch 93
# -------------------------------
# Training Error:
#  Accuracy: 90.8%, Avg loss: 0.326833
#
# Test Error:
#  Accuracy: 90.6%, Avg loss: 0.321229
#
# Epoch 94
# -------------------------------
# Training Error:
#  Accuracy: 90.9%, Avg loss: 0.323697
#
# Test Error:
#  Accuracy: 90.7%, Avg loss: 0.318184
#
# Epoch 95
# -------------------------------
# Training Error:
#  Accuracy: 90.9%, Avg loss: 0.320635
#
# Test Error:
#  Accuracy: 90.8%, Avg loss: 0.315213
#
# Epoch 96
# -------------------------------
# Training Error:
#  Accuracy: 91.0%, Avg loss: 0.317644
#
# Test Error:
#  Accuracy: 90.8%, Avg loss: 0.312315
#
# Epoch 97
# -------------------------------
# Training Error:
#  Accuracy: 91.1%, Avg loss: 0.314719
#
# Test Error:
#  Accuracy: 90.9%, Avg loss: 0.309477
#
# Epoch 98
# -------------------------------
# Training Error:
#  Accuracy: 91.2%, Avg loss: 0.311856
#
# Test Error:
#  Accuracy: 91.0%, Avg loss: 0.306699
#
# Epoch 99
# -------------------------------
# Training Error:
#  Accuracy: 91.2%, Avg loss: 0.309052
#
# Test Error:
#  Accuracy: 91.1%, Avg loss: 0.303986
#
# Epoch 100
# -------------------------------
# Training Error:
#  Accuracy: 91.3%, Avg loss: 0.306302
#
# Test Error:
#  Accuracy: 91.2%, Avg loss: 0.301327

# %%
visualise_model_perf(models, title='Avg error vs Number of Epochs');

# %% [markdown]
# <hr>

# %% [markdown]
# ### Experiment 3: Changing the learning rate

# %%
models = train_models(load_config('learning.json'))
# Out:
# Training l-1
# Epoch 1
# -------------------------------
# Training Error:
#  Accuracy: 94.9%, Avg loss: 0.164407
#
# Test Error:
#  Accuracy: 94.9%, Avg loss: 0.165252
#
# Epoch 2
# -------------------------------
# Training Error:
#  Accuracy: 97.1%, Avg loss: 0.094749
#
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.118939
#
# Epoch 3
# -------------------------------
# Training Error:
#  Accuracy: 97.9%, Avg loss: 0.064547
#
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.095200
#
# Epoch 4
# -------------------------------
# Training Error:
#  Accuracy: 98.6%, Avg loss: 0.043212
#
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.081151
#
# Epoch 5
# -------------------------------
# Training Error:
#  Accuracy: 98.6%, Avg loss: 0.044958
#
# Test Error:
#  Accuracy: 97.4%, Avg loss: 0.093783
#
# Epoch 6
# -------------------------------
# Training Error:
#  Accuracy: 98.8%, Avg loss: 0.038781
#
# Test Error:
#  Accuracy: 97.4%, Avg loss: 0.098294
#
# Epoch 7
# -------------------------------
# Training Error:
#  Accuracy: 98.8%, Avg loss: 0.037438
#
# Test Error:
#  Accuracy: 97.4%, Avg loss: 0.101222
#
# Epoch 8
# -------------------------------
# Training Error:
#  Accuracy: 98.9%, Avg loss: 0.032758
#
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.103885
#
# Epoch 9
# -------------------------------
# Training Error:
#  Accuracy: 99.1%, Avg loss: 0.027265
#
# Test Error:
#  Accuracy: 97.4%, Avg loss: 0.103921
#
# Epoch 10
# -------------------------------
# Training Error:
#  Accuracy: 99.4%, Avg loss: 0.017162
#
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.082815
#
# Epoch 11
# -------------------------------
# Training Error:
#  Accuracy: 99.2%, Avg loss: 0.026546
#
# Test Error:
#  Accuracy: 97.5%, Avg loss: 0.112600
#
# Epoch 12
# -------------------------------
# Training Error:
#  Accuracy: 99.5%, Avg loss: 0.015910
#
# Test Error:
#  Accuracy: 98.0%, Avg loss: 0.083889
#
# Epoch 13
# -------------------------------
# Training Error:
#  Accuracy: 99.5%, Avg loss: 0.014259
#
# Test Error:
#  Accuracy: 98.0%, Avg loss: 0.095295
#
# Epoch 14
# -------------------------------
# Training Error:
#  Accuracy: 99.5%, Avg loss: 0.016658
#
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.100104
#
# Epoch 15
# -------------------------------
# Training Error:
#  Accuracy: 99.7%, Avg loss: 0.008490
#
# Test Error:
#  Accuracy: 98.1%, Avg loss: 0.087277
#
# Epoch 16
# -------------------------------
# Training Error:
#  Accuracy: 99.9%, Avg loss: 0.004627
#
# Test Error:
#  Accuracy: 98.3%, Avg loss: 0.081461
#
# Epoch 17
# -------------------------------
# Training Error:
#  Accuracy: 99.0%, Avg loss: 0.047379
#
# Test Error:
#  Accuracy: 97.4%, Avg loss: 0.132026
#
# Epoch 18
# -------------------------------
# Training Error:
#  Accuracy: 99.8%, Avg loss: 0.006405
#
# Test Error:
#  Accuracy: 98.3%, Avg loss: 0.087626
#
# Epoch 19
# -------------------------------
# Training Error:
#  Accuracy: 99.9%, Avg loss: 0.004400
#
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.077617
#
# Epoch 20
# -------------------------------
# Training Error:
#  Accuracy: 99.6%, Avg loss: 0.014109
#
# Test Error:
#  Accuracy: 98.1%, Avg loss: 0.098717
#
# Epoch 21
# -------------------------------
# Training Error:
#  Accuracy: 99.9%, Avg loss: 0.002858
#
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.085377
#
# Epoch 22
# -------------------------------
# Training Error:
#  Accuracy: 99.6%, Avg loss: 0.010111
#
# Test Error:
#  Accuracy: 98.0%, Avg loss: 0.106344
#
# Epoch 23
# -------------------------------
# Training Error:
#  Accuracy: 99.9%, Avg loss: 0.003740
#
# Test Error:
#  Accuracy: 98.2%, Avg loss: 0.088751
#
# Epoch 24
# -------------------------------
# Training Error:
#  Accuracy: 99.9%, Avg loss: 0.002017
#
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.088053
#
# Epoch 25
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000539
#
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.090870
#
# Epoch 26
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000223
#
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.085182
#
# Epoch 27
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000133
#
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.088845
#
# Epoch 28
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000097
#
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.088392
#
# Epoch 29
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000076
#
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.090470
#
# Epoch 30
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000065
#
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.090863
#
# Epoch 31
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000057
#
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.091868
#
# Epoch 32
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000050
#
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.092266
#
# Epoch 33
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000043
#
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.093385
#
# Epoch 34
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000037
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.093886
#
# Epoch 35
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000031
#
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.094714
#
# Epoch 36
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000025
#
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.095395
#
# Epoch 37
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000022
#
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.095951
#
# Epoch 38
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000019
#
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.096278
#
# Epoch 39
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000018
#
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.096678
#
# Epoch 40
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000016
#
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.097101
#
# Epoch 41
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000015
#
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.097494
#
# Epoch 42
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000014
#
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.097879
#
# Epoch 43
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000014
#
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.098222
#
# Epoch 44
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000013
#
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.098583
#
# Epoch 45
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000012
#
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.098926
#
# Epoch 46
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000012
#
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.099221
#
# Epoch 47
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000011
#
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.099530
#
# Epoch 48
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000011
#
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.099818
#
# Epoch 49
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000010
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.100093
#
# Epoch 50
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000010
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.100380
#
# Epoch 51
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000009
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.100625
#
# Epoch 52
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000009
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.100884
#
# Epoch 53
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000009
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.101122
#
# Epoch 54
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000009
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.101362
#
# Epoch 55
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000008
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.101590
#
# Epoch 56
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000008
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.101821
#
# Epoch 57
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000008
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.102040
#
# Epoch 58
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000008
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.102246
#
# Epoch 59
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000007
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.102458
#
# Epoch 60
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000007
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.102661
#
# Epoch 61
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000007
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.102854
#
# Epoch 62
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000007
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.103039
#
# Epoch 63
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000007
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.103233
#
# Epoch 64
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000006
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.103415
#
# Epoch 65
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000006
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.103586
#
# Epoch 66
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000006
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.103760
#
# Epoch 67
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000006
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.103933
#
# Epoch 68
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000006
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.104099
#
# Epoch 69
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000006
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.104255
#
# Epoch 70
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000006
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.104420
#
# Epoch 71
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000005
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.104568
#
# Epoch 72
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000005
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.104724
#
# Epoch 73
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000005
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.104876
#
# Epoch 74
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000005
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.105020
#
# Epoch 75
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000005
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.105162
#
# Epoch 76
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000005
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.105313
#
# Epoch 77
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000005
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.105453
#
# Epoch 78
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000005
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.105595
#
# Epoch 79
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000005
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.105730
#
# Epoch 80
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000005
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.105867
#
# Epoch 81
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000004
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.105997
#
# Epoch 82
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000004
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.106130
#
# Epoch 83
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000004
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.106259
#
# Epoch 84
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000004
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.106391
#
# Epoch 85
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000004
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.106507
#
# Epoch 86
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000004
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.106636
#
# Epoch 87
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000004
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.106755
#
# Epoch 88
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000004
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.106879
#
# Epoch 89
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000004
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.106989
#
# Epoch 90
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000004
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.107112
#
# Epoch 91
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000004
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.107224
#
# Epoch 92
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000004
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.107337
#
# Epoch 93
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000004
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.107450
#
# Epoch 94
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000004
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.107558
#
# Epoch 95
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000004
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.107669
#
# Epoch 96
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000004
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.107778
#
# Epoch 97
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000004
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.107880
#
# Epoch 98
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000003
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.107990
#
# Epoch 99
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000003
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.108089
#
# Epoch 100
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000003
#
# Test Error:
#  Accuracy: 98.6%, Avg loss: 0.108197
#
# Training l-2
# Epoch 1
# -------------------------------
# Training Error:
#  Accuracy: 70.8%, Avg loss: 0.902380
#
# Test Error:
#  Accuracy: 71.0%, Avg loss: 0.887632
#
# Epoch 2
# -------------------------------
# Training Error:
#  Accuracy: 88.1%, Avg loss: 0.393365
#
# Test Error:
#  Accuracy: 88.2%, Avg loss: 0.386369
#
# Epoch 3
# -------------------------------
# Training Error:
#  Accuracy: 91.5%, Avg loss: 0.282810
#
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.285051
#
# Epoch 4
# -------------------------------
# Training Error:
#  Accuracy: 93.5%, Avg loss: 0.215523
#
# Test Error:
#  Accuracy: 93.2%, Avg loss: 0.220795
#
# Epoch 5
# -------------------------------
# Training Error:
#  Accuracy: 94.9%, Avg loss: 0.168150
#
# Test Error:
#  Accuracy: 94.6%, Avg loss: 0.176356
#
# Epoch 6
# -------------------------------
# Training Error:
#  Accuracy: 95.9%, Avg loss: 0.135811
#
# Test Error:
#  Accuracy: 95.5%, Avg loss: 0.147644
#
# Epoch 7
# -------------------------------
# Training Error:
#  Accuracy: 96.6%, Avg loss: 0.114192
#
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.129866
#
# Epoch 8
# -------------------------------
# Training Error:
#  Accuracy: 97.1%, Avg loss: 0.097157
#
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.116628
#
# Epoch 9
# -------------------------------
# Training Error:
#  Accuracy: 97.5%, Avg loss: 0.083887
#
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.107432
#
# Epoch 10
# -------------------------------
# Training Error:
#  Accuracy: 97.8%, Avg loss: 0.073176
#
# Test Error:
#  Accuracy: 97.0%, Avg loss: 0.100571
#
# Epoch 11
# -------------------------------
# Training Error:
#  Accuracy: 98.1%, Avg loss: 0.063893
#
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.095377
#
# Epoch 12
# -------------------------------
# Training Error:
#  Accuracy: 98.4%, Avg loss: 0.055380
#
# Test Error:
#  Accuracy: 97.3%, Avg loss: 0.090382
#
# Epoch 13
# -------------------------------
# Training Error:
#  Accuracy: 98.6%, Avg loss: 0.048818
#
# Test Error:
#  Accuracy: 97.5%, Avg loss: 0.087445
#
# Epoch 14
# -------------------------------
# Training Error:
#  Accuracy: 98.7%, Avg loss: 0.043830
#
# Test Error:
#  Accuracy: 97.5%, Avg loss: 0.086362
#
# Epoch 15
# -------------------------------
# Training Error:
#  Accuracy: 98.8%, Avg loss: 0.039655
#
# Test Error:
#  Accuracy: 97.5%, Avg loss: 0.086302
#
# Epoch 16
# -------------------------------
# Training Error:
#  Accuracy: 99.0%, Avg loss: 0.036113
#
# Test Error:
#  Accuracy: 97.5%, Avg loss: 0.086874
#
# Epoch 17
# -------------------------------
# Training Error:
#  Accuracy: 99.0%, Avg loss: 0.032907
#
# Test Error:
#  Accuracy: 97.5%, Avg loss: 0.087811
#
# Epoch 18
# -------------------------------
# Training Error:
#  Accuracy: 99.1%, Avg loss: 0.029624
#
# Test Error:
#  Accuracy: 97.5%, Avg loss: 0.088472
#
# Epoch 19
# -------------------------------
# Training Error:
#  Accuracy: 99.2%, Avg loss: 0.026382
#
# Test Error:
#  Accuracy: 97.5%, Avg loss: 0.089290
#
# Epoch 20
# -------------------------------
# Training Error:
#  Accuracy: 99.3%, Avg loss: 0.023368
#
# Test Error:
#  Accuracy: 97.5%, Avg loss: 0.090155
#
# Epoch 21
# -------------------------------
# Training Error:
#  Accuracy: 99.4%, Avg loss: 0.020887
#
# Test Error:
#  Accuracy: 97.5%, Avg loss: 0.091434
#
# Epoch 22
# -------------------------------
# Training Error:
#  Accuracy: 99.5%, Avg loss: 0.017504
#
# Test Error:
#  Accuracy: 97.5%, Avg loss: 0.090095
#
# Epoch 23
# -------------------------------
# Training Error:
#  Accuracy: 99.6%, Avg loss: 0.015412
#
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.091188
#
# Epoch 24
# -------------------------------
# Training Error:
#  Accuracy: 99.6%, Avg loss: 0.014608
#
# Test Error:
#  Accuracy: 97.5%, Avg loss: 0.094310
#
# Epoch 25
# -------------------------------
# Training Error:
#  Accuracy: 99.6%, Avg loss: 0.014844
#
# Test Error:
#  Accuracy: 97.5%, Avg loss: 0.098307
#
# Epoch 26
# -------------------------------
# Training Error:
#  Accuracy: 99.6%, Avg loss: 0.013971
#
# Test Error:
#  Accuracy: 97.5%, Avg loss: 0.100812
#
# Epoch 27
# -------------------------------
# Training Error:
#  Accuracy: 99.6%, Avg loss: 0.014642
#
# Test Error:
#  Accuracy: 97.5%, Avg loss: 0.104659
#
# Epoch 28
# -------------------------------
# Training Error:
#  Accuracy: 99.5%, Avg loss: 0.016027
#
# Test Error:
#  Accuracy: 97.4%, Avg loss: 0.110604
#
# Epoch 29
# -------------------------------
# Training Error:
#  Accuracy: 99.5%, Avg loss: 0.016987
#
# Test Error:
#  Accuracy: 97.3%, Avg loss: 0.115702
#
# Epoch 30
# -------------------------------
# Training Error:
#  Accuracy: 99.3%, Avg loss: 0.019738
#
# Test Error:
#  Accuracy: 97.3%, Avg loss: 0.122299
#
# Epoch 31
# -------------------------------
# Training Error:
#  Accuracy: 99.5%, Avg loss: 0.014673
#
# Test Error:
#  Accuracy: 97.4%, Avg loss: 0.115820
#
# Epoch 32
# -------------------------------
# Training Error:
#  Accuracy: 99.9%, Avg loss: 0.005112
#
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.097676
#
# Epoch 33
# -------------------------------
# Training Error:
#  Accuracy: 99.9%, Avg loss: 0.004008
#
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.096710
#
# Epoch 34
# -------------------------------
# Training Error:
#  Accuracy: 99.9%, Avg loss: 0.003472
#
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.097126
#
# Epoch 35
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.003052
#
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.097769
#
# Epoch 36
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.002765
#
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.098564
#
# Epoch 37
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.002473
#
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.099266
#
# Epoch 38
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.002261
#
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.100032
#
# Epoch 39
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.002039
#
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.100640
#
# Epoch 40
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.001867
#
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.101281
#
# Epoch 41
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.001713
#
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.101924
#
# Epoch 42
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.001574
#
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.102550
#
# Epoch 43
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.001454
#
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.103177
#
# Epoch 44
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.001345
#
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.103747
#
# Epoch 45
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.001252
#
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.104387
#
# Epoch 46
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.001163
#
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.104895
#
# Epoch 47
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.001087
#
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.105488
#
# Epoch 48
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.001013
#
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.105959
#
# Epoch 49
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000948
#
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.106508
#
# Epoch 50
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000892
#
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.107000
#
# Epoch 51
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000838
#
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.107476
#
# Epoch 52
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000790
#
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.107956
#
# Epoch 53
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000744
#
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.108403
#
# Epoch 54
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000707
#
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.108880
#
# Epoch 55
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000667
#
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.109284
#
# Epoch 56
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000635
#
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.109714
#
# Epoch 57
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000603
#
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.110133
#
# Epoch 58
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000574
#
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.110516
#
# Epoch 59
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000547
#
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.110906
#
# Epoch 60
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000522
#
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.111253
#
# Epoch 61
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000498
#
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.111622
#
# Epoch 62
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000477
#
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.111972
#
# Epoch 63
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000457
#
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.112313
#
# Epoch 64
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000439
#
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.112656
#
# Epoch 65
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000422
#
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.113006
#
# Epoch 66
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000405
#
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.113311
#
# Epoch 67
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000391
#
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.113636
#
# Epoch 68
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000376
#
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.113936
#
# Epoch 69
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000363
#
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.114260
#
# Epoch 70
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000351
#
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.114548
#
# Epoch 71
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000339
#
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.114847
#
# Epoch 72
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000327
#
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.115138
#
# Epoch 73
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000318
#
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.115424
#
# Epoch 74
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000307
#
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.115691
#
# Epoch 75
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000298
#
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.115991
#
# Epoch 76
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000289
#
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.116243
#
# Epoch 77
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000281
#
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.116492
#
# Epoch 78
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000273
#
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.116755
#
# Epoch 79
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000265
#
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.117016
#
# Epoch 80
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000258
#
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.117257
#
# Epoch 81
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000251
#
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.117496
#
# Epoch 82
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000245
#
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.117746
#
# Epoch 83
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000238
#
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.117975
#
# Epoch 84
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000232
#
# Test Error:
#  Accuracy: 97.8%, Avg loss: 0.118211
#
# Epoch 85
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000227
#
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.118458
#
# Epoch 86
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000221
#
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.118679
#
# Epoch 87
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000216
#
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.118891
#
# Epoch 88
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000211
#
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.119123
#
# Epoch 89
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000206
#
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.119335
#
# Epoch 90
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000201
#
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.119549
#
# Epoch 91
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000197
#
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.119761
#
# Epoch 92
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000193
#
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.119967
#
# Epoch 93
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000189
#
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.120180
#
# Epoch 94
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000185
#
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.120384
#
# Epoch 95
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000181
#
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.120587
#
# Epoch 96
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000178
#
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.120797
#
# Epoch 97
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000174
#
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.120976
#
# Epoch 98
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000171
#
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.121177
#
# Epoch 99
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000167
#
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.121380
#
# Epoch 100
# -------------------------------
# Training Error:
#  Accuracy: 100.0%, Avg loss: 0.000164
#
# Test Error:
#  Accuracy: 97.9%, Avg loss: 0.121557
#
# Training l-3
# Epoch 1
# -------------------------------
# Training Error:
#  Accuracy: 18.2%, Avg loss: 2.298600
#
# Test Error:
#  Accuracy: 17.8%, Avg loss: 2.298556
#
# Epoch 2
# -------------------------------
# Training Error:
#  Accuracy: 14.2%, Avg loss: 2.293950
#
# Test Error:
#  Accuracy: 14.3%, Avg loss: 2.293799
#
# Epoch 3
# -------------------------------
# Training Error:
#  Accuracy: 16.3%, Avg loss: 2.287601
#
# Test Error:
#  Accuracy: 16.7%, Avg loss: 2.287324
#
# Epoch 4
# -------------------------------
# Training Error:
#  Accuracy: 28.1%, Avg loss: 2.277831
#
# Test Error:
#  Accuracy: 29.2%, Avg loss: 2.277390
#
# Epoch 5
# -------------------------------
# Training Error:
#  Accuracy: 37.6%, Avg loss: 2.260233
#
# Test Error:
#  Accuracy: 37.9%, Avg loss: 2.259534
#
# Epoch 6
# -------------------------------
# Training Error:
#  Accuracy: 38.3%, Avg loss: 2.222116
#
# Test Error:
#  Accuracy: 38.0%, Avg loss: 2.220922
#
# Epoch 7
# -------------------------------
# Training Error:
#  Accuracy: 39.0%, Avg loss: 2.122288
#
# Test Error:
#  Accuracy: 38.9%, Avg loss: 2.120007
#
# Epoch 8
# -------------------------------
# Training Error:
#  Accuracy: 53.3%, Avg loss: 1.875587
#
# Test Error:
#  Accuracy: 54.9%, Avg loss: 1.869430
#
# Epoch 9
# -------------------------------
# Training Error:
#  Accuracy: 68.0%, Avg loss: 1.281749
#
# Test Error:
#  Accuracy: 68.5%, Avg loss: 1.266185
#
# Epoch 10
# -------------------------------
# Training Error:
#  Accuracy: 76.5%, Avg loss: 0.824266
#
# Test Error:
#  Accuracy: 77.1%, Avg loss: 0.808781
#
# Epoch 11
# -------------------------------
# Training Error:
#  Accuracy: 80.2%, Avg loss: 0.667948
#
# Test Error:
#  Accuracy: 80.8%, Avg loss: 0.653166
#
# Epoch 12
# -------------------------------
# Training Error:
#  Accuracy: 82.9%, Avg loss: 0.581062
#
# Test Error:
#  Accuracy: 83.3%, Avg loss: 0.566060
#
# Epoch 13
# -------------------------------
# Training Error:
#  Accuracy: 84.6%, Avg loss: 0.523577
#
# Test Error:
#  Accuracy: 84.9%, Avg loss: 0.508775
#
# Epoch 14
# -------------------------------
# Training Error:
#  Accuracy: 85.8%, Avg loss: 0.485931
#
# Test Error:
#  Accuracy: 85.8%, Avg loss: 0.472114
#
# Epoch 15
# -------------------------------
# Training Error:
#  Accuracy: 86.6%, Avg loss: 0.459098
#
# Test Error:
#  Accuracy: 86.5%, Avg loss: 0.446676
#
# Epoch 16
# -------------------------------
# Training Error:
#  Accuracy: 87.2%, Avg loss: 0.437730
#
# Test Error:
#  Accuracy: 87.1%, Avg loss: 0.426766
#
# Epoch 17
# -------------------------------
# Training Error:
#  Accuracy: 87.8%, Avg loss: 0.419452
#
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.409825
#
# Epoch 18
# -------------------------------
# Training Error:
#  Accuracy: 88.3%, Avg loss: 0.403193
#
# Test Error:
#  Accuracy: 88.1%, Avg loss: 0.394703
#
# Epoch 19
# -------------------------------
# Training Error:
#  Accuracy: 88.7%, Avg loss: 0.388248
#
# Test Error:
#  Accuracy: 88.6%, Avg loss: 0.380725
#
# Epoch 20
# -------------------------------
# Training Error:
#  Accuracy: 89.2%, Avg loss: 0.374305
#
# Test Error:
#  Accuracy: 89.2%, Avg loss: 0.367548
#
# Epoch 21
# -------------------------------
# Training Error:
#  Accuracy: 89.6%, Avg loss: 0.361118
#
# Test Error:
#  Accuracy: 89.7%, Avg loss: 0.354963
#
# Epoch 22
# -------------------------------
# Training Error:
#  Accuracy: 89.9%, Avg loss: 0.348595
#
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.342905
#
# Epoch 23
# -------------------------------
# Training Error:
#  Accuracy: 90.3%, Avg loss: 0.336590
#
# Test Error:
#  Accuracy: 90.2%, Avg loss: 0.331328
#
# Epoch 24
# -------------------------------
# Training Error:
#  Accuracy: 90.6%, Avg loss: 0.325124
#
# Test Error:
#  Accuracy: 90.5%, Avg loss: 0.320221
#
# Epoch 25
# -------------------------------
# Training Error:
#  Accuracy: 91.0%, Avg loss: 0.314167
#
# Test Error:
#  Accuracy: 90.7%, Avg loss: 0.309499
#
# Epoch 26
# -------------------------------
# Training Error:
#  Accuracy: 91.3%, Avg loss: 0.303696
#
# Test Error:
#  Accuracy: 91.0%, Avg loss: 0.299177
#
# Epoch 27
# -------------------------------
# Training Error:
#  Accuracy: 91.5%, Avg loss: 0.293653
#
# Test Error:
#  Accuracy: 91.3%, Avg loss: 0.289260
#
# Epoch 28
# -------------------------------
# Training Error:
#  Accuracy: 91.8%, Avg loss: 0.284034
#
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.279749
#
# Epoch 29
# -------------------------------
# Training Error:
#  Accuracy: 92.0%, Avg loss: 0.274800
#
# Test Error:
#  Accuracy: 91.9%, Avg loss: 0.270638
#
# Epoch 30
# -------------------------------
# Training Error:
#  Accuracy: 92.3%, Avg loss: 0.265966
#
# Test Error:
#  Accuracy: 92.3%, Avg loss: 0.261952
#
# Epoch 31
# -------------------------------
# Training Error:
#  Accuracy: 92.6%, Avg loss: 0.257487
#
# Test Error:
#  Accuracy: 92.6%, Avg loss: 0.253657
#
# Epoch 32
# -------------------------------
# Training Error:
#  Accuracy: 92.8%, Avg loss: 0.249337
#
# Test Error:
#  Accuracy: 92.8%, Avg loss: 0.245713
#
# Epoch 33
# -------------------------------
# Training Error:
#  Accuracy: 93.0%, Avg loss: 0.241537
#
# Test Error:
#  Accuracy: 93.1%, Avg loss: 0.238172
#
# Epoch 34
# -------------------------------
# Training Error:
#  Accuracy: 93.2%, Avg loss: 0.234042
#
# Test Error:
#  Accuracy: 93.3%, Avg loss: 0.230967
#
# Epoch 35
# -------------------------------
# Training Error:
#  Accuracy: 93.4%, Avg loss: 0.226822
#
# Test Error:
#  Accuracy: 93.5%, Avg loss: 0.224045
#
# Epoch 36
# -------------------------------
# Training Error:
#  Accuracy: 93.7%, Avg loss: 0.219949
#
# Test Error:
#  Accuracy: 93.7%, Avg loss: 0.217491
#
# Epoch 37
# -------------------------------
# Training Error:
#  Accuracy: 93.9%, Avg loss: 0.213434
#
# Test Error:
#  Accuracy: 93.8%, Avg loss: 0.211360
#
# Epoch 38
# -------------------------------
# Training Error:
#  Accuracy: 94.0%, Avg loss: 0.207170
#
# Test Error:
#  Accuracy: 94.1%, Avg loss: 0.205513
#
# Epoch 39
# -------------------------------
# Training Error:
#  Accuracy: 94.1%, Avg loss: 0.201183
#
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.199956
#
# Epoch 40
# -------------------------------
# Training Error:
#  Accuracy: 94.3%, Avg loss: 0.195481
#
# Test Error:
#  Accuracy: 94.4%, Avg loss: 0.194736
#
# Epoch 41
# -------------------------------
# Training Error:
#  Accuracy: 94.5%, Avg loss: 0.190018
#
# Test Error:
#  Accuracy: 94.5%, Avg loss: 0.189779
#
# Epoch 42
# -------------------------------
# Training Error:
#  Accuracy: 94.6%, Avg loss: 0.184760
#
# Test Error:
#  Accuracy: 94.6%, Avg loss: 0.185062
#
# Epoch 43
# -------------------------------
# Training Error:
#  Accuracy: 94.8%, Avg loss: 0.179732
#
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.180620
#
# Epoch 44
# -------------------------------
# Training Error:
#  Accuracy: 94.9%, Avg loss: 0.174914
#
# Test Error:
#  Accuracy: 94.9%, Avg loss: 0.176381
#
# Epoch 45
# -------------------------------
# Training Error:
#  Accuracy: 95.0%, Avg loss: 0.170309
#
# Test Error:
#  Accuracy: 95.0%, Avg loss: 0.172375
#
# Epoch 46
# -------------------------------
# Training Error:
#  Accuracy: 95.2%, Avg loss: 0.165902
#
# Test Error:
#  Accuracy: 95.2%, Avg loss: 0.168555
#
# Epoch 47
# -------------------------------
# Training Error:
#  Accuracy: 95.3%, Avg loss: 0.161699
#
# Test Error:
#  Accuracy: 95.2%, Avg loss: 0.164926
#
# Epoch 48
# -------------------------------
# Training Error:
#  Accuracy: 95.4%, Avg loss: 0.157648
#
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.161493
#
# Epoch 49
# -------------------------------
# Training Error:
#  Accuracy: 95.5%, Avg loss: 0.153745
#
# Test Error:
#  Accuracy: 95.4%, Avg loss: 0.158221
#
# Epoch 50
# -------------------------------
# Training Error:
#  Accuracy: 95.7%, Avg loss: 0.150003
#
# Test Error:
#  Accuracy: 95.5%, Avg loss: 0.155142
#
# Epoch 51
# -------------------------------
# Training Error:
#  Accuracy: 95.8%, Avg loss: 0.146403
#
# Test Error:
#  Accuracy: 95.6%, Avg loss: 0.152209
#
# Epoch 52
# -------------------------------
# Training Error:
#  Accuracy: 95.9%, Avg loss: 0.142903
#
# Test Error:
#  Accuracy: 95.7%, Avg loss: 0.149379
#
# Epoch 53
# -------------------------------
# Training Error:
#  Accuracy: 96.0%, Avg loss: 0.139558
#
# Test Error:
#  Accuracy: 95.8%, Avg loss: 0.146723
#
# Epoch 54
# -------------------------------
# Training Error:
#  Accuracy: 96.1%, Avg loss: 0.136304
#
# Test Error:
#  Accuracy: 95.8%, Avg loss: 0.144163
#
# Epoch 55
# -------------------------------
# Training Error:
#  Accuracy: 96.2%, Avg loss: 0.133134
#
# Test Error:
#  Accuracy: 95.9%, Avg loss: 0.141689
#
# Epoch 56
# -------------------------------
# Training Error:
#  Accuracy: 96.3%, Avg loss: 0.130105
#
# Test Error:
#  Accuracy: 95.9%, Avg loss: 0.139358
#
# Epoch 57
# -------------------------------
# Training Error:
#  Accuracy: 96.3%, Avg loss: 0.127160
#
# Test Error:
#  Accuracy: 95.9%, Avg loss: 0.137144
#
# Epoch 58
# -------------------------------
# Training Error:
#  Accuracy: 96.4%, Avg loss: 0.124309
#
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.135014
#
# Epoch 59
# -------------------------------
# Training Error:
#  Accuracy: 96.5%, Avg loss: 0.121551
#
# Test Error:
#  Accuracy: 95.9%, Avg loss: 0.132992
#
# Epoch 60
# -------------------------------
# Training Error:
#  Accuracy: 96.6%, Avg loss: 0.118868
#
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.131028
#
# Epoch 61
# -------------------------------
# Training Error:
#  Accuracy: 96.7%, Avg loss: 0.116274
#
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.129159
#
# Epoch 62
# -------------------------------
# Training Error:
#  Accuracy: 96.7%, Avg loss: 0.113769
#
# Test Error:
#  Accuracy: 96.1%, Avg loss: 0.127370
#
# Epoch 63
# -------------------------------
# Training Error:
#  Accuracy: 96.8%, Avg loss: 0.111342
#
# Test Error:
#  Accuracy: 96.2%, Avg loss: 0.125674
#
# Epoch 64
# -------------------------------
# Training Error:
#  Accuracy: 96.9%, Avg loss: 0.108992
#
# Test Error:
#  Accuracy: 96.2%, Avg loss: 0.124055
#
# Epoch 65
# -------------------------------
# Training Error:
#  Accuracy: 97.0%, Avg loss: 0.106706
#
# Test Error:
#  Accuracy: 96.3%, Avg loss: 0.122480
#
# Epoch 66
# -------------------------------
# Training Error:
#  Accuracy: 97.0%, Avg loss: 0.104491
#
# Test Error:
#  Accuracy: 96.3%, Avg loss: 0.120979
#
# Epoch 67
# -------------------------------
# Training Error:
#  Accuracy: 97.1%, Avg loss: 0.102333
#
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.119558
#
# Epoch 68
# -------------------------------
# Training Error:
#  Accuracy: 97.1%, Avg loss: 0.100233
#
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.118162
#
# Epoch 69
# -------------------------------
# Training Error:
#  Accuracy: 97.2%, Avg loss: 0.098191
#
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.116842
#
# Epoch 70
# -------------------------------
# Training Error:
#  Accuracy: 97.2%, Avg loss: 0.096191
#
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.115554
#
# Epoch 71
# -------------------------------
# Training Error:
#  Accuracy: 97.3%, Avg loss: 0.094259
#
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.114336
#
# Epoch 72
# -------------------------------
# Training Error:
#  Accuracy: 97.4%, Avg loss: 0.092367
#
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.113159
#
# Epoch 73
# -------------------------------
# Training Error:
#  Accuracy: 97.4%, Avg loss: 0.090539
#
# Test Error:
#  Accuracy: 96.6%, Avg loss: 0.112010
#
# Epoch 74
# -------------------------------
# Training Error:
#  Accuracy: 97.5%, Avg loss: 0.088749
#
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.110909
#
# Epoch 75
# -------------------------------
# Training Error:
#  Accuracy: 97.5%, Avg loss: 0.087010
#
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.109854
#
# Epoch 76
# -------------------------------
# Training Error:
#  Accuracy: 97.6%, Avg loss: 0.085316
#
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.108837
#
# Epoch 77
# -------------------------------
# Training Error:
#  Accuracy: 97.6%, Avg loss: 0.083662
#
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.107885
#
# Epoch 78
# -------------------------------
# Training Error:
#  Accuracy: 97.7%, Avg loss: 0.082032
#
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.106931
#
# Epoch 79
# -------------------------------
# Training Error:
#  Accuracy: 97.7%, Avg loss: 0.080460
#
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.106035
#
# Epoch 80
# -------------------------------
# Training Error:
#  Accuracy: 97.8%, Avg loss: 0.078917
#
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.105164
#
# Epoch 81
# -------------------------------
# Training Error:
#  Accuracy: 97.8%, Avg loss: 0.077408
#
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.104323
#
# Epoch 82
# -------------------------------
# Training Error:
#  Accuracy: 97.9%, Avg loss: 0.075931
#
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.103502
#
# Epoch 83
# -------------------------------
# Training Error:
#  Accuracy: 97.9%, Avg loss: 0.074475
#
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.102668
#
# Epoch 84
# -------------------------------
# Training Error:
#  Accuracy: 98.0%, Avg loss: 0.073056
#
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.101880
#
# Epoch 85
# -------------------------------
# Training Error:
#  Accuracy: 98.0%, Avg loss: 0.071657
#
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.101092
#
# Epoch 86
# -------------------------------
# Training Error:
#  Accuracy: 98.0%, Avg loss: 0.070299
#
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.100343
#
# Epoch 87
# -------------------------------
# Training Error:
#  Accuracy: 98.1%, Avg loss: 0.068967
#
# Test Error:
#  Accuracy: 97.0%, Avg loss: 0.099629
#
# Epoch 88
# -------------------------------
# Training Error:
#  Accuracy: 98.1%, Avg loss: 0.067657
#
# Test Error:
#  Accuracy: 97.0%, Avg loss: 0.098911
#
# Epoch 89
# -------------------------------
# Training Error:
#  Accuracy: 98.2%, Avg loss: 0.066377
#
# Test Error:
#  Accuracy: 97.0%, Avg loss: 0.098220
#
# Epoch 90
# -------------------------------
# Training Error:
#  Accuracy: 98.2%, Avg loss: 0.065121
#
# Test Error:
#  Accuracy: 97.1%, Avg loss: 0.097588
#
# Epoch 91
# -------------------------------
# Training Error:
#  Accuracy: 98.3%, Avg loss: 0.063887
#
# Test Error:
#  Accuracy: 97.1%, Avg loss: 0.096949
#
# Epoch 92
# -------------------------------
# Training Error:
#  Accuracy: 98.3%, Avg loss: 0.062689
#
# Test Error:
#  Accuracy: 97.1%, Avg loss: 0.096358
#
# Epoch 93
# -------------------------------
# Training Error:
#  Accuracy: 98.3%, Avg loss: 0.061503
#
# Test Error:
#  Accuracy: 97.1%, Avg loss: 0.095778
#
# Epoch 94
# -------------------------------
# Training Error:
#  Accuracy: 98.4%, Avg loss: 0.060338
#
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.095185
#
# Epoch 95
# -------------------------------
# Training Error:
#  Accuracy: 98.4%, Avg loss: 0.059190
#
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.094649
#
# Epoch 96
# -------------------------------
# Training Error:
#  Accuracy: 98.4%, Avg loss: 0.058062
#
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.094118
#
# Epoch 97
# -------------------------------
# Training Error:
#  Accuracy: 98.5%, Avg loss: 0.056981
#
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.093643
#
# Epoch 98
# -------------------------------
# Training Error:
#  Accuracy: 98.5%, Avg loss: 0.055905
#
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.093140
#
# Epoch 99
# -------------------------------
# Training Error:
#  Accuracy: 98.5%, Avg loss: 0.054866
#
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.092687
#
# Epoch 100
# -------------------------------
# Training Error:
#  Accuracy: 98.6%, Avg loss: 0.053835
#
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.092249
#
# Training l-4
# Epoch 1
# -------------------------------
# Training Error:
#  Accuracy: 12.8%, Avg loss: 2.302204
#
# Test Error:
#  Accuracy: 13.2%, Avg loss: 2.302464
#
# Epoch 2
# -------------------------------
# Training Error:
#  Accuracy: 14.9%, Avg loss: 2.301818
#
# Test Error:
#  Accuracy: 15.4%, Avg loss: 2.302060
#
# Epoch 3
# -------------------------------
# Training Error:
#  Accuracy: 16.0%, Avg loss: 2.301435
#
# Test Error:
#  Accuracy: 16.9%, Avg loss: 2.301661
#
# Epoch 4
# -------------------------------
# Training Error:
#  Accuracy: 16.1%, Avg loss: 2.301056
#
# Test Error:
#  Accuracy: 16.8%, Avg loss: 2.301265
#
# Epoch 5
# -------------------------------
# Training Error:
#  Accuracy: 15.8%, Avg loss: 2.300679
#
# Test Error:
#  Accuracy: 16.3%, Avg loss: 2.300872
#
# Epoch 6
# -------------------------------
# Training Error:
#  Accuracy: 15.4%, Avg loss: 2.300305
#
# Test Error:
#  Accuracy: 15.7%, Avg loss: 2.300481
#
# Epoch 7
# -------------------------------
# Training Error:
#  Accuracy: 15.1%, Avg loss: 2.299931
#
# Test Error:
#  Accuracy: 15.3%, Avg loss: 2.300091
#
# Epoch 8
# -------------------------------
# Training Error:
#  Accuracy: 15.0%, Avg loss: 2.299559
#
# Test Error:
#  Accuracy: 15.0%, Avg loss: 2.299702
#
# Epoch 9
# -------------------------------
# Training Error:
#  Accuracy: 14.8%, Avg loss: 2.299186
#
# Test Error:
#  Accuracy: 14.8%, Avg loss: 2.299314
#
# Epoch 10
# -------------------------------
# Training Error:
#  Accuracy: 14.8%, Avg loss: 2.298812
#
# Test Error:
#  Accuracy: 14.8%, Avg loss: 2.298924
#
# Epoch 11
# -------------------------------
# Training Error:
#  Accuracy: 14.8%, Avg loss: 2.298437
#
# Test Error:
#  Accuracy: 14.7%, Avg loss: 2.298532
#
# Epoch 12
# -------------------------------
# Training Error:
#  Accuracy: 14.9%, Avg loss: 2.298058
#
# Test Error:
#  Accuracy: 14.8%, Avg loss: 2.298138
#
# Epoch 13
# -------------------------------
# Training Error:
#  Accuracy: 15.0%, Avg loss: 2.297675
#
# Test Error:
#  Accuracy: 14.9%, Avg loss: 2.297740
#
# Epoch 14
# -------------------------------
# Training Error:
#  Accuracy: 15.2%, Avg loss: 2.297289
#
# Test Error:
#  Accuracy: 15.1%, Avg loss: 2.297337
#
# Epoch 15
# -------------------------------
# Training Error:
#  Accuracy: 15.9%, Avg loss: 2.296896
#
# Test Error:
#  Accuracy: 15.6%, Avg loss: 2.296929
#
# Epoch 16
# -------------------------------
# Training Error:
#  Accuracy: 17.8%, Avg loss: 2.296498
#
# Test Error:
#  Accuracy: 17.4%, Avg loss: 2.296516
#
# Epoch 17
# -------------------------------
# Training Error:
#  Accuracy: 20.1%, Avg loss: 2.296093
#
# Test Error:
#  Accuracy: 19.7%, Avg loss: 2.296095
#
# Epoch 18
# -------------------------------
# Training Error:
#  Accuracy: 22.2%, Avg loss: 2.295680
#
# Test Error:
#  Accuracy: 22.1%, Avg loss: 2.295666
#
# Epoch 19
# -------------------------------
# Training Error:
#  Accuracy: 23.4%, Avg loss: 2.295259
#
# Test Error:
#  Accuracy: 23.4%, Avg loss: 2.295229
#
# Epoch 20
# -------------------------------
# Training Error:
#  Accuracy: 23.4%, Avg loss: 2.294827
#
# Test Error:
#  Accuracy: 23.7%, Avg loss: 2.294781
#
# Epoch 21
# -------------------------------
# Training Error:
#  Accuracy: 22.4%, Avg loss: 2.294384
#
# Test Error:
#  Accuracy: 22.9%, Avg loss: 2.294323
#
# Epoch 22
# -------------------------------
# Training Error:
#  Accuracy: 21.2%, Avg loss: 2.293930
#
# Test Error:
#  Accuracy: 21.6%, Avg loss: 2.293852
#
# Epoch 23
# -------------------------------
# Training Error:
#  Accuracy: 19.9%, Avg loss: 2.293462
#
# Test Error:
#  Accuracy: 20.4%, Avg loss: 2.293368
#
# Epoch 24
# -------------------------------
# Training Error:
#  Accuracy: 18.9%, Avg loss: 2.292979
#
# Test Error:
#  Accuracy: 19.1%, Avg loss: 2.292869
#
# Epoch 25
# -------------------------------
# Training Error:
#  Accuracy: 18.0%, Avg loss: 2.292480
#
# Test Error:
#  Accuracy: 18.3%, Avg loss: 2.292354
#
# Epoch 26
# -------------------------------
# Training Error:
#  Accuracy: 17.3%, Avg loss: 2.291964
#
# Test Error:
#  Accuracy: 17.6%, Avg loss: 2.291821
#
# Epoch 27
# -------------------------------
# Training Error:
#  Accuracy: 16.8%, Avg loss: 2.291430
#
# Test Error:
#  Accuracy: 17.2%, Avg loss: 2.291270
#
# Epoch 28
# -------------------------------
# Training Error:
#  Accuracy: 16.6%, Avg loss: 2.290875
#
# Test Error:
#  Accuracy: 16.8%, Avg loss: 2.290697
#
# Epoch 29
# -------------------------------
# Training Error:
#  Accuracy: 16.4%, Avg loss: 2.290299
#
# Test Error:
#  Accuracy: 16.6%, Avg loss: 2.290103
#
# Epoch 30
# -------------------------------
# Training Error:
#  Accuracy: 16.4%, Avg loss: 2.289698
#
# Test Error:
#  Accuracy: 16.5%, Avg loss: 2.289483
#
# Epoch 31
# -------------------------------
# Training Error:
#  Accuracy: 16.5%, Avg loss: 2.289072
#
# Test Error:
#  Accuracy: 16.5%, Avg loss: 2.288838
#
# Epoch 32
# -------------------------------
# Training Error:
#  Accuracy: 16.6%, Avg loss: 2.288417
#
# Test Error:
#  Accuracy: 16.6%, Avg loss: 2.288164
#
# Epoch 33
# -------------------------------
# Training Error:
#  Accuracy: 16.8%, Avg loss: 2.287733
#
# Test Error:
#  Accuracy: 16.8%, Avg loss: 2.287460
#
# Epoch 34
# -------------------------------
# Training Error:
#  Accuracy: 17.0%, Avg loss: 2.287017
#
# Test Error:
#  Accuracy: 17.2%, Avg loss: 2.286723
#
# Epoch 35
# -------------------------------
# Training Error:
#  Accuracy: 17.3%, Avg loss: 2.286264
#
# Test Error:
#  Accuracy: 17.4%, Avg loss: 2.285949
#
# Epoch 36
# -------------------------------
# Training Error:
#  Accuracy: 17.5%, Avg loss: 2.285474
#
# Test Error:
#  Accuracy: 17.6%, Avg loss: 2.285136
#
# Epoch 37
# -------------------------------
# Training Error:
#  Accuracy: 17.8%, Avg loss: 2.284641
#
# Test Error:
#  Accuracy: 17.9%, Avg loss: 2.284280
#
# Epoch 38
# -------------------------------
# Training Error:
#  Accuracy: 18.2%, Avg loss: 2.283763
#
# Test Error:
#  Accuracy: 18.3%, Avg loss: 2.283379
#
# Epoch 39
# -------------------------------
# Training Error:
#  Accuracy: 18.6%, Avg loss: 2.282836
#
# Test Error:
#  Accuracy: 18.6%, Avg loss: 2.282427
#
# Epoch 40
# -------------------------------
# Training Error:
#  Accuracy: 19.0%, Avg loss: 2.281855
#
# Test Error:
#  Accuracy: 19.0%, Avg loss: 2.281421
#
# Epoch 41
# -------------------------------
# Training Error:
#  Accuracy: 19.3%, Avg loss: 2.280816
#
# Test Error:
#  Accuracy: 19.6%, Avg loss: 2.280355
#
# Epoch 42
# -------------------------------
# Training Error:
#  Accuracy: 19.7%, Avg loss: 2.279713
#
# Test Error:
#  Accuracy: 20.1%, Avg loss: 2.279224
#
# Epoch 43
# -------------------------------
# Training Error:
#  Accuracy: 20.2%, Avg loss: 2.278540
#
# Test Error:
#  Accuracy: 20.5%, Avg loss: 2.278022
#
# Epoch 44
# -------------------------------
# Training Error:
#  Accuracy: 20.8%, Avg loss: 2.277289
#
# Test Error:
#  Accuracy: 21.3%, Avg loss: 2.276742
#
# Epoch 45
# -------------------------------
# Training Error:
#  Accuracy: 21.3%, Avg loss: 2.275955
#
# Test Error:
#  Accuracy: 21.9%, Avg loss: 2.275378
#
# Epoch 46
# -------------------------------
# Training Error:
#  Accuracy: 22.0%, Avg loss: 2.274530
#
# Test Error:
#  Accuracy: 22.5%, Avg loss: 2.273920
#
# Epoch 47
# -------------------------------
# Training Error:
#  Accuracy: 22.7%, Avg loss: 2.273006
#
# Test Error:
#  Accuracy: 23.2%, Avg loss: 2.272361
#
# Epoch 48
# -------------------------------
# Training Error:
#  Accuracy: 23.3%, Avg loss: 2.271374
#
# Test Error:
#  Accuracy: 23.9%, Avg loss: 2.270693
#
# Epoch 49
# -------------------------------
# Training Error:
#  Accuracy: 24.0%, Avg loss: 2.269626
#
# Test Error:
#  Accuracy: 24.6%, Avg loss: 2.268907
#
# Epoch 50
# -------------------------------
# Training Error:
#  Accuracy: 24.6%, Avg loss: 2.267750
#
# Test Error:
#  Accuracy: 25.2%, Avg loss: 2.266989
#
# Epoch 51
# -------------------------------
# Training Error:
#  Accuracy: 25.3%, Avg loss: 2.265731
#
# Test Error:
#  Accuracy: 26.0%, Avg loss: 2.264928
#
# Epoch 52
# -------------------------------
# Training Error:
#  Accuracy: 26.1%, Avg loss: 2.263555
#
# Test Error:
#  Accuracy: 26.6%, Avg loss: 2.262705
#
# Epoch 53
# -------------------------------
# Training Error:
#  Accuracy: 26.7%, Avg loss: 2.261202
#
# Test Error:
#  Accuracy: 27.2%, Avg loss: 2.260302
#
# Epoch 54
# -------------------------------
# Training Error:
#  Accuracy: 27.4%, Avg loss: 2.258651
#
# Test Error:
#  Accuracy: 27.6%, Avg loss: 2.257697
#
# Epoch 55
# -------------------------------
# Training Error:
#  Accuracy: 28.0%, Avg loss: 2.255879
#
# Test Error:
#  Accuracy: 28.2%, Avg loss: 2.254869
#
# Epoch 56
# -------------------------------
# Training Error:
#  Accuracy: 28.6%, Avg loss: 2.252864
#
# Test Error:
#  Accuracy: 28.9%, Avg loss: 2.251792
#
# Epoch 57
# -------------------------------
# Training Error:
#  Accuracy: 29.2%, Avg loss: 2.249575
#
# Test Error:
#  Accuracy: 29.5%, Avg loss: 2.248438
#
# Epoch 58
# -------------------------------
# Training Error:
#  Accuracy: 29.8%, Avg loss: 2.245979
#
# Test Error:
#  Accuracy: 29.8%, Avg loss: 2.244771
#
# Epoch 59
# -------------------------------
# Training Error:
#  Accuracy: 30.3%, Avg loss: 2.242035
#
# Test Error:
#  Accuracy: 30.4%, Avg loss: 2.240751
#
# Epoch 60
# -------------------------------
# Training Error:
#  Accuracy: 30.8%, Avg loss: 2.237698
#
# Test Error:
#  Accuracy: 30.9%, Avg loss: 2.236330
#
# Epoch 61
# -------------------------------
# Training Error:
#  Accuracy: 31.3%, Avg loss: 2.232912
#
# Test Error:
#  Accuracy: 31.6%, Avg loss: 2.231451
#
# Epoch 62
# -------------------------------
# Training Error:
#  Accuracy: 31.8%, Avg loss: 2.227610
#
# Test Error:
#  Accuracy: 32.0%, Avg loss: 2.226048
#
# Epoch 63
# -------------------------------
# Training Error:
#  Accuracy: 32.3%, Avg loss: 2.221718
#
# Test Error:
#  Accuracy: 32.5%, Avg loss: 2.220046
#
# Epoch 64
# -------------------------------
# Training Error:
#  Accuracy: 32.9%, Avg loss: 2.215150
#
# Test Error:
#  Accuracy: 33.1%, Avg loss: 2.213358
#
# Epoch 65
# -------------------------------
# Training Error:
#  Accuracy: 33.5%, Avg loss: 2.207806
#
# Test Error:
#  Accuracy: 33.6%, Avg loss: 2.205883
#
# Epoch 66
# -------------------------------
# Training Error:
#  Accuracy: 34.1%, Avg loss: 2.199576
#
# Test Error:
#  Accuracy: 34.3%, Avg loss: 2.197509
#
# Epoch 67
# -------------------------------
# Training Error:
#  Accuracy: 34.9%, Avg loss: 2.190335
#
# Test Error:
#  Accuracy: 35.0%, Avg loss: 2.188111
#
# Epoch 68
# -------------------------------
# Training Error:
#  Accuracy: 35.7%, Avg loss: 2.179948
#
# Test Error:
#  Accuracy: 36.1%, Avg loss: 2.177555
#
# Epoch 69
# -------------------------------
# Training Error:
#  Accuracy: 36.7%, Avg loss: 2.168274
#
# Test Error:
#  Accuracy: 37.4%, Avg loss: 2.165695
#
# Epoch 70
# -------------------------------
# Training Error:
#  Accuracy: 37.7%, Avg loss: 2.155171
#
# Test Error:
#  Accuracy: 38.4%, Avg loss: 2.152391
#
# Epoch 71
# -------------------------------
# Training Error:
#  Accuracy: 38.7%, Avg loss: 2.140508
#
# Test Error:
#  Accuracy: 39.6%, Avg loss: 2.137513
#
# Epoch 72
# -------------------------------
# Training Error:
#  Accuracy: 39.9%, Avg loss: 2.124182
#
# Test Error:
#  Accuracy: 41.0%, Avg loss: 2.120964
#
# Epoch 73
# -------------------------------
# Training Error:
#  Accuracy: 41.1%, Avg loss: 2.106141
#
# Test Error:
#  Accuracy: 42.2%, Avg loss: 2.102686
#
# Epoch 74
# -------------------------------
# Training Error:
#  Accuracy: 42.5%, Avg loss: 2.086392
#
# Test Error:
#  Accuracy: 43.5%, Avg loss: 2.082689
#
# Epoch 75
# -------------------------------
# Training Error:
#  Accuracy: 44.0%, Avg loss: 2.065011
#
# Test Error:
#  Accuracy: 44.8%, Avg loss: 2.061047
#
# Epoch 76
# -------------------------------
# Training Error:
#  Accuracy: 45.5%, Avg loss: 2.042108
#
# Test Error:
#  Accuracy: 46.5%, Avg loss: 2.037860
#
# Epoch 77
# -------------------------------
# Training Error:
#  Accuracy: 47.1%, Avg loss: 2.017759
#
# Test Error:
#  Accuracy: 48.3%, Avg loss: 2.013194
#
# Epoch 78
# -------------------------------
# Training Error:
#  Accuracy: 49.0%, Avg loss: 1.991970
#
# Test Error:
#  Accuracy: 50.1%, Avg loss: 1.987032
#
# Epoch 79
# -------------------------------
# Training Error:
#  Accuracy: 51.0%, Avg loss: 1.964654
#
# Test Error:
#  Accuracy: 51.9%, Avg loss: 1.959272
#
# Epoch 80
# -------------------------------
# Training Error:
#  Accuracy: 52.9%, Avg loss: 1.935608
#
# Test Error:
#  Accuracy: 53.6%, Avg loss: 1.929698
#
# Epoch 81
# -------------------------------
# Training Error:
#  Accuracy: 54.7%, Avg loss: 1.904592
#
# Test Error:
#  Accuracy: 55.5%, Avg loss: 1.898057
#
# Epoch 82
# -------------------------------
# Training Error:
#  Accuracy: 56.4%, Avg loss: 1.871390
#
# Test Error:
#  Accuracy: 57.0%, Avg loss: 1.864139
#
# Epoch 83
# -------------------------------
# Training Error:
#  Accuracy: 58.0%, Avg loss: 1.835817
#
# Test Error:
#  Accuracy: 58.4%, Avg loss: 1.827764
#
# Epoch 84
# -------------------------------
# Training Error:
#  Accuracy: 59.4%, Avg loss: 1.797753
#
# Test Error:
#  Accuracy: 59.8%, Avg loss: 1.788826
#
# Epoch 85
# -------------------------------
# Training Error:
#  Accuracy: 60.4%, Avg loss: 1.757195
#
# Test Error:
#  Accuracy: 60.8%, Avg loss: 1.747348
#
# Epoch 86
# -------------------------------
# Training Error:
#  Accuracy: 61.1%, Avg loss: 1.714318
#
# Test Error:
#  Accuracy: 61.6%, Avg loss: 1.703529
#
# Epoch 87
# -------------------------------
# Training Error:
#  Accuracy: 61.8%, Avg loss: 1.669366
#
# Test Error:
#  Accuracy: 62.2%, Avg loss: 1.657637
#
# Epoch 88
# -------------------------------
# Training Error:
#  Accuracy: 62.4%, Avg loss: 1.622567
#
# Test Error:
#  Accuracy: 62.7%, Avg loss: 1.609927
#
# Epoch 89
# -------------------------------
# Training Error:
#  Accuracy: 63.0%, Avg loss: 1.574168
#
# Test Error:
#  Accuracy: 63.4%, Avg loss: 1.560654
#
# Epoch 90
# -------------------------------
# Training Error:
#  Accuracy: 63.5%, Avg loss: 1.524462
#
# Test Error:
#  Accuracy: 64.0%, Avg loss: 1.510124
#
# Epoch 91
# -------------------------------
# Training Error:
#  Accuracy: 64.1%, Avg loss: 1.473814
#
# Test Error:
#  Accuracy: 64.7%, Avg loss: 1.458706
#
# Epoch 92
# -------------------------------
# Training Error:
#  Accuracy: 64.6%, Avg loss: 1.422727
#
# Test Error:
#  Accuracy: 65.0%, Avg loss: 1.406923
#
# Epoch 93
# -------------------------------
# Training Error:
#  Accuracy: 65.0%, Avg loss: 1.371872
#
# Test Error:
#  Accuracy: 65.3%, Avg loss: 1.355470
#
# Epoch 94
# -------------------------------
# Training Error:
#  Accuracy: 65.5%, Avg loss: 1.322032
#
# Test Error:
#  Accuracy: 65.6%, Avg loss: 1.305154
#
# Epoch 95
# -------------------------------
# Training Error:
#  Accuracy: 65.9%, Avg loss: 1.273969
#
# Test Error:
#  Accuracy: 66.1%, Avg loss: 1.256758
#
# Epoch 96
# -------------------------------
# Training Error:
#  Accuracy: 66.4%, Avg loss: 1.228306
#
# Test Error:
#  Accuracy: 66.7%, Avg loss: 1.210903
#
# Epoch 97
# -------------------------------
# Training Error:
#  Accuracy: 67.1%, Avg loss: 1.185389
#
# Test Error:
#  Accuracy: 67.4%, Avg loss: 1.167902
#
# Epoch 98
# -------------------------------
# Training Error:
#  Accuracy: 67.7%, Avg loss: 1.145238
#
# Test Error:
#  Accuracy: 68.0%, Avg loss: 1.127748
#
# Epoch 99
# -------------------------------
# Training Error:
#  Accuracy: 68.5%, Avg loss: 1.107685
#
# Test Error:
#  Accuracy: 68.8%, Avg loss: 1.090258
#
# Epoch 100
# -------------------------------
# Training Error:
#  Accuracy: 69.1%, Avg loss: 1.072478
#
# Test Error:
#  Accuracy: 69.5%, Avg loss: 1.055144

# %%
visualise_model_perf(models, title='Avg error vs Number of Epochs');

# %%
fig, ax = plt.subplots()
fig.set_size_inches(18.5, 10.5)
for m in models:
    epochs = m.epochs
    ax.plot(range(1, epochs+1), m.error_test, label = f"{m.name}: test loss")
    ax.plot(range(1, epochs+1), m.error_training, label = f"{m.name}: training loss")
ax.set_title("Avg error vs Number of Epochs")
ax.set_xlabel("Number of Epochs")
ax.set_ylabel("Average Error")
ax.legend()

# %% [markdown]
# <hr>

# %% [markdown]
# ### Experiment 4: Changing the width of the layers

# %%
models = train_models(load_config('widths.json'))
# Out:
# Training w64
# Epoch 1
# -------------------------------
# Training Error:
#  Accuracy: 9.9%, Avg loss: 2.301317
#
# Test Error:
#  Accuracy: 10.3%, Avg loss: 2.300958
#
# Epoch 2
# -------------------------------
# Training Error:
#  Accuracy: 10.5%, Avg loss: 2.297057
#
# Test Error:
#  Accuracy: 11.0%, Avg loss: 2.296643
#
# Epoch 3
# -------------------------------
# Training Error:
#  Accuracy: 25.2%, Avg loss: 2.292188
#
# Test Error:
#  Accuracy: 25.8%, Avg loss: 2.291694
#
# Epoch 4
# -------------------------------
# Training Error:
#  Accuracy: 22.1%, Avg loss: 2.285451
#
# Test Error:
#  Accuracy: 22.6%, Avg loss: 2.284843
#
# Epoch 5
# -------------------------------
# Training Error:
#  Accuracy: 29.7%, Avg loss: 2.274246
#
# Test Error:
#  Accuracy: 30.0%, Avg loss: 2.273429
#
# Epoch 6
# -------------------------------
# Training Error:
#  Accuracy: 27.6%, Avg loss: 2.251684
#
# Test Error:
#  Accuracy: 28.2%, Avg loss: 2.250410
#
# Epoch 7
# -------------------------------
# Training Error:
#  Accuracy: 24.7%, Avg loss: 2.197992
#
# Test Error:
#  Accuracy: 25.0%, Avg loss: 2.195663
#
# Epoch 8
# -------------------------------
# Training Error:
#  Accuracy: 25.4%, Avg loss: 2.074893
#
# Test Error:
#  Accuracy: 25.4%, Avg loss: 2.071128
#
# Epoch 9
# -------------------------------
# Training Error:
#  Accuracy: 33.6%, Avg loss: 1.908907
#
# Test Error:
#  Accuracy: 33.6%, Avg loss: 1.903314
#
# Epoch 10
# -------------------------------
# Training Error:
#  Accuracy: 49.9%, Avg loss: 1.641654
#
# Test Error:
#  Accuracy: 50.0%, Avg loss: 1.632503
#
# Epoch 11
# -------------------------------
# Training Error:
#  Accuracy: 57.6%, Avg loss: 1.297793
#
# Test Error:
#  Accuracy: 58.5%, Avg loss: 1.285219
#
# Epoch 12
# -------------------------------
# Training Error:
#  Accuracy: 64.6%, Avg loss: 1.055702
#
# Test Error:
#  Accuracy: 65.0%, Avg loss: 1.043735
#
# Epoch 13
# -------------------------------
# Training Error:
#  Accuracy: 71.9%, Avg loss: 0.860801
#
# Test Error:
#  Accuracy: 72.3%, Avg loss: 0.849087
#
# Epoch 14
# -------------------------------
# Training Error:
#  Accuracy: 76.6%, Avg loss: 0.732936
#
# Test Error:
#  Accuracy: 77.5%, Avg loss: 0.718768
#
# Epoch 15
# -------------------------------
# Training Error:
#  Accuracy: 79.4%, Avg loss: 0.664430
#
# Test Error:
#  Accuracy: 80.3%, Avg loss: 0.649103
#
# Epoch 16
# -------------------------------
# Training Error:
#  Accuracy: 81.2%, Avg loss: 0.621923
#
# Test Error:
#  Accuracy: 81.8%, Avg loss: 0.606934
#
# Epoch 17
# -------------------------------
# Training Error:
#  Accuracy: 82.3%, Avg loss: 0.590806
#
# Test Error:
#  Accuracy: 82.9%, Avg loss: 0.576711
#
# Epoch 18
# -------------------------------
# Training Error:
#  Accuracy: 83.3%, Avg loss: 0.565608
#
# Test Error:
#  Accuracy: 83.7%, Avg loss: 0.552542
#
# Epoch 19
# -------------------------------
# Training Error:
#  Accuracy: 84.0%, Avg loss: 0.543584
#
# Test Error:
#  Accuracy: 84.5%, Avg loss: 0.531681
#
# Epoch 20
# -------------------------------
# Training Error:
#  Accuracy: 84.7%, Avg loss: 0.523464
#
# Test Error:
#  Accuracy: 85.0%, Avg loss: 0.512595
#
# Epoch 21
# -------------------------------
# Training Error:
#  Accuracy: 85.3%, Avg loss: 0.504069
#
# Test Error:
#  Accuracy: 85.6%, Avg loss: 0.494326
#
# Epoch 22
# -------------------------------
# Training Error:
#  Accuracy: 86.0%, Avg loss: 0.484709
#
# Test Error:
#  Accuracy: 86.0%, Avg loss: 0.476185
#
# Epoch 23
# -------------------------------
# Training Error:
#  Accuracy: 86.6%, Avg loss: 0.464999
#
# Test Error:
#  Accuracy: 86.6%, Avg loss: 0.457644
#
# Epoch 24
# -------------------------------
# Training Error:
#  Accuracy: 87.2%, Avg loss: 0.445036
#
# Test Error:
#  Accuracy: 87.1%, Avg loss: 0.438960
#
# Epoch 25
# -------------------------------
# Training Error:
#  Accuracy: 87.7%, Avg loss: 0.425455
#
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.420628
#
# Epoch 26
# -------------------------------
# Training Error:
#  Accuracy: 88.3%, Avg loss: 0.407520
#
# Test Error:
#  Accuracy: 88.2%, Avg loss: 0.403776
#
# Epoch 27
# -------------------------------
# Training Error:
#  Accuracy: 88.7%, Avg loss: 0.391583
#
# Test Error:
#  Accuracy: 88.5%, Avg loss: 0.388750
#
# Epoch 28
# -------------------------------
# Training Error:
#  Accuracy: 89.1%, Avg loss: 0.377721
#
# Test Error:
#  Accuracy: 89.0%, Avg loss: 0.375488
#
# Epoch 29
# -------------------------------
# Training Error:
#  Accuracy: 89.4%, Avg loss: 0.365468
#
# Test Error:
#  Accuracy: 89.4%, Avg loss: 0.363660
#
# Epoch 30
# -------------------------------
# Training Error:
#  Accuracy: 89.7%, Avg loss: 0.354274
#
# Test Error:
#  Accuracy: 89.7%, Avg loss: 0.352690
#
# Epoch 31
# -------------------------------
# Training Error:
#  Accuracy: 90.0%, Avg loss: 0.343657
#
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.342323
#
# Epoch 32
# -------------------------------
# Training Error:
#  Accuracy: 90.3%, Avg loss: 0.333626
#
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.332577
#
# Epoch 33
# -------------------------------
# Training Error:
#  Accuracy: 90.6%, Avg loss: 0.323991
#
# Test Error:
#  Accuracy: 90.6%, Avg loss: 0.323281
#
# Epoch 34
# -------------------------------
# Training Error:
#  Accuracy: 90.9%, Avg loss: 0.314702
#
# Test Error:
#  Accuracy: 90.8%, Avg loss: 0.314321
#
# Epoch 35
# -------------------------------
# Training Error:
#  Accuracy: 91.2%, Avg loss: 0.305871
#
# Test Error:
#  Accuracy: 91.1%, Avg loss: 0.305771
#
# Epoch 36
# -------------------------------
# Training Error:
#  Accuracy: 91.4%, Avg loss: 0.297503
#
# Test Error:
#  Accuracy: 91.3%, Avg loss: 0.297641
#
# Epoch 37
# -------------------------------
# Training Error:
#  Accuracy: 91.6%, Avg loss: 0.289492
#
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.289876
#
# Epoch 38
# -------------------------------
# Training Error:
#  Accuracy: 91.9%, Avg loss: 0.281802
#
# Test Error:
#  Accuracy: 91.8%, Avg loss: 0.282364
#
# Epoch 39
# -------------------------------
# Training Error:
#  Accuracy: 92.1%, Avg loss: 0.274527
#
# Test Error:
#  Accuracy: 92.1%, Avg loss: 0.275236
#
# Epoch 40
# -------------------------------
# Training Error:
#  Accuracy: 92.3%, Avg loss: 0.267510
#
# Test Error:
#  Accuracy: 92.2%, Avg loss: 0.268388
#
# Epoch 41
# -------------------------------
# Training Error:
#  Accuracy: 92.5%, Avg loss: 0.260818
#
# Test Error:
#  Accuracy: 92.4%, Avg loss: 0.261882
#
# Epoch 42
# -------------------------------
# Training Error:
#  Accuracy: 92.6%, Avg loss: 0.254492
#
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.255715
#
# Epoch 43
# -------------------------------
# Training Error:
#  Accuracy: 92.8%, Avg loss: 0.248419
#
# Test Error:
#  Accuracy: 92.8%, Avg loss: 0.249815
#
# Epoch 44
# -------------------------------
# Training Error:
#  Accuracy: 92.9%, Avg loss: 0.242668
#
# Test Error:
#  Accuracy: 92.9%, Avg loss: 0.244168
#
# Epoch 45
# -------------------------------
# Training Error:
#  Accuracy: 93.1%, Avg loss: 0.237214
#
# Test Error:
#  Accuracy: 93.1%, Avg loss: 0.238851
#
# Epoch 46
# -------------------------------
# Training Error:
#  Accuracy: 93.3%, Avg loss: 0.232008
#
# Test Error:
#  Accuracy: 93.2%, Avg loss: 0.233789
#
# Epoch 47
# -------------------------------
# Training Error:
#  Accuracy: 93.4%, Avg loss: 0.227091
#
# Test Error:
#  Accuracy: 93.2%, Avg loss: 0.229060
#
# Epoch 48
# -------------------------------
# Training Error:
#  Accuracy: 93.5%, Avg loss: 0.222386
#
# Test Error:
#  Accuracy: 93.4%, Avg loss: 0.224620
#
# Epoch 49
# -------------------------------
# Training Error:
#  Accuracy: 93.7%, Avg loss: 0.217760
#
# Test Error:
#  Accuracy: 93.6%, Avg loss: 0.220204
#
# Epoch 50
# -------------------------------
# Training Error:
#  Accuracy: 93.8%, Avg loss: 0.213414
#
# Test Error:
#  Accuracy: 93.8%, Avg loss: 0.216106
#
# Epoch 51
# -------------------------------
# Training Error:
#  Accuracy: 93.9%, Avg loss: 0.209257
#
# Test Error:
#  Accuracy: 93.9%, Avg loss: 0.212188
#
# Epoch 52
# -------------------------------
# Training Error:
#  Accuracy: 94.0%, Avg loss: 0.205236
#
# Test Error:
#  Accuracy: 94.0%, Avg loss: 0.208478
#
# Epoch 53
# -------------------------------
# Training Error:
#  Accuracy: 94.1%, Avg loss: 0.201328
#
# Test Error:
#  Accuracy: 94.1%, Avg loss: 0.204902
#
# Epoch 54
# -------------------------------
# Training Error:
#  Accuracy: 94.2%, Avg loss: 0.197587
#
# Test Error:
#  Accuracy: 94.2%, Avg loss: 0.201525
#
# Epoch 55
# -------------------------------
# Training Error:
#  Accuracy: 94.3%, Avg loss: 0.193965
#
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.198296
#
# Epoch 56
# -------------------------------
# Training Error:
#  Accuracy: 94.4%, Avg loss: 0.190422
#
# Test Error:
#  Accuracy: 94.4%, Avg loss: 0.195153
#
# Epoch 57
# -------------------------------
# Training Error:
#  Accuracy: 94.5%, Avg loss: 0.186970
#
# Test Error:
#  Accuracy: 94.5%, Avg loss: 0.192160
#
# Epoch 58
# -------------------------------
# Training Error:
#  Accuracy: 94.6%, Avg loss: 0.183653
#
# Test Error:
#  Accuracy: 94.6%, Avg loss: 0.189350
#
# Epoch 59
# -------------------------------
# Training Error:
#  Accuracy: 94.7%, Avg loss: 0.180565
#
# Test Error:
#  Accuracy: 94.7%, Avg loss: 0.186657
#
# Epoch 60
# -------------------------------
# Training Error:
#  Accuracy: 94.8%, Avg loss: 0.177477
#
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.184051
#
# Epoch 61
# -------------------------------
# Training Error:
#  Accuracy: 94.9%, Avg loss: 0.174459
#
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.181524
#
# Epoch 62
# -------------------------------
# Training Error:
#  Accuracy: 95.0%, Avg loss: 0.171536
#
# Test Error:
#  Accuracy: 94.9%, Avg loss: 0.179133
#
# Epoch 63
# -------------------------------
# Training Error:
#  Accuracy: 95.1%, Avg loss: 0.168755
#
# Test Error:
#  Accuracy: 95.0%, Avg loss: 0.176879
#
# Epoch 64
# -------------------------------
# Training Error:
#  Accuracy: 95.1%, Avg loss: 0.166177
#
# Test Error:
#  Accuracy: 95.1%, Avg loss: 0.174777
#
# Epoch 65
# -------------------------------
# Training Error:
#  Accuracy: 95.2%, Avg loss: 0.163583
#
# Test Error:
#  Accuracy: 95.2%, Avg loss: 0.172744
#
# Epoch 66
# -------------------------------
# Training Error:
#  Accuracy: 95.3%, Avg loss: 0.161074
#
# Test Error:
#  Accuracy: 95.2%, Avg loss: 0.170778
#
# Epoch 67
# -------------------------------
# Training Error:
#  Accuracy: 95.4%, Avg loss: 0.158600
#
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.168876
#
# Epoch 68
# -------------------------------
# Training Error:
#  Accuracy: 95.5%, Avg loss: 0.156210
#
# Test Error:
#  Accuracy: 95.4%, Avg loss: 0.167068
#
# Epoch 69
# -------------------------------
# Training Error:
#  Accuracy: 95.5%, Avg loss: 0.153935
#
# Test Error:
#  Accuracy: 95.4%, Avg loss: 0.165284
#
# Epoch 70
# -------------------------------
# Training Error:
#  Accuracy: 95.6%, Avg loss: 0.151740
#
# Test Error:
#  Accuracy: 95.5%, Avg loss: 0.163663
#
# Epoch 71
# -------------------------------
# Training Error:
#  Accuracy: 95.7%, Avg loss: 0.149592
#
# Test Error:
#  Accuracy: 95.5%, Avg loss: 0.162069
#
# Epoch 72
# -------------------------------
# Training Error:
#  Accuracy: 95.7%, Avg loss: 0.147501
#
# Test Error:
#  Accuracy: 95.5%, Avg loss: 0.160554
#
# Epoch 73
# -------------------------------
# Training Error:
#  Accuracy: 95.8%, Avg loss: 0.145460
#
# Test Error:
#  Accuracy: 95.5%, Avg loss: 0.159125
#
# Epoch 74
# -------------------------------
# Training Error:
#  Accuracy: 95.8%, Avg loss: 0.143474
#
# Test Error:
#  Accuracy: 95.5%, Avg loss: 0.157728
#
# Epoch 75
# -------------------------------
# Training Error:
#  Accuracy: 95.9%, Avg loss: 0.141580
#
# Test Error:
#  Accuracy: 95.6%, Avg loss: 0.156364
#
# Epoch 76
# -------------------------------
# Training Error:
#  Accuracy: 95.9%, Avg loss: 0.139678
#
# Test Error:
#  Accuracy: 95.7%, Avg loss: 0.155061
#
# Epoch 77
# -------------------------------
# Training Error:
#  Accuracy: 96.0%, Avg loss: 0.137795
#
# Test Error:
#  Accuracy: 95.7%, Avg loss: 0.153761
#
# Epoch 78
# -------------------------------
# Training Error:
#  Accuracy: 96.1%, Avg loss: 0.136032
#
# Test Error:
#  Accuracy: 95.7%, Avg loss: 0.152702
#
# Epoch 79
# -------------------------------
# Training Error:
#  Accuracy: 96.1%, Avg loss: 0.134288
#
# Test Error:
#  Accuracy: 95.7%, Avg loss: 0.151621
#
# Epoch 80
# -------------------------------
# Training Error:
#  Accuracy: 96.2%, Avg loss: 0.132600
#
# Test Error:
#  Accuracy: 95.7%, Avg loss: 0.150555
#
# Epoch 81
# -------------------------------
# Training Error:
#  Accuracy: 96.2%, Avg loss: 0.130955
#
# Test Error:
#  Accuracy: 95.8%, Avg loss: 0.149567
#
# Epoch 82
# -------------------------------
# Training Error:
#  Accuracy: 96.3%, Avg loss: 0.129327
#
# Test Error:
#  Accuracy: 95.8%, Avg loss: 0.148562
#
# Epoch 83
# -------------------------------
# Training Error:
#  Accuracy: 96.3%, Avg loss: 0.127777
#
# Test Error:
#  Accuracy: 95.8%, Avg loss: 0.147637
#
# Epoch 84
# -------------------------------
# Training Error:
#  Accuracy: 96.3%, Avg loss: 0.126211
#
# Test Error:
#  Accuracy: 95.9%, Avg loss: 0.146695
#
# Epoch 85
# -------------------------------
# Training Error:
#  Accuracy: 96.4%, Avg loss: 0.124688
#
# Test Error:
#  Accuracy: 95.8%, Avg loss: 0.145796
#
# Epoch 86
# -------------------------------
# Training Error:
#  Accuracy: 96.4%, Avg loss: 0.123201
#
# Test Error:
#  Accuracy: 95.9%, Avg loss: 0.144917
#
# Epoch 87
# -------------------------------
# Training Error:
#  Accuracy: 96.5%, Avg loss: 0.121714
#
# Test Error:
#  Accuracy: 95.9%, Avg loss: 0.144047
#
# Epoch 88
# -------------------------------
# Training Error:
#  Accuracy: 96.5%, Avg loss: 0.120295
#
# Test Error:
#  Accuracy: 95.9%, Avg loss: 0.143243
#
# Epoch 89
# -------------------------------
# Training Error:
#  Accuracy: 96.6%, Avg loss: 0.118879
#
# Test Error:
#  Accuracy: 95.9%, Avg loss: 0.142493
#
# Epoch 90
# -------------------------------
# Training Error:
#  Accuracy: 96.6%, Avg loss: 0.117437
#
# Test Error:
#  Accuracy: 95.9%, Avg loss: 0.141614
#
# Epoch 91
# -------------------------------
# Training Error:
#  Accuracy: 96.6%, Avg loss: 0.116155
#
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.140902
#
# Epoch 92
# -------------------------------
# Training Error:
#  Accuracy: 96.7%, Avg loss: 0.114771
#
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.140042
#
# Epoch 93
# -------------------------------
# Training Error:
#  Accuracy: 96.7%, Avg loss: 0.113508
#
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.139398
#
# Epoch 94
# -------------------------------
# Training Error:
#  Accuracy: 96.8%, Avg loss: 0.112261
#
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.138648
#
# Epoch 95
# -------------------------------
# Training Error:
#  Accuracy: 96.8%, Avg loss: 0.111054
#
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.137996
#
# Epoch 96
# -------------------------------
# Training Error:
#  Accuracy: 96.8%, Avg loss: 0.109830
#
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.137342
#
# Epoch 97
# -------------------------------
# Training Error:
#  Accuracy: 96.8%, Avg loss: 0.108655
#
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.136738
#
# Epoch 98
# -------------------------------
# Training Error:
#  Accuracy: 96.9%, Avg loss: 0.107471
#
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.136079
#
# Epoch 99
# -------------------------------
# Training Error:
#  Accuracy: 96.9%, Avg loss: 0.106319
#
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.135468
#
# Epoch 100
# -------------------------------
# Training Error:
#  Accuracy: 96.9%, Avg loss: 0.105194
#
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.134891
#
# Training w128
# Epoch 1
# -------------------------------
# Training Error:
#  Accuracy: 9.8%, Avg loss: 2.301188
#
# Test Error:
#  Accuracy: 9.7%, Avg loss: 2.301296
#
# Epoch 2
# -------------------------------
# Training Error:
#  Accuracy: 22.4%, Avg loss: 2.298146
#
# Test Error:
#  Accuracy: 23.5%, Avg loss: 2.298127
#
# Epoch 3
# -------------------------------
# Training Error:
#  Accuracy: 15.9%, Avg loss: 2.294935
#
# Test Error:
#  Accuracy: 15.9%, Avg loss: 2.294785
#
# Epoch 4
# -------------------------------
# Training Error:
#  Accuracy: 16.2%, Avg loss: 2.290976
#
# Test Error:
#  Accuracy: 16.2%, Avg loss: 2.290676
#
# Epoch 5
# -------------------------------
# Training Error:
#  Accuracy: 18.0%, Avg loss: 2.285418
#
# Test Error:
#  Accuracy: 18.2%, Avg loss: 2.284926
#
# Epoch 6
# -------------------------------
# Training Error:
#  Accuracy: 19.7%, Avg loss: 2.276726
#
# Test Error:
#  Accuracy: 19.9%, Avg loss: 2.275954
#
# Epoch 7
# -------------------------------
# Training Error:
#  Accuracy: 21.7%, Avg loss: 2.261524
#
# Test Error:
#  Accuracy: 22.0%, Avg loss: 2.260322
#
# Epoch 8
# -------------------------------
# Training Error:
#  Accuracy: 29.0%, Avg loss: 2.230363
#
# Test Error:
#  Accuracy: 30.0%, Avg loss: 2.228316
#
# Epoch 9
# -------------------------------
# Training Error:
#  Accuracy: 34.2%, Avg loss: 2.148457
#
# Test Error:
#  Accuracy: 35.2%, Avg loss: 2.144417
#
# Epoch 10
# -------------------------------
# Training Error:
#  Accuracy: 42.7%, Avg loss: 1.942470
#
# Test Error:
#  Accuracy: 43.3%, Avg loss: 1.933071
#
# Epoch 11
# -------------------------------
# Training Error:
#  Accuracy: 53.3%, Avg loss: 1.498837
#
# Test Error:
#  Accuracy: 54.1%, Avg loss: 1.475608
#
# Epoch 12
# -------------------------------
# Training Error:
#  Accuracy: 61.2%, Avg loss: 1.152427
#
# Test Error:
#  Accuracy: 62.0%, Avg loss: 1.125678
#
# Epoch 13
# -------------------------------
# Training Error:
#  Accuracy: 68.6%, Avg loss: 0.981481
#
# Test Error:
#  Accuracy: 69.1%, Avg loss: 0.957256
#
# Epoch 14
# -------------------------------
# Training Error:
#  Accuracy: 75.1%, Avg loss: 0.814139
#
# Test Error:
#  Accuracy: 75.9%, Avg loss: 0.793716
#
# Epoch 15
# -------------------------------
# Training Error:
#  Accuracy: 78.7%, Avg loss: 0.691976
#
# Test Error:
#  Accuracy: 79.5%, Avg loss: 0.673776
#
# Epoch 16
# -------------------------------
# Training Error:
#  Accuracy: 81.0%, Avg loss: 0.627544
#
# Test Error:
#  Accuracy: 81.7%, Avg loss: 0.610467
#
# Epoch 17
# -------------------------------
# Training Error:
#  Accuracy: 82.6%, Avg loss: 0.583682
#
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.567921
#
# Epoch 18
# -------------------------------
# Training Error:
#  Accuracy: 83.8%, Avg loss: 0.547829
#
# Test Error:
#  Accuracy: 84.2%, Avg loss: 0.533443
#
# Epoch 19
# -------------------------------
# Training Error:
#  Accuracy: 84.8%, Avg loss: 0.516307
#
# Test Error:
#  Accuracy: 85.2%, Avg loss: 0.503190
#
# Epoch 20
# -------------------------------
# Training Error:
#  Accuracy: 85.7%, Avg loss: 0.488287
#
# Test Error:
#  Accuracy: 86.1%, Avg loss: 0.476382
#
# Epoch 21
# -------------------------------
# Training Error:
#  Accuracy: 86.5%, Avg loss: 0.463435
#
# Test Error:
#  Accuracy: 86.8%, Avg loss: 0.452728
#
# Epoch 22
# -------------------------------
# Training Error:
#  Accuracy: 87.1%, Avg loss: 0.441388
#
# Test Error:
#  Accuracy: 87.4%, Avg loss: 0.431812
#
# Epoch 23
# -------------------------------
# Training Error:
#  Accuracy: 87.7%, Avg loss: 0.421371
#
# Test Error:
#  Accuracy: 88.1%, Avg loss: 0.412953
#
# Epoch 24
# -------------------------------
# Training Error:
#  Accuracy: 88.2%, Avg loss: 0.402922
#
# Test Error:
#  Accuracy: 88.5%, Avg loss: 0.395476
#
# Epoch 25
# -------------------------------
# Training Error:
#  Accuracy: 88.7%, Avg loss: 0.385816
#
# Test Error:
#  Accuracy: 88.8%, Avg loss: 0.379293
#
# Epoch 26
# -------------------------------
# Training Error:
#  Accuracy: 89.2%, Avg loss: 0.369915
#
# Test Error:
#  Accuracy: 89.2%, Avg loss: 0.364239
#
# Epoch 27
# -------------------------------
# Training Error:
#  Accuracy: 89.7%, Avg loss: 0.355226
#
# Test Error:
#  Accuracy: 89.5%, Avg loss: 0.350372
#
# Epoch 28
# -------------------------------
# Training Error:
#  Accuracy: 90.1%, Avg loss: 0.341614
#
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.337593
#
# Epoch 29
# -------------------------------
# Training Error:
#  Accuracy: 90.5%, Avg loss: 0.329053
#
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.325827
#
# Epoch 30
# -------------------------------
# Training Error:
#  Accuracy: 90.9%, Avg loss: 0.317368
#
# Test Error:
#  Accuracy: 90.5%, Avg loss: 0.314943
#
# Epoch 31
# -------------------------------
# Training Error:
#  Accuracy: 91.2%, Avg loss: 0.306430
#
# Test Error:
#  Accuracy: 91.0%, Avg loss: 0.304826
#
# Epoch 32
# -------------------------------
# Training Error:
#  Accuracy: 91.5%, Avg loss: 0.296227
#
# Test Error:
#  Accuracy: 91.3%, Avg loss: 0.295485
#
# Epoch 33
# -------------------------------
# Training Error:
#  Accuracy: 91.8%, Avg loss: 0.286659
#
# Test Error:
#  Accuracy: 91.6%, Avg loss: 0.286732
#
# Epoch 34
# -------------------------------
# Training Error:
#  Accuracy: 92.0%, Avg loss: 0.277598
#
# Test Error:
#  Accuracy: 91.7%, Avg loss: 0.278491
#
# Epoch 35
# -------------------------------
# Training Error:
#  Accuracy: 92.2%, Avg loss: 0.269022
#
# Test Error:
#  Accuracy: 91.9%, Avg loss: 0.270776
#
# Epoch 36
# -------------------------------
# Training Error:
#  Accuracy: 92.5%, Avg loss: 0.260857
#
# Test Error:
#  Accuracy: 92.2%, Avg loss: 0.263441
#
# Epoch 37
# -------------------------------
# Training Error:
#  Accuracy: 92.7%, Avg loss: 0.253101
#
# Test Error:
#  Accuracy: 92.4%, Avg loss: 0.256500
#
# Epoch 38
# -------------------------------
# Training Error:
#  Accuracy: 92.8%, Avg loss: 0.245654
#
# Test Error:
#  Accuracy: 92.6%, Avg loss: 0.249886
#
# Epoch 39
# -------------------------------
# Training Error:
#  Accuracy: 93.1%, Avg loss: 0.238657
#
# Test Error:
#  Accuracy: 92.8%, Avg loss: 0.243782
#
# Epoch 40
# -------------------------------
# Training Error:
#  Accuracy: 93.3%, Avg loss: 0.231921
#
# Test Error:
#  Accuracy: 92.9%, Avg loss: 0.237911
#
# Epoch 41
# -------------------------------
# Training Error:
#  Accuracy: 93.4%, Avg loss: 0.225569
#
# Test Error:
#  Accuracy: 93.1%, Avg loss: 0.232410
#
# Epoch 42
# -------------------------------
# Training Error:
#  Accuracy: 93.6%, Avg loss: 0.219350
#
# Test Error:
#  Accuracy: 93.3%, Avg loss: 0.227007
#
# Epoch 43
# -------------------------------
# Training Error:
#  Accuracy: 93.8%, Avg loss: 0.213369
#
# Test Error:
#  Accuracy: 93.3%, Avg loss: 0.221920
#
# Epoch 44
# -------------------------------
# Training Error:
#  Accuracy: 93.9%, Avg loss: 0.207637
#
# Test Error:
#  Accuracy: 93.5%, Avg loss: 0.217031
#
# Epoch 45
# -------------------------------
# Training Error:
#  Accuracy: 94.1%, Avg loss: 0.202040
#
# Test Error:
#  Accuracy: 93.6%, Avg loss: 0.212256
#
# Epoch 46
# -------------------------------
# Training Error:
#  Accuracy: 94.2%, Avg loss: 0.196620
#
# Test Error:
#  Accuracy: 93.8%, Avg loss: 0.207563
#
# Epoch 47
# -------------------------------
# Training Error:
#  Accuracy: 94.3%, Avg loss: 0.191478
#
# Test Error:
#  Accuracy: 93.8%, Avg loss: 0.203124
#
# Epoch 48
# -------------------------------
# Training Error:
#  Accuracy: 94.5%, Avg loss: 0.186470
#
# Test Error:
#  Accuracy: 93.9%, Avg loss: 0.198816
#
# Epoch 49
# -------------------------------
# Training Error:
#  Accuracy: 94.7%, Avg loss: 0.181708
#
# Test Error:
#  Accuracy: 94.0%, Avg loss: 0.194686
#
# Epoch 50
# -------------------------------
# Training Error:
#  Accuracy: 94.8%, Avg loss: 0.177130
#
# Test Error:
#  Accuracy: 94.1%, Avg loss: 0.190705
#
# Epoch 51
# -------------------------------
# Training Error:
#  Accuracy: 95.0%, Avg loss: 0.172699
#
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.186880
#
# Epoch 52
# -------------------------------
# Training Error:
#  Accuracy: 95.1%, Avg loss: 0.168490
#
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.183269
#
# Epoch 53
# -------------------------------
# Training Error:
#  Accuracy: 95.2%, Avg loss: 0.164437
#
# Test Error:
#  Accuracy: 94.5%, Avg loss: 0.179837
#
# Epoch 54
# -------------------------------
# Training Error:
#  Accuracy: 95.3%, Avg loss: 0.160606
#
# Test Error:
#  Accuracy: 94.6%, Avg loss: 0.176636
#
# Epoch 55
# -------------------------------
# Training Error:
#  Accuracy: 95.4%, Avg loss: 0.156861
#
# Test Error:
#  Accuracy: 94.7%, Avg loss: 0.173450
#
# Epoch 56
# -------------------------------
# Training Error:
#  Accuracy: 95.6%, Avg loss: 0.153309
#
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.170476
#
# Epoch 57
# -------------------------------
# Training Error:
#  Accuracy: 95.6%, Avg loss: 0.149946
#
# Test Error:
#  Accuracy: 94.9%, Avg loss: 0.167681
#
# Epoch 58
# -------------------------------
# Training Error:
#  Accuracy: 95.7%, Avg loss: 0.146663
#
# Test Error:
#  Accuracy: 95.0%, Avg loss: 0.164932
#
# Epoch 59
# -------------------------------
# Training Error:
#  Accuracy: 95.8%, Avg loss: 0.143548
#
# Test Error:
#  Accuracy: 95.1%, Avg loss: 0.162379
#
# Epoch 60
# -------------------------------
# Training Error:
#  Accuracy: 95.9%, Avg loss: 0.140581
#
# Test Error:
#  Accuracy: 95.1%, Avg loss: 0.160001
#
# Epoch 61
# -------------------------------
# Training Error:
#  Accuracy: 96.0%, Avg loss: 0.137697
#
# Test Error:
#  Accuracy: 95.2%, Avg loss: 0.157681
#
# Epoch 62
# -------------------------------
# Training Error:
#  Accuracy: 96.1%, Avg loss: 0.134991
#
# Test Error:
#  Accuracy: 95.2%, Avg loss: 0.155543
#
# Epoch 63
# -------------------------------
# Training Error:
#  Accuracy: 96.2%, Avg loss: 0.132395
#
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.153483
#
# Epoch 64
# -------------------------------
# Training Error:
#  Accuracy: 96.2%, Avg loss: 0.129861
#
# Test Error:
#  Accuracy: 95.4%, Avg loss: 0.151509
#
# Epoch 65
# -------------------------------
# Training Error:
#  Accuracy: 96.3%, Avg loss: 0.127403
#
# Test Error:
#  Accuracy: 95.5%, Avg loss: 0.149577
#
# Epoch 66
# -------------------------------
# Training Error:
#  Accuracy: 96.4%, Avg loss: 0.124983
#
# Test Error:
#  Accuracy: 95.5%, Avg loss: 0.147721
#
# Epoch 67
# -------------------------------
# Training Error:
#  Accuracy: 96.5%, Avg loss: 0.122654
#
# Test Error:
#  Accuracy: 95.6%, Avg loss: 0.145974
#
# Epoch 68
# -------------------------------
# Training Error:
#  Accuracy: 96.5%, Avg loss: 0.120441
#
# Test Error:
#  Accuracy: 95.7%, Avg loss: 0.144321
#
# Epoch 69
# -------------------------------
# Training Error:
#  Accuracy: 96.6%, Avg loss: 0.118261
#
# Test Error:
#  Accuracy: 95.7%, Avg loss: 0.142693
#
# Epoch 70
# -------------------------------
# Training Error:
#  Accuracy: 96.7%, Avg loss: 0.116165
#
# Test Error:
#  Accuracy: 95.8%, Avg loss: 0.141147
#
# Epoch 71
# -------------------------------
# Training Error:
#  Accuracy: 96.7%, Avg loss: 0.114142
#
# Test Error:
#  Accuracy: 95.8%, Avg loss: 0.139720
#
# Epoch 72
# -------------------------------
# Training Error:
#  Accuracy: 96.8%, Avg loss: 0.112157
#
# Test Error:
#  Accuracy: 95.8%, Avg loss: 0.138323
#
# Epoch 73
# -------------------------------
# Training Error:
#  Accuracy: 96.8%, Avg loss: 0.110204
#
# Test Error:
#  Accuracy: 95.9%, Avg loss: 0.136973
#
# Epoch 74
# -------------------------------
# Training Error:
#  Accuracy: 96.9%, Avg loss: 0.108367
#
# Test Error:
#  Accuracy: 95.9%, Avg loss: 0.135768
#
# Epoch 75
# -------------------------------
# Training Error:
#  Accuracy: 96.9%, Avg loss: 0.106526
#
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.134485
#
# Epoch 76
# -------------------------------
# Training Error:
#  Accuracy: 97.0%, Avg loss: 0.104783
#
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.133342
#
# Epoch 77
# -------------------------------
# Training Error:
#  Accuracy: 97.0%, Avg loss: 0.103069
#
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.132211
#
# Epoch 78
# -------------------------------
# Training Error:
#  Accuracy: 97.1%, Avg loss: 0.101416
#
# Test Error:
#  Accuracy: 96.1%, Avg loss: 0.131158
#
# Epoch 79
# -------------------------------
# Training Error:
#  Accuracy: 97.1%, Avg loss: 0.099808
#
# Test Error:
#  Accuracy: 96.1%, Avg loss: 0.130130
#
# Epoch 80
# -------------------------------
# Training Error:
#  Accuracy: 97.1%, Avg loss: 0.098208
#
# Test Error:
#  Accuracy: 96.2%, Avg loss: 0.129096
#
# Epoch 81
# -------------------------------
# Training Error:
#  Accuracy: 97.2%, Avg loss: 0.096663
#
# Test Error:
#  Accuracy: 96.2%, Avg loss: 0.128170
#
# Epoch 82
# -------------------------------
# Training Error:
#  Accuracy: 97.2%, Avg loss: 0.095152
#
# Test Error:
#  Accuracy: 96.2%, Avg loss: 0.127315
#
# Epoch 83
# -------------------------------
# Training Error:
#  Accuracy: 97.3%, Avg loss: 0.093675
#
# Test Error:
#  Accuracy: 96.2%, Avg loss: 0.126521
#
# Epoch 84
# -------------------------------
# Training Error:
#  Accuracy: 97.4%, Avg loss: 0.092218
#
# Test Error:
#  Accuracy: 96.2%, Avg loss: 0.125675
#
# Epoch 85
# -------------------------------
# Training Error:
#  Accuracy: 97.4%, Avg loss: 0.090780
#
# Test Error:
#  Accuracy: 96.3%, Avg loss: 0.124879
#
# Epoch 86
# -------------------------------
# Training Error:
#  Accuracy: 97.4%, Avg loss: 0.089412
#
# Test Error:
#  Accuracy: 96.3%, Avg loss: 0.124082
#
# Epoch 87
# -------------------------------
# Training Error:
#  Accuracy: 97.5%, Avg loss: 0.088076
#
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.123408
#
# Epoch 88
# -------------------------------
# Training Error:
#  Accuracy: 97.5%, Avg loss: 0.086772
#
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.122726
#
# Epoch 89
# -------------------------------
# Training Error:
#  Accuracy: 97.5%, Avg loss: 0.085458
#
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.122012
#
# Epoch 90
# -------------------------------
# Training Error:
#  Accuracy: 97.6%, Avg loss: 0.084208
#
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.121372
#
# Epoch 91
# -------------------------------
# Training Error:
#  Accuracy: 97.6%, Avg loss: 0.082940
#
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.120740
#
# Epoch 92
# -------------------------------
# Training Error:
#  Accuracy: 97.6%, Avg loss: 0.081653
#
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.120089
#
# Epoch 93
# -------------------------------
# Training Error:
#  Accuracy: 97.7%, Avg loss: 0.080414
#
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.119445
#
# Epoch 94
# -------------------------------
# Training Error:
#  Accuracy: 97.7%, Avg loss: 0.079223
#
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.118864
#
# Epoch 95
# -------------------------------
# Training Error:
#  Accuracy: 97.8%, Avg loss: 0.078128
#
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.118400
#
# Epoch 96
# -------------------------------
# Training Error:
#  Accuracy: 97.8%, Avg loss: 0.076980
#
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.117836
#
# Epoch 97
# -------------------------------
# Training Error:
#  Accuracy: 97.8%, Avg loss: 0.075906
#
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.117374
#
# Epoch 98
# -------------------------------
# Training Error:
#  Accuracy: 97.9%, Avg loss: 0.074793
#
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.116875
#
# Epoch 99
# -------------------------------
# Training Error:
#  Accuracy: 97.9%, Avg loss: 0.073689
#
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.116310
#
# Epoch 100
# -------------------------------
# Training Error:
#  Accuracy: 97.9%, Avg loss: 0.072651
#
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.115919
#
# Training w256
# Epoch 1
# -------------------------------
# Training Error:
#  Accuracy: 11.2%, Avg loss: 2.299601
#
# Test Error:
#  Accuracy: 11.4%, Avg loss: 2.299511
#
# Epoch 2
# -------------------------------
# Training Error:
#  Accuracy: 11.2%, Avg loss: 2.296481
#
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.296293
#
# Epoch 3
# -------------------------------
# Training Error:
#  Accuracy: 11.2%, Avg loss: 2.292709
#
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.292424
#
# Epoch 4
# -------------------------------
# Training Error:
#  Accuracy: 11.2%, Avg loss: 2.287545
#
# Test Error:
#  Accuracy: 11.3%, Avg loss: 2.287140
#
# Epoch 5
# -------------------------------
# Training Error:
#  Accuracy: 11.3%, Avg loss: 2.279635
#
# Test Error:
#  Accuracy: 11.4%, Avg loss: 2.279052
#
# Epoch 6
# -------------------------------
# Training Error:
#  Accuracy: 17.0%, Avg loss: 2.266055
#
# Test Error:
#  Accuracy: 17.3%, Avg loss: 2.265183
#
# Epoch 7
# -------------------------------
# Training Error:
#  Accuracy: 30.4%, Avg loss: 2.239833
#
# Test Error:
#  Accuracy: 31.4%, Avg loss: 2.238489
#
# Epoch 8
# -------------------------------
# Training Error:
#  Accuracy: 40.3%, Avg loss: 2.177790
#
# Test Error:
#  Accuracy: 40.4%, Avg loss: 2.175327
#
# Epoch 9
# -------------------------------
# Training Error:
#  Accuracy: 45.6%, Avg loss: 1.975134
#
# Test Error:
#  Accuracy: 45.9%, Avg loss: 1.968820
#
# Epoch 10
# -------------------------------
# Training Error:
#  Accuracy: 60.6%, Avg loss: 1.401055
#
# Test Error:
#  Accuracy: 61.0%, Avg loss: 1.385748
#
# Epoch 11
# -------------------------------
# Training Error:
#  Accuracy: 70.9%, Avg loss: 0.939022
#
# Test Error:
#  Accuracy: 71.5%, Avg loss: 0.920950
#
# Epoch 12
# -------------------------------
# Training Error:
#  Accuracy: 76.0%, Avg loss: 0.754322
#
# Test Error:
#  Accuracy: 76.8%, Avg loss: 0.736235
#
# Epoch 13
# -------------------------------
# Training Error:
#  Accuracy: 79.1%, Avg loss: 0.669931
#
# Test Error:
#  Accuracy: 79.5%, Avg loss: 0.652459
#
# Epoch 14
# -------------------------------
# Training Error:
#  Accuracy: 81.2%, Avg loss: 0.616744
#
# Test Error:
#  Accuracy: 81.7%, Avg loss: 0.600114
#
# Epoch 15
# -------------------------------
# Training Error:
#  Accuracy: 82.8%, Avg loss: 0.575347
#
# Test Error:
#  Accuracy: 83.3%, Avg loss: 0.559696
#
# Epoch 16
# -------------------------------
# Training Error:
#  Accuracy: 84.1%, Avg loss: 0.539012
#
# Test Error:
#  Accuracy: 84.5%, Avg loss: 0.524497
#
# Epoch 17
# -------------------------------
# Training Error:
#  Accuracy: 85.3%, Avg loss: 0.504857
#
# Test Error:
#  Accuracy: 85.7%, Avg loss: 0.491487
#
# Epoch 18
# -------------------------------
# Training Error:
#  Accuracy: 86.3%, Avg loss: 0.472550
#
# Test Error:
#  Accuracy: 86.6%, Avg loss: 0.460322
#
# Epoch 19
# -------------------------------
# Training Error:
#  Accuracy: 87.2%, Avg loss: 0.444017
#
# Test Error:
#  Accuracy: 87.3%, Avg loss: 0.432773
#
# Epoch 20
# -------------------------------
# Training Error:
#  Accuracy: 87.8%, Avg loss: 0.420354
#
# Test Error:
#  Accuracy: 88.1%, Avg loss: 0.409984
#
# Epoch 21
# -------------------------------
# Training Error:
#  Accuracy: 88.4%, Avg loss: 0.400767
#
# Test Error:
#  Accuracy: 88.6%, Avg loss: 0.391244
#
# Epoch 22
# -------------------------------
# Training Error:
#  Accuracy: 88.9%, Avg loss: 0.383907
#
# Test Error:
#  Accuracy: 89.0%, Avg loss: 0.375220
#
# Epoch 23
# -------------------------------
# Training Error:
#  Accuracy: 89.3%, Avg loss: 0.368913
#
# Test Error:
#  Accuracy: 89.4%, Avg loss: 0.361042
#
# Epoch 24
# -------------------------------
# Training Error:
#  Accuracy: 89.7%, Avg loss: 0.355171
#
# Test Error:
#  Accuracy: 89.7%, Avg loss: 0.348069
#
# Epoch 25
# -------------------------------
# Training Error:
#  Accuracy: 90.0%, Avg loss: 0.342255
#
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.335855
#
# Epoch 26
# -------------------------------
# Training Error:
#  Accuracy: 90.4%, Avg loss: 0.330130
#
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.324423
#
# Epoch 27
# -------------------------------
# Training Error:
#  Accuracy: 90.8%, Avg loss: 0.318687
#
# Test Error:
#  Accuracy: 90.7%, Avg loss: 0.313581
#
# Epoch 28
# -------------------------------
# Training Error:
#  Accuracy: 91.1%, Avg loss: 0.307874
#
# Test Error:
#  Accuracy: 91.2%, Avg loss: 0.303412
#
# Epoch 29
# -------------------------------
# Training Error:
#  Accuracy: 91.4%, Avg loss: 0.297598
#
# Test Error:
#  Accuracy: 91.4%, Avg loss: 0.293766
#
# Epoch 30
# -------------------------------
# Training Error:
#  Accuracy: 91.7%, Avg loss: 0.287821
#
# Test Error:
#  Accuracy: 91.6%, Avg loss: 0.284538
#
# Epoch 31
# -------------------------------
# Training Error:
#  Accuracy: 92.0%, Avg loss: 0.278492
#
# Test Error:
#  Accuracy: 91.8%, Avg loss: 0.275747
#
# Epoch 32
# -------------------------------
# Training Error:
#  Accuracy: 92.2%, Avg loss: 0.269597
#
# Test Error:
#  Accuracy: 92.2%, Avg loss: 0.267396
#
# Epoch 33
# -------------------------------
# Training Error:
#  Accuracy: 92.5%, Avg loss: 0.261060
#
# Test Error:
#  Accuracy: 92.3%, Avg loss: 0.259378
#
# Epoch 34
# -------------------------------
# Training Error:
#  Accuracy: 92.7%, Avg loss: 0.252977
#
# Test Error:
#  Accuracy: 92.6%, Avg loss: 0.251819
#
# Epoch 35
# -------------------------------
# Training Error:
#  Accuracy: 92.9%, Avg loss: 0.245213
#
# Test Error:
#  Accuracy: 92.8%, Avg loss: 0.244560
#
# Epoch 36
# -------------------------------
# Training Error:
#  Accuracy: 93.1%, Avg loss: 0.237786
#
# Test Error:
#  Accuracy: 93.0%, Avg loss: 0.237659
#
# Epoch 37
# -------------------------------
# Training Error:
#  Accuracy: 93.3%, Avg loss: 0.230637
#
# Test Error:
#  Accuracy: 93.2%, Avg loss: 0.231035
#
# Epoch 38
# -------------------------------
# Training Error:
#  Accuracy: 93.5%, Avg loss: 0.223817
#
# Test Error:
#  Accuracy: 93.4%, Avg loss: 0.224718
#
# Epoch 39
# -------------------------------
# Training Error:
#  Accuracy: 93.8%, Avg loss: 0.217318
#
# Test Error:
#  Accuracy: 93.6%, Avg loss: 0.218721
#
# Epoch 40
# -------------------------------
# Training Error:
#  Accuracy: 94.0%, Avg loss: 0.211039
#
# Test Error:
#  Accuracy: 93.7%, Avg loss: 0.212889
#
# Epoch 41
# -------------------------------
# Training Error:
#  Accuracy: 94.1%, Avg loss: 0.205047
#
# Test Error:
#  Accuracy: 93.9%, Avg loss: 0.207337
#
# Epoch 42
# -------------------------------
# Training Error:
#  Accuracy: 94.3%, Avg loss: 0.199336
#
# Test Error:
#  Accuracy: 94.1%, Avg loss: 0.202068
#
# Epoch 43
# -------------------------------
# Training Error:
#  Accuracy: 94.4%, Avg loss: 0.193850
#
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.197037
#
# Epoch 44
# -------------------------------
# Training Error:
#  Accuracy: 94.6%, Avg loss: 0.188628
#
# Test Error:
#  Accuracy: 94.4%, Avg loss: 0.192266
#
# Epoch 45
# -------------------------------
# Training Error:
#  Accuracy: 94.7%, Avg loss: 0.183582
#
# Test Error:
#  Accuracy: 94.6%, Avg loss: 0.187671
#
# Epoch 46
# -------------------------------
# Training Error:
#  Accuracy: 94.9%, Avg loss: 0.178857
#
# Test Error:
#  Accuracy: 94.7%, Avg loss: 0.183411
#
# Epoch 47
# -------------------------------
# Training Error:
#  Accuracy: 95.0%, Avg loss: 0.174271
#
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.179280
#
# Epoch 48
# -------------------------------
# Training Error:
#  Accuracy: 95.2%, Avg loss: 0.169884
#
# Test Error:
#  Accuracy: 94.9%, Avg loss: 0.175389
#
# Epoch 49
# -------------------------------
# Training Error:
#  Accuracy: 95.3%, Avg loss: 0.165717
#
# Test Error:
#  Accuracy: 95.0%, Avg loss: 0.171727
#
# Epoch 50
# -------------------------------
# Training Error:
#  Accuracy: 95.4%, Avg loss: 0.161711
#
# Test Error:
#  Accuracy: 95.2%, Avg loss: 0.168275
#
# Epoch 51
# -------------------------------
# Training Error:
#  Accuracy: 95.5%, Avg loss: 0.157887
#
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.165019
#
# Epoch 52
# -------------------------------
# Training Error:
#  Accuracy: 95.6%, Avg loss: 0.154213
#
# Test Error:
#  Accuracy: 95.4%, Avg loss: 0.161920
#
# Epoch 53
# -------------------------------
# Training Error:
#  Accuracy: 95.8%, Avg loss: 0.150691
#
# Test Error:
#  Accuracy: 95.4%, Avg loss: 0.158957
#
# Epoch 54
# -------------------------------
# Training Error:
#  Accuracy: 95.9%, Avg loss: 0.147284
#
# Test Error:
#  Accuracy: 95.5%, Avg loss: 0.156146
#
# Epoch 55
# -------------------------------
# Training Error:
#  Accuracy: 96.0%, Avg loss: 0.144032
#
# Test Error:
#  Accuracy: 95.5%, Avg loss: 0.153478
#
# Epoch 56
# -------------------------------
# Training Error:
#  Accuracy: 96.1%, Avg loss: 0.140920
#
# Test Error:
#  Accuracy: 95.6%, Avg loss: 0.150924
#
# Epoch 57
# -------------------------------
# Training Error:
#  Accuracy: 96.2%, Avg loss: 0.137943
#
# Test Error:
#  Accuracy: 95.7%, Avg loss: 0.148548
#
# Epoch 58
# -------------------------------
# Training Error:
#  Accuracy: 96.2%, Avg loss: 0.135094
#
# Test Error:
#  Accuracy: 95.7%, Avg loss: 0.146323
#
# Epoch 59
# -------------------------------
# Training Error:
#  Accuracy: 96.3%, Avg loss: 0.132332
#
# Test Error:
#  Accuracy: 95.8%, Avg loss: 0.144217
#
# Epoch 60
# -------------------------------
# Training Error:
#  Accuracy: 96.4%, Avg loss: 0.129635
#
# Test Error:
#  Accuracy: 95.9%, Avg loss: 0.142212
#
# Epoch 61
# -------------------------------
# Training Error:
#  Accuracy: 96.4%, Avg loss: 0.127018
#
# Test Error:
#  Accuracy: 95.9%, Avg loss: 0.140309
#
# Epoch 62
# -------------------------------
# Training Error:
#  Accuracy: 96.5%, Avg loss: 0.124510
#
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.138532
#
# Epoch 63
# -------------------------------
# Training Error:
#  Accuracy: 96.5%, Avg loss: 0.122074
#
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.136805
#
# Epoch 64
# -------------------------------
# Training Error:
#  Accuracy: 96.6%, Avg loss: 0.119720
#
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.135188
#
# Epoch 65
# -------------------------------
# Training Error:
#  Accuracy: 96.7%, Avg loss: 0.117412
#
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.133626
#
# Epoch 66
# -------------------------------
# Training Error:
#  Accuracy: 96.7%, Avg loss: 0.115180
#
# Test Error:
#  Accuracy: 96.1%, Avg loss: 0.132139
#
# Epoch 67
# -------------------------------
# Training Error:
#  Accuracy: 96.8%, Avg loss: 0.113030
#
# Test Error:
#  Accuracy: 96.1%, Avg loss: 0.130759
#
# Epoch 68
# -------------------------------
# Training Error:
#  Accuracy: 96.8%, Avg loss: 0.110931
#
# Test Error:
#  Accuracy: 96.2%, Avg loss: 0.129407
#
# Epoch 69
# -------------------------------
# Training Error:
#  Accuracy: 96.9%, Avg loss: 0.108890
#
# Test Error:
#  Accuracy: 96.2%, Avg loss: 0.128139
#
# Epoch 70
# -------------------------------
# Training Error:
#  Accuracy: 97.0%, Avg loss: 0.106901
#
# Test Error:
#  Accuracy: 96.2%, Avg loss: 0.126909
#
# Epoch 71
# -------------------------------
# Training Error:
#  Accuracy: 97.0%, Avg loss: 0.104952
#
# Test Error:
#  Accuracy: 96.3%, Avg loss: 0.125725
#
# Epoch 72
# -------------------------------
# Training Error:
#  Accuracy: 97.1%, Avg loss: 0.103069
#
# Test Error:
#  Accuracy: 96.3%, Avg loss: 0.124592
#
# Epoch 73
# -------------------------------
# Training Error:
#  Accuracy: 97.1%, Avg loss: 0.101228
#
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.123481
#
# Epoch 74
# -------------------------------
# Training Error:
#  Accuracy: 97.2%, Avg loss: 0.099442
#
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.122449
#
# Epoch 75
# -------------------------------
# Training Error:
#  Accuracy: 97.2%, Avg loss: 0.097701
#
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.121464
#
# Epoch 76
# -------------------------------
# Training Error:
#  Accuracy: 97.2%, Avg loss: 0.095995
#
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.120530
#
# Epoch 77
# -------------------------------
# Training Error:
#  Accuracy: 97.3%, Avg loss: 0.094318
#
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.119616
#
# Epoch 78
# -------------------------------
# Training Error:
#  Accuracy: 97.3%, Avg loss: 0.092679
#
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.118703
#
# Epoch 79
# -------------------------------
# Training Error:
#  Accuracy: 97.4%, Avg loss: 0.091085
#
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.117844
#
# Epoch 80
# -------------------------------
# Training Error:
#  Accuracy: 97.4%, Avg loss: 0.089511
#
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.117013
#
# Epoch 81
# -------------------------------
# Training Error:
#  Accuracy: 97.5%, Avg loss: 0.087990
#
# Test Error:
#  Accuracy: 96.6%, Avg loss: 0.116228
#
# Epoch 82
# -------------------------------
# Training Error:
#  Accuracy: 97.5%, Avg loss: 0.086484
#
# Test Error:
#  Accuracy: 96.6%, Avg loss: 0.115449
#
# Epoch 83
# -------------------------------
# Training Error:
#  Accuracy: 97.6%, Avg loss: 0.085012
#
# Test Error:
#  Accuracy: 96.6%, Avg loss: 0.114679
#
# Epoch 84
# -------------------------------
# Training Error:
#  Accuracy: 97.6%, Avg loss: 0.083539
#
# Test Error:
#  Accuracy: 96.6%, Avg loss: 0.113917
#
# Epoch 85
# -------------------------------
# Training Error:
#  Accuracy: 97.7%, Avg loss: 0.082142
#
# Test Error:
#  Accuracy: 96.6%, Avg loss: 0.113223
#
# Epoch 86
# -------------------------------
# Training Error:
#  Accuracy: 97.7%, Avg loss: 0.080728
#
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.112486
#
# Epoch 87
# -------------------------------
# Training Error:
#  Accuracy: 97.8%, Avg loss: 0.079335
#
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.111805
#
# Epoch 88
# -------------------------------
# Training Error:
#  Accuracy: 97.8%, Avg loss: 0.077989
#
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.111110
#
# Epoch 89
# -------------------------------
# Training Error:
#  Accuracy: 97.8%, Avg loss: 0.076668
#
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.110525
#
# Epoch 90
# -------------------------------
# Training Error:
#  Accuracy: 97.9%, Avg loss: 0.075378
#
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.109915
#
# Epoch 91
# -------------------------------
# Training Error:
#  Accuracy: 97.9%, Avg loss: 0.074116
#
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.109357
#
# Epoch 92
# -------------------------------
# Training Error:
#  Accuracy: 97.9%, Avg loss: 0.072874
#
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.108771
#
# Epoch 93
# -------------------------------
# Training Error:
#  Accuracy: 98.0%, Avg loss: 0.071652
#
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.108248
#
# Epoch 94
# -------------------------------
# Training Error:
#  Accuracy: 98.0%, Avg loss: 0.070458
#
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.107718
#
# Epoch 95
# -------------------------------
# Training Error:
#  Accuracy: 98.1%, Avg loss: 0.069249
#
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.107210
#
# Epoch 96
# -------------------------------
# Training Error:
#  Accuracy: 98.1%, Avg loss: 0.068080
#
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.106714
#
# Epoch 97
# -------------------------------
# Training Error:
#  Accuracy: 98.1%, Avg loss: 0.066945
#
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.106247
#
# Epoch 98
# -------------------------------
# Training Error:
#  Accuracy: 98.2%, Avg loss: 0.065819
#
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.105763
#
# Epoch 99
# -------------------------------
# Training Error:
#  Accuracy: 98.2%, Avg loss: 0.064700
#
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.105301
#
# Epoch 100
# -------------------------------
# Training Error:
#  Accuracy: 98.2%, Avg loss: 0.063632
#
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.104842
#
# Training w512
# Epoch 1
# -------------------------------
# Training Error:
#  Accuracy: 21.0%, Avg loss: 2.298557
#
# Test Error:
#  Accuracy: 21.2%, Avg loss: 2.298533
#
# Epoch 2
# -------------------------------
# Training Error:
#  Accuracy: 13.3%, Avg loss: 2.294207
#
# Test Error:
#  Accuracy: 13.8%, Avg loss: 2.294081
#
# Epoch 3
# -------------------------------
# Training Error:
#  Accuracy: 14.7%, Avg loss: 2.288600
#
# Test Error:
#  Accuracy: 15.2%, Avg loss: 2.288352
#
# Epoch 4
# -------------------------------
# Training Error:
#  Accuracy: 20.6%, Avg loss: 2.280172
#
# Test Error:
#  Accuracy: 21.0%, Avg loss: 2.279744
#
# Epoch 5
# -------------------------------
# Training Error:
#  Accuracy: 30.1%, Avg loss: 2.265413
#
# Test Error:
#  Accuracy: 30.5%, Avg loss: 2.264695
#
# Epoch 6
# -------------------------------
# Training Error:
#  Accuracy: 40.0%, Avg loss: 2.235004
#
# Test Error:
#  Accuracy: 39.9%, Avg loss: 2.233767
#
# Epoch 7
# -------------------------------
# Training Error:
#  Accuracy: 44.6%, Avg loss: 2.155693
#
# Test Error:
#  Accuracy: 43.6%, Avg loss: 2.153232
#
# Epoch 8
# -------------------------------
# Training Error:
#  Accuracy: 45.8%, Avg loss: 1.884000
#
# Test Error:
#  Accuracy: 44.8%, Avg loss: 1.878188
#
# Epoch 9
# -------------------------------
# Training Error:
#  Accuracy: 63.2%, Avg loss: 1.336059
#
# Test Error:
#  Accuracy: 63.5%, Avg loss: 1.326959
#
# Epoch 10
# -------------------------------
# Training Error:
#  Accuracy: 72.1%, Avg loss: 0.920699
#
# Test Error:
#  Accuracy: 72.1%, Avg loss: 0.913245
#
# Epoch 11
# -------------------------------
# Training Error:
#  Accuracy: 78.2%, Avg loss: 0.715558
#
# Test Error:
#  Accuracy: 78.2%, Avg loss: 0.706049
#
# Epoch 12
# -------------------------------
# Training Error:
#  Accuracy: 81.7%, Avg loss: 0.607272
#
# Test Error:
#  Accuracy: 82.1%, Avg loss: 0.594821
#
# Epoch 13
# -------------------------------
# Training Error:
#  Accuracy: 83.8%, Avg loss: 0.539764
#
# Test Error:
#  Accuracy: 84.4%, Avg loss: 0.525666
#
# Epoch 14
# -------------------------------
# Training Error:
#  Accuracy: 85.3%, Avg loss: 0.495050
#
# Test Error:
#  Accuracy: 85.4%, Avg loss: 0.480850
#
# Epoch 15
# -------------------------------
# Training Error:
#  Accuracy: 86.2%, Avg loss: 0.462682
#
# Test Error:
#  Accuracy: 86.6%, Avg loss: 0.449233
#
# Epoch 16
# -------------------------------
# Training Error:
#  Accuracy: 87.0%, Avg loss: 0.437001
#
# Test Error:
#  Accuracy: 87.4%, Avg loss: 0.424687
#
# Epoch 17
# -------------------------------
# Training Error:
#  Accuracy: 87.8%, Avg loss: 0.415489
#
# Test Error:
#  Accuracy: 87.9%, Avg loss: 0.404468
#
# Epoch 18
# -------------------------------
# Training Error:
#  Accuracy: 88.4%, Avg loss: 0.396964
#
# Test Error:
#  Accuracy: 88.4%, Avg loss: 0.387258
#
# Epoch 19
# -------------------------------
# Training Error:
#  Accuracy: 89.0%, Avg loss: 0.380734
#
# Test Error:
#  Accuracy: 88.9%, Avg loss: 0.372247
#
# Epoch 20
# -------------------------------
# Training Error:
#  Accuracy: 89.4%, Avg loss: 0.366280
#
# Test Error:
#  Accuracy: 89.3%, Avg loss: 0.358869
#
# Epoch 21
# -------------------------------
# Training Error:
#  Accuracy: 89.8%, Avg loss: 0.353187
#
# Test Error:
#  Accuracy: 89.7%, Avg loss: 0.346720
#
# Epoch 22
# -------------------------------
# Training Error:
#  Accuracy: 90.1%, Avg loss: 0.341170
#
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.335471
#
# Epoch 23
# -------------------------------
# Training Error:
#  Accuracy: 90.4%, Avg loss: 0.330053
#
# Test Error:
#  Accuracy: 90.4%, Avg loss: 0.324999
#
# Epoch 24
# -------------------------------
# Training Error:
#  Accuracy: 90.7%, Avg loss: 0.319686
#
# Test Error:
#  Accuracy: 90.7%, Avg loss: 0.315176
#
# Epoch 25
# -------------------------------
# Training Error:
#  Accuracy: 91.0%, Avg loss: 0.309922
#
# Test Error:
#  Accuracy: 91.0%, Avg loss: 0.305896
#
# Epoch 26
# -------------------------------
# Training Error:
#  Accuracy: 91.3%, Avg loss: 0.300587
#
# Test Error:
#  Accuracy: 91.2%, Avg loss: 0.296959
#
# Epoch 27
# -------------------------------
# Training Error:
#  Accuracy: 91.6%, Avg loss: 0.291642
#
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.288363
#
# Epoch 28
# -------------------------------
# Training Error:
#  Accuracy: 91.8%, Avg loss: 0.283049
#
# Test Error:
#  Accuracy: 91.8%, Avg loss: 0.280103
#
# Epoch 29
# -------------------------------
# Training Error:
#  Accuracy: 92.1%, Avg loss: 0.274754
#
# Test Error:
#  Accuracy: 91.9%, Avg loss: 0.272162
#
# Epoch 30
# -------------------------------
# Training Error:
#  Accuracy: 92.3%, Avg loss: 0.266704
#
# Test Error:
#  Accuracy: 92.1%, Avg loss: 0.264416
#
# Epoch 31
# -------------------------------
# Training Error:
#  Accuracy: 92.5%, Avg loss: 0.258902
#
# Test Error:
#  Accuracy: 92.3%, Avg loss: 0.256893
#
# Epoch 32
# -------------------------------
# Training Error:
#  Accuracy: 92.7%, Avg loss: 0.251328
#
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.249594
#
# Epoch 33
# -------------------------------
# Training Error:
#  Accuracy: 92.9%, Avg loss: 0.244024
#
# Test Error:
#  Accuracy: 92.8%, Avg loss: 0.242554
#
# Epoch 34
# -------------------------------
# Training Error:
#  Accuracy: 93.1%, Avg loss: 0.236917
#
# Test Error:
#  Accuracy: 93.0%, Avg loss: 0.235716
#
# Epoch 35
# -------------------------------
# Training Error:
#  Accuracy: 93.4%, Avg loss: 0.230017
#
# Test Error:
#  Accuracy: 93.2%, Avg loss: 0.229075
#
# Epoch 36
# -------------------------------
# Training Error:
#  Accuracy: 93.6%, Avg loss: 0.223342
#
# Test Error:
#  Accuracy: 93.4%, Avg loss: 0.222663
#
# Epoch 37
# -------------------------------
# Training Error:
#  Accuracy: 93.8%, Avg loss: 0.216869
#
# Test Error:
#  Accuracy: 93.6%, Avg loss: 0.216451
#
# Epoch 38
# -------------------------------
# Training Error:
#  Accuracy: 94.0%, Avg loss: 0.210606
#
# Test Error:
#  Accuracy: 93.8%, Avg loss: 0.210459
#
# Epoch 39
# -------------------------------
# Training Error:
#  Accuracy: 94.1%, Avg loss: 0.204512
#
# Test Error:
#  Accuracy: 94.1%, Avg loss: 0.204654
#
# Epoch 40
# -------------------------------
# Training Error:
#  Accuracy: 94.3%, Avg loss: 0.198644
#
# Test Error:
#  Accuracy: 94.2%, Avg loss: 0.199094
#
# Epoch 41
# -------------------------------
# Training Error:
#  Accuracy: 94.4%, Avg loss: 0.193004
#
# Test Error:
#  Accuracy: 94.4%, Avg loss: 0.193755
#
# Epoch 42
# -------------------------------
# Training Error:
#  Accuracy: 94.6%, Avg loss: 0.187557
#
# Test Error:
#  Accuracy: 94.4%, Avg loss: 0.188637
#
# Epoch 43
# -------------------------------
# Training Error:
#  Accuracy: 94.8%, Avg loss: 0.182318
#
# Test Error:
#  Accuracy: 94.5%, Avg loss: 0.183743
#
# Epoch 44
# -------------------------------
# Training Error:
#  Accuracy: 94.9%, Avg loss: 0.177257
#
# Test Error:
#  Accuracy: 94.7%, Avg loss: 0.179031
#
# Epoch 45
# -------------------------------
# Training Error:
#  Accuracy: 95.1%, Avg loss: 0.172395
#
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.174545
#
# Epoch 46
# -------------------------------
# Training Error:
#  Accuracy: 95.2%, Avg loss: 0.167720
#
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.170256
#
# Epoch 47
# -------------------------------
# Training Error:
#  Accuracy: 95.3%, Avg loss: 0.163231
#
# Test Error:
#  Accuracy: 95.0%, Avg loss: 0.166194
#
# Epoch 48
# -------------------------------
# Training Error:
#  Accuracy: 95.5%, Avg loss: 0.158920
#
# Test Error:
#  Accuracy: 95.1%, Avg loss: 0.162298
#
# Epoch 49
# -------------------------------
# Training Error:
#  Accuracy: 95.6%, Avg loss: 0.154824
#
# Test Error:
#  Accuracy: 95.2%, Avg loss: 0.158641
#
# Epoch 50
# -------------------------------
# Training Error:
#  Accuracy: 95.7%, Avg loss: 0.150874
#
# Test Error:
#  Accuracy: 95.4%, Avg loss: 0.155136
#
# Epoch 51
# -------------------------------
# Training Error:
#  Accuracy: 95.8%, Avg loss: 0.147090
#
# Test Error:
#  Accuracy: 95.5%, Avg loss: 0.151838
#
# Epoch 52
# -------------------------------
# Training Error:
#  Accuracy: 95.9%, Avg loss: 0.143496
#
# Test Error:
#  Accuracy: 95.6%, Avg loss: 0.148745
#
# Epoch 53
# -------------------------------
# Training Error:
#  Accuracy: 96.0%, Avg loss: 0.140045
#
# Test Error:
#  Accuracy: 95.7%, Avg loss: 0.145813
#
# Epoch 54
# -------------------------------
# Training Error:
#  Accuracy: 96.1%, Avg loss: 0.136721
#
# Test Error:
#  Accuracy: 95.8%, Avg loss: 0.143024
#
# Epoch 55
# -------------------------------
# Training Error:
#  Accuracy: 96.2%, Avg loss: 0.133528
#
# Test Error:
#  Accuracy: 95.8%, Avg loss: 0.140394
#
# Epoch 56
# -------------------------------
# Training Error:
#  Accuracy: 96.3%, Avg loss: 0.130483
#
# Test Error:
#  Accuracy: 95.9%, Avg loss: 0.137935
#
# Epoch 57
# -------------------------------
# Training Error:
#  Accuracy: 96.4%, Avg loss: 0.127517
#
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.135572
#
# Epoch 58
# -------------------------------
# Training Error:
#  Accuracy: 96.4%, Avg loss: 0.124670
#
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.133369
#
# Epoch 59
# -------------------------------
# Training Error:
#  Accuracy: 96.5%, Avg loss: 0.121911
#
# Test Error:
#  Accuracy: 96.1%, Avg loss: 0.131255
#
# Epoch 60
# -------------------------------
# Training Error:
#  Accuracy: 96.6%, Avg loss: 0.119261
#
# Test Error:
#  Accuracy: 96.1%, Avg loss: 0.129256
#
# Epoch 61
# -------------------------------
# Training Error:
#  Accuracy: 96.7%, Avg loss: 0.116667
#
# Test Error:
#  Accuracy: 96.2%, Avg loss: 0.127341
#
# Epoch 62
# -------------------------------
# Training Error:
#  Accuracy: 96.7%, Avg loss: 0.114167
#
# Test Error:
#  Accuracy: 96.3%, Avg loss: 0.125524
#
# Epoch 63
# -------------------------------
# Training Error:
#  Accuracy: 96.8%, Avg loss: 0.111757
#
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.123795
#
# Epoch 64
# -------------------------------
# Training Error:
#  Accuracy: 96.8%, Avg loss: 0.109442
#
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.122166
#
# Epoch 65
# -------------------------------
# Training Error:
#  Accuracy: 96.9%, Avg loss: 0.107207
#
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.120634
#
# Epoch 66
# -------------------------------
# Training Error:
#  Accuracy: 96.9%, Avg loss: 0.105008
#
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.119121
#
# Epoch 67
# -------------------------------
# Training Error:
#  Accuracy: 97.0%, Avg loss: 0.102912
#
# Test Error:
#  Accuracy: 96.6%, Avg loss: 0.117729
#
# Epoch 68
# -------------------------------
# Training Error:
#  Accuracy: 97.1%, Avg loss: 0.100836
#
# Test Error:
#  Accuracy: 96.6%, Avg loss: 0.116353
#
# Epoch 69
# -------------------------------
# Training Error:
#  Accuracy: 97.1%, Avg loss: 0.098816
#
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.115018
#
# Epoch 70
# -------------------------------
# Training Error:
#  Accuracy: 97.2%, Avg loss: 0.096870
#
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.113755
#
# Epoch 71
# -------------------------------
# Training Error:
#  Accuracy: 97.2%, Avg loss: 0.094941
#
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.112524
#
# Epoch 72
# -------------------------------
# Training Error:
#  Accuracy: 97.3%, Avg loss: 0.093080
#
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.111345
#
# Epoch 73
# -------------------------------
# Training Error:
#  Accuracy: 97.3%, Avg loss: 0.091276
#
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.110227
#
# Epoch 74
# -------------------------------
# Training Error:
#  Accuracy: 97.4%, Avg loss: 0.089521
#
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.109138
#
# Epoch 75
# -------------------------------
# Training Error:
#  Accuracy: 97.5%, Avg loss: 0.087802
#
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.108084
#
# Epoch 76
# -------------------------------
# Training Error:
#  Accuracy: 97.5%, Avg loss: 0.086114
#
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.107068
#
# Epoch 77
# -------------------------------
# Training Error:
#  Accuracy: 97.6%, Avg loss: 0.084479
#
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.106098
#
# Epoch 78
# -------------------------------
# Training Error:
#  Accuracy: 97.6%, Avg loss: 0.082887
#
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.105175
#
# Epoch 79
# -------------------------------
# Training Error:
#  Accuracy: 97.7%, Avg loss: 0.081349
#
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.104320
#
# Epoch 80
# -------------------------------
# Training Error:
#  Accuracy: 97.7%, Avg loss: 0.079836
#
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.103442
#
# Epoch 81
# -------------------------------
# Training Error:
#  Accuracy: 97.8%, Avg loss: 0.078363
#
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.102625
#
# Epoch 82
# -------------------------------
# Training Error:
#  Accuracy: 97.8%, Avg loss: 0.076928
#
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.101836
#
# Epoch 83
# -------------------------------
# Training Error:
#  Accuracy: 97.9%, Avg loss: 0.075503
#
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.101044
#
# Epoch 84
# -------------------------------
# Training Error:
#  Accuracy: 97.9%, Avg loss: 0.074125
#
# Test Error:
#  Accuracy: 97.0%, Avg loss: 0.100310
#
# Epoch 85
# -------------------------------
# Training Error:
#  Accuracy: 98.0%, Avg loss: 0.072785
#
# Test Error:
#  Accuracy: 97.0%, Avg loss: 0.099612
#
# Epoch 86
# -------------------------------
# Training Error:
#  Accuracy: 98.0%, Avg loss: 0.071447
#
# Test Error:
#  Accuracy: 97.0%, Avg loss: 0.098880
#
# Epoch 87
# -------------------------------
# Training Error:
#  Accuracy: 98.1%, Avg loss: 0.070164
#
# Test Error:
#  Accuracy: 97.0%, Avg loss: 0.098234
#
# Epoch 88
# -------------------------------
# Training Error:
#  Accuracy: 98.1%, Avg loss: 0.068897
#
# Test Error:
#  Accuracy: 97.1%, Avg loss: 0.097603
#
# Epoch 89
# -------------------------------
# Training Error:
#  Accuracy: 98.2%, Avg loss: 0.067645
#
# Test Error:
#  Accuracy: 97.1%, Avg loss: 0.097003
#
# Epoch 90
# -------------------------------
# Training Error:
#  Accuracy: 98.2%, Avg loss: 0.066442
#
# Test Error:
#  Accuracy: 97.1%, Avg loss: 0.096431
#
# Epoch 91
# -------------------------------
# Training Error:
#  Accuracy: 98.3%, Avg loss: 0.065257
#
# Test Error:
#  Accuracy: 97.1%, Avg loss: 0.095884
#
# Epoch 92
# -------------------------------
# Training Error:
#  Accuracy: 98.3%, Avg loss: 0.064080
#
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.095320
#
# Epoch 93
# -------------------------------
# Training Error:
#  Accuracy: 98.3%, Avg loss: 0.062929
#
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.094795
#
# Epoch 94
# -------------------------------
# Training Error:
#  Accuracy: 98.4%, Avg loss: 0.061794
#
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.094296
#
# Epoch 95
# -------------------------------
# Training Error:
#  Accuracy: 98.4%, Avg loss: 0.060682
#
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.093816
#
# Epoch 96
# -------------------------------
# Training Error:
#  Accuracy: 98.4%, Avg loss: 0.059572
#
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.093319
#
# Epoch 97
# -------------------------------
# Training Error:
#  Accuracy: 98.5%, Avg loss: 0.058502
#
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.092876
#
# Epoch 98
# -------------------------------
# Training Error:
#  Accuracy: 98.5%, Avg loss: 0.057446
#
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.092444
#
# Epoch 99
# -------------------------------
# Training Error:
#  Accuracy: 98.5%, Avg loss: 0.056429
#
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.092042
#
# Epoch 100
# -------------------------------
# Training Error:
#  Accuracy: 98.5%, Avg loss: 0.055406
#
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.091606

# %%
fig, ax = plt.subplots()
fig.set_size_inches(18.5, 10.5)
for m in models:
    epochs = m.epochs
    ax.plot(range(1, epochs+1), m.error_test, label = f"{m.name}: test loss")
    ax.plot(range(1, epochs+1), m.error_training, label = f"{m.name}: training loss")
ax.set_title("Avg error vs Number of Epochs")
ax.set_xlabel("Number of Epochs")
ax.set_ylabel("Average Error")
ax.legend()

# %%
visualise_model_perf(models, title='Avg error vs Number of Epochs');

# %% [markdown]
# <hr>

# %% [markdown]
# ### Demonstrating Model fitting

# %%
models = train_models(load_config('overfitting_demo.json'))
# Out:
# Training model
# Epoch 1
# -------------------------------
# Training Error:
#  Accuracy: 16.8%, Avg loss: 2.293055
#
# Test Error:
#  Accuracy: 16.7%, Avg loss: 2.292735
#
# Epoch 2
# -------------------------------
# Training Error:
#  Accuracy: 20.0%, Avg loss: 2.283338
#
# Test Error:
#  Accuracy: 20.0%, Avg loss: 2.282843
#
# Epoch 3
# -------------------------------
# Training Error:
#  Accuracy: 27.3%, Avg loss: 2.270730
#
# Test Error:
#  Accuracy: 27.2%, Avg loss: 2.269983
#
# Epoch 4
# -------------------------------
# Training Error:
#  Accuracy: 38.0%, Avg loss: 2.252704
#
# Test Error:
#  Accuracy: 38.4%, Avg loss: 2.251581
#
# Epoch 5
# -------------------------------
# Training Error:
#  Accuracy: 47.4%, Avg loss: 2.224827
#
# Test Error:
#  Accuracy: 48.5%, Avg loss: 2.223154
#
# Epoch 6
# -------------------------------
# Training Error:
#  Accuracy: 55.0%, Avg loss: 2.178210
#
# Test Error:
#  Accuracy: 55.4%, Avg loss: 2.175639
#
# Epoch 7
# -------------------------------
# Training Error:
#  Accuracy: 60.1%, Avg loss: 2.093445
#
# Test Error:
#  Accuracy: 61.3%, Avg loss: 2.089293
#
# Epoch 8
# -------------------------------
# Training Error:
#  Accuracy: 62.7%, Avg loss: 1.932574
#
# Test Error:
#  Accuracy: 64.1%, Avg loss: 1.925449
#
# Epoch 9
# -------------------------------
# Training Error:
#  Accuracy: 65.6%, Avg loss: 1.660260
#
# Test Error:
#  Accuracy: 66.7%, Avg loss: 1.648215
#
# Epoch 10
# -------------------------------
# Training Error:
#  Accuracy: 69.4%, Avg loss: 1.331176
#
# Test Error:
#  Accuracy: 70.0%, Avg loss: 1.314781
#
# Epoch 11
# -------------------------------
# Training Error:
#  Accuracy: 73.5%, Avg loss: 1.064935
#
# Test Error:
#  Accuracy: 74.0%, Avg loss: 1.047391
#
# Epoch 12
# -------------------------------
# Training Error:
#  Accuracy: 76.4%, Avg loss: 0.890539
#
# Test Error:
#  Accuracy: 76.6%, Avg loss: 0.873675
#
# Epoch 13
# -------------------------------
# Training Error:
#  Accuracy: 78.5%, Avg loss: 0.777325
#
# Test Error:
#  Accuracy: 78.9%, Avg loss: 0.761459
#
# Epoch 14
# -------------------------------
# Training Error:
#  Accuracy: 80.3%, Avg loss: 0.698682
#
# Test Error:
#  Accuracy: 80.7%, Avg loss: 0.683613
#
# Epoch 15
# -------------------------------
# Training Error:
#  Accuracy: 81.9%, Avg loss: 0.639679
#
# Test Error:
#  Accuracy: 82.3%, Avg loss: 0.625172
#
# Epoch 16
# -------------------------------
# Training Error:
#  Accuracy: 83.1%, Avg loss: 0.592851
#
# Test Error:
#  Accuracy: 83.6%, Avg loss: 0.578710
#
# Epoch 17
# -------------------------------
# Training Error:
#  Accuracy: 84.2%, Avg loss: 0.554605
#
# Test Error:
#  Accuracy: 84.6%, Avg loss: 0.540678
#
# Epoch 18
# -------------------------------
# Training Error:
#  Accuracy: 85.1%, Avg loss: 0.522906
#
# Test Error:
#  Accuracy: 85.4%, Avg loss: 0.509145
#
# Epoch 19
# -------------------------------
# Training Error:
#  Accuracy: 85.9%, Avg loss: 0.496412
#
# Test Error:
#  Accuracy: 86.1%, Avg loss: 0.482836
#
# Epoch 20
# -------------------------------
# Training Error:
#  Accuracy: 86.5%, Avg loss: 0.474105
#
# Test Error:
#  Accuracy: 86.7%, Avg loss: 0.460749
#
# Epoch 21
# -------------------------------
# Training Error:
#  Accuracy: 87.1%, Avg loss: 0.455176
#
# Test Error:
#  Accuracy: 87.3%, Avg loss: 0.442080
#
# Epoch 22
# -------------------------------
# Training Error:
#  Accuracy: 87.6%, Avg loss: 0.438973
#
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.426174
#
# Epoch 23
# -------------------------------
# Training Error:
#  Accuracy: 87.9%, Avg loss: 0.424973
#
# Test Error:
#  Accuracy: 88.1%, Avg loss: 0.412484
#
# Epoch 24
# -------------------------------
# Training Error:
#  Accuracy: 88.3%, Avg loss: 0.412765
#
# Test Error:
#  Accuracy: 88.4%, Avg loss: 0.400583
#
# Epoch 25
# -------------------------------
# Training Error:
#  Accuracy: 88.6%, Avg loss: 0.402034
#
# Test Error:
#  Accuracy: 88.7%, Avg loss: 0.390146
#
# Epoch 26
# -------------------------------
# Training Error:
#  Accuracy: 88.9%, Avg loss: 0.392508
#
# Test Error:
#  Accuracy: 88.9%, Avg loss: 0.380908
#
# Epoch 27
# -------------------------------
# Training Error:
#  Accuracy: 89.1%, Avg loss: 0.383971
#
# Test Error:
#  Accuracy: 89.2%, Avg loss: 0.372655
#
# Epoch 28
# -------------------------------
# Training Error:
#  Accuracy: 89.3%, Avg loss: 0.376262
#
# Test Error:
#  Accuracy: 89.4%, Avg loss: 0.365223
#
# Epoch 29
# -------------------------------
# Training Error:
#  Accuracy: 89.4%, Avg loss: 0.369234
#
# Test Error:
#  Accuracy: 89.6%, Avg loss: 0.358460
#
# Epoch 30
# -------------------------------
# Training Error:
#  Accuracy: 89.6%, Avg loss: 0.362770
#
# Test Error:
#  Accuracy: 89.7%, Avg loss: 0.352248
#
# Epoch 31
# -------------------------------
# Training Error:
#  Accuracy: 89.8%, Avg loss: 0.356776
#
# Test Error:
#  Accuracy: 89.7%, Avg loss: 0.346494
#
# Epoch 32
# -------------------------------
# Training Error:
#  Accuracy: 90.0%, Avg loss: 0.351177
#
# Test Error:
#  Accuracy: 89.9%, Avg loss: 0.341130
#
# Epoch 33
# -------------------------------
# Training Error:
#  Accuracy: 90.1%, Avg loss: 0.345911
#
# Test Error:
#  Accuracy: 90.1%, Avg loss: 0.336094
#
# Epoch 34
# -------------------------------
# Training Error:
#  Accuracy: 90.3%, Avg loss: 0.340924
#
# Test Error:
#  Accuracy: 90.2%, Avg loss: 0.331335
#
# Epoch 35
# -------------------------------
# Training Error:
#  Accuracy: 90.4%, Avg loss: 0.336182
#
# Test Error:
#  Accuracy: 90.4%, Avg loss: 0.326819
#
# Epoch 36
# -------------------------------
# Training Error:
#  Accuracy: 90.5%, Avg loss: 0.331653
#
# Test Error:
#  Accuracy: 90.5%, Avg loss: 0.322522
#
# Epoch 37
# -------------------------------
# Training Error:
#  Accuracy: 90.7%, Avg loss: 0.327307
#
# Test Error:
#  Accuracy: 90.6%, Avg loss: 0.318400
#
# Epoch 38
# -------------------------------
# Training Error:
#  Accuracy: 90.8%, Avg loss: 0.323129
#
# Test Error:
#  Accuracy: 90.7%, Avg loss: 0.314457
#
# Epoch 39
# -------------------------------
# Training Error:
#  Accuracy: 90.9%, Avg loss: 0.319096
#
# Test Error:
#  Accuracy: 90.8%, Avg loss: 0.310655
#
# Epoch 40
# -------------------------------
# Training Error:
#  Accuracy: 91.0%, Avg loss: 0.315186
#
# Test Error:
#  Accuracy: 90.9%, Avg loss: 0.306981
#
# Epoch 41
# -------------------------------
# Training Error:
#  Accuracy: 91.1%, Avg loss: 0.311385
#
# Test Error:
#  Accuracy: 91.0%, Avg loss: 0.303418
#
# Epoch 42
# -------------------------------
# Training Error:
#  Accuracy: 91.2%, Avg loss: 0.307686
#
# Test Error:
#  Accuracy: 91.2%, Avg loss: 0.299952
#
# Epoch 43
# -------------------------------
# Training Error:
#  Accuracy: 91.3%, Avg loss: 0.304069
#
# Test Error:
#  Accuracy: 91.3%, Avg loss: 0.296573
#
# Epoch 44
# -------------------------------
# Training Error:
#  Accuracy: 91.4%, Avg loss: 0.300527
#
# Test Error:
#  Accuracy: 91.3%, Avg loss: 0.293275
#
# Epoch 45
# -------------------------------
# Training Error:
#  Accuracy: 91.5%, Avg loss: 0.297052
#
# Test Error:
#  Accuracy: 91.4%, Avg loss: 0.290042
#
# Epoch 46
# -------------------------------
# Training Error:
#  Accuracy: 91.6%, Avg loss: 0.293644
#
# Test Error:
#  Accuracy: 91.5%, Avg loss: 0.286878
#
# Epoch 47
# -------------------------------
# Training Error:
#  Accuracy: 91.7%, Avg loss: 0.290300
#
# Test Error:
#  Accuracy: 91.6%, Avg loss: 0.283789
#
# Epoch 48
# -------------------------------
# Training Error:
#  Accuracy: 91.8%, Avg loss: 0.287014
#
# Test Error:
#  Accuracy: 91.7%, Avg loss: 0.280759
#
# Epoch 49
# -------------------------------
# Training Error:
#  Accuracy: 91.9%, Avg loss: 0.283778
#
# Test Error:
#  Accuracy: 91.9%, Avg loss: 0.277773
#
# Epoch 50
# -------------------------------
# Training Error:
#  Accuracy: 92.0%, Avg loss: 0.280591
#
# Test Error:
#  Accuracy: 92.0%, Avg loss: 0.274836
#
# Epoch 51
# -------------------------------
# Training Error:
#  Accuracy: 92.1%, Avg loss: 0.277455
#
# Test Error:
#  Accuracy: 92.2%, Avg loss: 0.271943
#
# Epoch 52
# -------------------------------
# Training Error:
#  Accuracy: 92.2%, Avg loss: 0.274367
#
# Test Error:
#  Accuracy: 92.3%, Avg loss: 0.269098
#
# Epoch 53
# -------------------------------
# Training Error:
#  Accuracy: 92.3%, Avg loss: 0.271321
#
# Test Error:
#  Accuracy: 92.4%, Avg loss: 0.266294
#
# Epoch 54
# -------------------------------
# Training Error:
#  Accuracy: 92.4%, Avg loss: 0.268318
#
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.263528
#
# Epoch 55
# -------------------------------
# Training Error:
#  Accuracy: 92.5%, Avg loss: 0.265354
#
# Test Error:
#  Accuracy: 92.5%, Avg loss: 0.260793
#
# Epoch 56
# -------------------------------
# Training Error:
#  Accuracy: 92.5%, Avg loss: 0.262434
#
# Test Error:
#  Accuracy: 92.6%, Avg loss: 0.258099
#
# Epoch 57
# -------------------------------
# Training Error:
#  Accuracy: 92.6%, Avg loss: 0.259556
#
# Test Error:
#  Accuracy: 92.7%, Avg loss: 0.255439
#
# Epoch 58
# -------------------------------
# Training Error:
#  Accuracy: 92.7%, Avg loss: 0.256713
#
# Test Error:
#  Accuracy: 92.8%, Avg loss: 0.252801
#
# Epoch 59
# -------------------------------
# Training Error:
#  Accuracy: 92.8%, Avg loss: 0.253912
#
# Test Error:
#  Accuracy: 92.8%, Avg loss: 0.250205
#
# Epoch 60
# -------------------------------
# Training Error:
#  Accuracy: 92.8%, Avg loss: 0.251150
#
# Test Error:
#  Accuracy: 92.8%, Avg loss: 0.247643
#
# Epoch 61
# -------------------------------
# Training Error:
#  Accuracy: 92.9%, Avg loss: 0.248425
#
# Test Error:
#  Accuracy: 92.9%, Avg loss: 0.245124
#
# Epoch 62
# -------------------------------
# Training Error:
#  Accuracy: 93.0%, Avg loss: 0.245738
#
# Test Error:
#  Accuracy: 93.1%, Avg loss: 0.242638
#
# Epoch 63
# -------------------------------
# Training Error:
#  Accuracy: 93.0%, Avg loss: 0.243083
#
# Test Error:
#  Accuracy: 93.1%, Avg loss: 0.240183
#
# Epoch 64
# -------------------------------
# Training Error:
#  Accuracy: 93.1%, Avg loss: 0.240463
#
# Test Error:
#  Accuracy: 93.2%, Avg loss: 0.237760
#
# Epoch 65
# -------------------------------
# Training Error:
#  Accuracy: 93.2%, Avg loss: 0.237884
#
# Test Error:
#  Accuracy: 93.3%, Avg loss: 0.235372
#
# Epoch 66
# -------------------------------
# Training Error:
#  Accuracy: 93.3%, Avg loss: 0.235345
#
# Test Error:
#  Accuracy: 93.4%, Avg loss: 0.233019
#
# Epoch 67
# -------------------------------
# Training Error:
#  Accuracy: 93.3%, Avg loss: 0.232845
#
# Test Error:
#  Accuracy: 93.4%, Avg loss: 0.230697
#
# Epoch 68
# -------------------------------
# Training Error:
#  Accuracy: 93.4%, Avg loss: 0.230381
#
# Test Error:
#  Accuracy: 93.5%, Avg loss: 0.228407
#
# Epoch 69
# -------------------------------
# Training Error:
#  Accuracy: 93.5%, Avg loss: 0.227956
#
# Test Error:
#  Accuracy: 93.5%, Avg loss: 0.226152
#
# Epoch 70
# -------------------------------
# Training Error:
#  Accuracy: 93.6%, Avg loss: 0.225569
#
# Test Error:
#  Accuracy: 93.7%, Avg loss: 0.223931
#
# Epoch 71
# -------------------------------
# Training Error:
#  Accuracy: 93.7%, Avg loss: 0.223218
#
# Test Error:
#  Accuracy: 93.8%, Avg loss: 0.221742
#
# Epoch 72
# -------------------------------
# Training Error:
#  Accuracy: 93.7%, Avg loss: 0.220906
#
# Test Error:
#  Accuracy: 93.8%, Avg loss: 0.219585
#
# Epoch 73
# -------------------------------
# Training Error:
#  Accuracy: 93.8%, Avg loss: 0.218624
#
# Test Error:
#  Accuracy: 93.9%, Avg loss: 0.217454
#
# Epoch 74
# -------------------------------
# Training Error:
#  Accuracy: 93.8%, Avg loss: 0.216381
#
# Test Error:
#  Accuracy: 93.9%, Avg loss: 0.215365
#
# Epoch 75
# -------------------------------
# Training Error:
#  Accuracy: 93.9%, Avg loss: 0.214173
#
# Test Error:
#  Accuracy: 94.0%, Avg loss: 0.213306
#
# Epoch 76
# -------------------------------
# Training Error:
#  Accuracy: 94.0%, Avg loss: 0.212002
#
# Test Error:
#  Accuracy: 94.1%, Avg loss: 0.211282
#
# Epoch 77
# -------------------------------
# Training Error:
#  Accuracy: 94.0%, Avg loss: 0.209865
#
# Test Error:
#  Accuracy: 94.1%, Avg loss: 0.209287
#
# Epoch 78
# -------------------------------
# Training Error:
#  Accuracy: 94.1%, Avg loss: 0.207765
#
# Test Error:
#  Accuracy: 94.2%, Avg loss: 0.207317
#
# Epoch 79
# -------------------------------
# Training Error:
#  Accuracy: 94.2%, Avg loss: 0.205698
#
# Test Error:
#  Accuracy: 94.2%, Avg loss: 0.205377
#
# Epoch 80
# -------------------------------
# Training Error:
#  Accuracy: 94.2%, Avg loss: 0.203666
#
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.203467
#
# Epoch 81
# -------------------------------
# Training Error:
#  Accuracy: 94.3%, Avg loss: 0.201670
#
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.201591
#
# Epoch 82
# -------------------------------
# Training Error:
#  Accuracy: 94.4%, Avg loss: 0.199706
#
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.199755
#
# Epoch 83
# -------------------------------
# Training Error:
#  Accuracy: 94.4%, Avg loss: 0.197770
#
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.197939
#
# Epoch 84
# -------------------------------
# Training Error:
#  Accuracy: 94.5%, Avg loss: 0.195865
#
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.196153
#
# Epoch 85
# -------------------------------
# Training Error:
#  Accuracy: 94.5%, Avg loss: 0.193992
#
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.194395
#
# Epoch 86
# -------------------------------
# Training Error:
#  Accuracy: 94.6%, Avg loss: 0.192150
#
# Test Error:
#  Accuracy: 94.4%, Avg loss: 0.192673
#
# Epoch 87
# -------------------------------
# Training Error:
#  Accuracy: 94.6%, Avg loss: 0.190339
#
# Test Error:
#  Accuracy: 94.4%, Avg loss: 0.190985
#
# Epoch 88
# -------------------------------
# Training Error:
#  Accuracy: 94.7%, Avg loss: 0.188555
#
# Test Error:
#  Accuracy: 94.5%, Avg loss: 0.189325
#
# Epoch 89
# -------------------------------
# Training Error:
#  Accuracy: 94.7%, Avg loss: 0.186800
#
# Test Error:
#  Accuracy: 94.5%, Avg loss: 0.187696
#
# Epoch 90
# -------------------------------
# Training Error:
#  Accuracy: 94.8%, Avg loss: 0.185074
#
# Test Error:
#  Accuracy: 94.6%, Avg loss: 0.186091
#
# Epoch 91
# -------------------------------
# Training Error:
#  Accuracy: 94.8%, Avg loss: 0.183372
#
# Test Error:
#  Accuracy: 94.6%, Avg loss: 0.184516
#
# Epoch 92
# -------------------------------
# Training Error:
#  Accuracy: 94.9%, Avg loss: 0.181700
#
# Test Error:
#  Accuracy: 94.7%, Avg loss: 0.182970
#
# Epoch 93
# -------------------------------
# Training Error:
#  Accuracy: 94.9%, Avg loss: 0.180054
#
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.181454
#
# Epoch 94
# -------------------------------
# Training Error:
#  Accuracy: 95.0%, Avg loss: 0.178433
#
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.179962
#
# Epoch 95
# -------------------------------
# Training Error:
#  Accuracy: 95.0%, Avg loss: 0.176839
#
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.178498
#
# Epoch 96
# -------------------------------
# Training Error:
#  Accuracy: 95.1%, Avg loss: 0.175264
#
# Test Error:
#  Accuracy: 94.9%, Avg loss: 0.177052
#
# Epoch 97
# -------------------------------
# Training Error:
#  Accuracy: 95.1%, Avg loss: 0.173711
#
# Test Error:
#  Accuracy: 94.9%, Avg loss: 0.175630
#
# Epoch 98
# -------------------------------
# Training Error:
#  Accuracy: 95.2%, Avg loss: 0.172180
#
# Test Error:
#  Accuracy: 95.0%, Avg loss: 0.174235
#
# Epoch 99
# -------------------------------
# Training Error:
#  Accuracy: 95.2%, Avg loss: 0.170671
#
# Test Error:
#  Accuracy: 95.0%, Avg loss: 0.172867
#
# Epoch 100
# -------------------------------
# Training Error:
#  Accuracy: 95.2%, Avg loss: 0.169184
#
# Test Error:
#  Accuracy: 95.1%, Avg loss: 0.171518
#
# Epoch 101
# -------------------------------
# Training Error:
#  Accuracy: 95.3%, Avg loss: 0.167717
#
# Test Error:
#  Accuracy: 95.1%, Avg loss: 0.170191
#
# Epoch 102
# -------------------------------
# Training Error:
#  Accuracy: 95.3%, Avg loss: 0.166268
#
# Test Error:
#  Accuracy: 95.2%, Avg loss: 0.168886
#
# Epoch 103
# -------------------------------
# Training Error:
#  Accuracy: 95.3%, Avg loss: 0.164843
#
# Test Error:
#  Accuracy: 95.2%, Avg loss: 0.167605
#
# Epoch 104
# -------------------------------
# Training Error:
#  Accuracy: 95.4%, Avg loss: 0.163434
#
# Test Error:
#  Accuracy: 95.2%, Avg loss: 0.166338
#
# Epoch 105
# -------------------------------
# Training Error:
#  Accuracy: 95.4%, Avg loss: 0.162048
#
# Test Error:
#  Accuracy: 95.2%, Avg loss: 0.165097
#
# Epoch 106
# -------------------------------
# Training Error:
#  Accuracy: 95.5%, Avg loss: 0.160683
#
# Test Error:
#  Accuracy: 95.2%, Avg loss: 0.163874
#
# Epoch 107
# -------------------------------
# Training Error:
#  Accuracy: 95.5%, Avg loss: 0.159335
#
# Test Error:
#  Accuracy: 95.2%, Avg loss: 0.162674
#
# Epoch 108
# -------------------------------
# Training Error:
#  Accuracy: 95.5%, Avg loss: 0.158006
#
# Test Error:
#  Accuracy: 95.2%, Avg loss: 0.161501
#
# Epoch 109
# -------------------------------
# Training Error:
#  Accuracy: 95.6%, Avg loss: 0.156697
#
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.160341
#
# Epoch 110
# -------------------------------
# Training Error:
#  Accuracy: 95.6%, Avg loss: 0.155401
#
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.159201
#
# Epoch 111
# -------------------------------
# Training Error:
#  Accuracy: 95.7%, Avg loss: 0.154123
#
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.158079
#
# Epoch 112
# -------------------------------
# Training Error:
#  Accuracy: 95.7%, Avg loss: 0.152863
#
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.156983
#
# Epoch 113
# -------------------------------
# Training Error:
#  Accuracy: 95.7%, Avg loss: 0.151619
#
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.155903
#
# Epoch 114
# -------------------------------
# Training Error:
#  Accuracy: 95.8%, Avg loss: 0.150397
#
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.154841
#
# Epoch 115
# -------------------------------
# Training Error:
#  Accuracy: 95.8%, Avg loss: 0.149188
#
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.153794
#
# Epoch 116
# -------------------------------
# Training Error:
#  Accuracy: 95.8%, Avg loss: 0.147994
#
# Test Error:
#  Accuracy: 95.4%, Avg loss: 0.152763
#
# Epoch 117
# -------------------------------
# Training Error:
#  Accuracy: 95.8%, Avg loss: 0.146816
#
# Test Error:
#  Accuracy: 95.4%, Avg loss: 0.151751
#
# Epoch 118
# -------------------------------
# Training Error:
#  Accuracy: 95.9%, Avg loss: 0.145652
#
# Test Error:
#  Accuracy: 95.5%, Avg loss: 0.150758
#
# Epoch 119
# -------------------------------
# Training Error:
#  Accuracy: 95.9%, Avg loss: 0.144503
#
# Test Error:
#  Accuracy: 95.5%, Avg loss: 0.149780
#
# Epoch 120
# -------------------------------
# Training Error:
#  Accuracy: 95.9%, Avg loss: 0.143368
#
# Test Error:
#  Accuracy: 95.5%, Avg loss: 0.148821
#
# Epoch 121
# -------------------------------
# Training Error:
#  Accuracy: 96.0%, Avg loss: 0.142249
#
# Test Error:
#  Accuracy: 95.6%, Avg loss: 0.147875
#
# Epoch 122
# -------------------------------
# Training Error:
#  Accuracy: 96.0%, Avg loss: 0.141142
#
# Test Error:
#  Accuracy: 95.6%, Avg loss: 0.146940
#
# Epoch 123
# -------------------------------
# Training Error:
#  Accuracy: 96.0%, Avg loss: 0.140047
#
# Test Error:
#  Accuracy: 95.6%, Avg loss: 0.146022
#
# Epoch 124
# -------------------------------
# Training Error:
#  Accuracy: 96.1%, Avg loss: 0.138970
#
# Test Error:
#  Accuracy: 95.6%, Avg loss: 0.145121
#
# Epoch 125
# -------------------------------
# Training Error:
#  Accuracy: 96.1%, Avg loss: 0.137903
#
# Test Error:
#  Accuracy: 95.6%, Avg loss: 0.144233
#
# Epoch 126
# -------------------------------
# Training Error:
#  Accuracy: 96.1%, Avg loss: 0.136848
#
# Test Error:
#  Accuracy: 95.7%, Avg loss: 0.143356
#
# Epoch 127
# -------------------------------
# Training Error:
#  Accuracy: 96.1%, Avg loss: 0.135805
#
# Test Error:
#  Accuracy: 95.7%, Avg loss: 0.142494
#
# Epoch 128
# -------------------------------
# Training Error:
#  Accuracy: 96.2%, Avg loss: 0.134775
#
# Test Error:
#  Accuracy: 95.8%, Avg loss: 0.141642
#
# Epoch 129
# -------------------------------
# Training Error:
#  Accuracy: 96.2%, Avg loss: 0.133757
#
# Test Error:
#  Accuracy: 95.9%, Avg loss: 0.140802
#
# Epoch 130
# -------------------------------
# Training Error:
#  Accuracy: 96.2%, Avg loss: 0.132752
#
# Test Error:
#  Accuracy: 95.9%, Avg loss: 0.139984
#
# Epoch 131
# -------------------------------
# Training Error:
#  Accuracy: 96.2%, Avg loss: 0.131756
#
# Test Error:
#  Accuracy: 95.9%, Avg loss: 0.139175
#
# Epoch 132
# -------------------------------
# Training Error:
#  Accuracy: 96.3%, Avg loss: 0.130772
#
# Test Error:
#  Accuracy: 95.9%, Avg loss: 0.138374
#
# Epoch 133
# -------------------------------
# Training Error:
#  Accuracy: 96.3%, Avg loss: 0.129801
#
# Test Error:
#  Accuracy: 95.9%, Avg loss: 0.137589
#
# Epoch 134
# -------------------------------
# Training Error:
#  Accuracy: 96.3%, Avg loss: 0.128840
#
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.136814
#
# Epoch 135
# -------------------------------
# Training Error:
#  Accuracy: 96.4%, Avg loss: 0.127887
#
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.136049
#
# Epoch 136
# -------------------------------
# Training Error:
#  Accuracy: 96.4%, Avg loss: 0.126947
#
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.135298
#
# Epoch 137
# -------------------------------
# Training Error:
#  Accuracy: 96.4%, Avg loss: 0.126018
#
# Test Error:
#  Accuracy: 96.1%, Avg loss: 0.134554
#
# Epoch 138
# -------------------------------
# Training Error:
#  Accuracy: 96.4%, Avg loss: 0.125096
#
# Test Error:
#  Accuracy: 96.1%, Avg loss: 0.133821
#
# Epoch 139
# -------------------------------
# Training Error:
#  Accuracy: 96.4%, Avg loss: 0.124184
#
# Test Error:
#  Accuracy: 96.1%, Avg loss: 0.133097
#
# Epoch 140
# -------------------------------
# Training Error:
#  Accuracy: 96.5%, Avg loss: 0.123283
#
# Test Error:
#  Accuracy: 96.1%, Avg loss: 0.132384
#
# Epoch 141
# -------------------------------
# Training Error:
#  Accuracy: 96.5%, Avg loss: 0.122390
#
# Test Error:
#  Accuracy: 96.1%, Avg loss: 0.131679
#
# Epoch 142
# -------------------------------
# Training Error:
#  Accuracy: 96.5%, Avg loss: 0.121506
#
# Test Error:
#  Accuracy: 96.1%, Avg loss: 0.130983
#
# Epoch 143
# -------------------------------
# Training Error:
#  Accuracy: 96.6%, Avg loss: 0.120632
#
# Test Error:
#  Accuracy: 96.1%, Avg loss: 0.130292
#
# Epoch 144
# -------------------------------
# Training Error:
#  Accuracy: 96.6%, Avg loss: 0.119769
#
# Test Error:
#  Accuracy: 96.1%, Avg loss: 0.129616
#
# Epoch 145
# -------------------------------
# Training Error:
#  Accuracy: 96.6%, Avg loss: 0.118913
#
# Test Error:
#  Accuracy: 96.1%, Avg loss: 0.128945
#
# Epoch 146
# -------------------------------
# Training Error:
#  Accuracy: 96.6%, Avg loss: 0.118071
#
# Test Error:
#  Accuracy: 96.1%, Avg loss: 0.128288
#
# Epoch 147
# -------------------------------
# Training Error:
#  Accuracy: 96.7%, Avg loss: 0.117231
#
# Test Error:
#  Accuracy: 96.2%, Avg loss: 0.127637
#
# Epoch 148
# -------------------------------
# Training Error:
#  Accuracy: 96.7%, Avg loss: 0.116403
#
# Test Error:
#  Accuracy: 96.2%, Avg loss: 0.126993
#
# Epoch 149
# -------------------------------
# Training Error:
#  Accuracy: 96.7%, Avg loss: 0.115579
#
# Test Error:
#  Accuracy: 96.2%, Avg loss: 0.126357
#
# Epoch 150
# -------------------------------
# Training Error:
#  Accuracy: 96.7%, Avg loss: 0.114766
#
# Test Error:
#  Accuracy: 96.3%, Avg loss: 0.125734
#
# Epoch 151
# -------------------------------
# Training Error:
#  Accuracy: 96.8%, Avg loss: 0.113958
#
# Test Error:
#  Accuracy: 96.3%, Avg loss: 0.125113
#
# Epoch 152
# -------------------------------
# Training Error:
#  Accuracy: 96.8%, Avg loss: 0.113158
#
# Test Error:
#  Accuracy: 96.3%, Avg loss: 0.124498
#
# Epoch 153
# -------------------------------
# Training Error:
#  Accuracy: 96.8%, Avg loss: 0.112366
#
# Test Error:
#  Accuracy: 96.3%, Avg loss: 0.123887
#
# Epoch 154
# -------------------------------
# Training Error:
#  Accuracy: 96.8%, Avg loss: 0.111581
#
# Test Error:
#  Accuracy: 96.3%, Avg loss: 0.123290
#
# Epoch 155
# -------------------------------
# Training Error:
#  Accuracy: 96.9%, Avg loss: 0.110802
#
# Test Error:
#  Accuracy: 96.3%, Avg loss: 0.122696
#
# Epoch 156
# -------------------------------
# Training Error:
#  Accuracy: 96.9%, Avg loss: 0.110031
#
# Test Error:
#  Accuracy: 96.3%, Avg loss: 0.122108
#
# Epoch 157
# -------------------------------
# Training Error:
#  Accuracy: 96.9%, Avg loss: 0.109269
#
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.121530
#
# Epoch 158
# -------------------------------
# Training Error:
#  Accuracy: 96.9%, Avg loss: 0.108516
#
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.120960
#
# Epoch 159
# -------------------------------
# Training Error:
#  Accuracy: 96.9%, Avg loss: 0.107770
#
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.120398
#
# Epoch 160
# -------------------------------
# Training Error:
#  Accuracy: 97.0%, Avg loss: 0.107030
#
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.119840
#
# Epoch 161
# -------------------------------
# Training Error:
#  Accuracy: 97.0%, Avg loss: 0.106301
#
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.119294
#
# Epoch 162
# -------------------------------
# Training Error:
#  Accuracy: 97.0%, Avg loss: 0.105578
#
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.118751
#
# Epoch 163
# -------------------------------
# Training Error:
#  Accuracy: 97.0%, Avg loss: 0.104859
#
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.118208
#
# Epoch 164
# -------------------------------
# Training Error:
#  Accuracy: 97.0%, Avg loss: 0.104147
#
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.117676
#
# Epoch 165
# -------------------------------
# Training Error:
#  Accuracy: 97.1%, Avg loss: 0.103444
#
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.117150
#
# Epoch 166
# -------------------------------
# Training Error:
#  Accuracy: 97.1%, Avg loss: 0.102745
#
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.116630
#
# Epoch 167
# -------------------------------
# Training Error:
#  Accuracy: 97.1%, Avg loss: 0.102053
#
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.116118
#
# Epoch 168
# -------------------------------
# Training Error:
#  Accuracy: 97.1%, Avg loss: 0.101366
#
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.115611
#
# Epoch 169
# -------------------------------
# Training Error:
#  Accuracy: 97.2%, Avg loss: 0.100686
#
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.115111
#
# Epoch 170
# -------------------------------
# Training Error:
#  Accuracy: 97.2%, Avg loss: 0.100012
#
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.114612
#
# Epoch 171
# -------------------------------
# Training Error:
#  Accuracy: 97.2%, Avg loss: 0.099343
#
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.114122
#
# Epoch 172
# -------------------------------
# Training Error:
#  Accuracy: 97.2%, Avg loss: 0.098680
#
# Test Error:
#  Accuracy: 96.5%, Avg loss: 0.113640
#
# Epoch 173
# -------------------------------
# Training Error:
#  Accuracy: 97.2%, Avg loss: 0.098024
#
# Test Error:
#  Accuracy: 96.6%, Avg loss: 0.113162
#
# Epoch 174
# -------------------------------
# Training Error:
#  Accuracy: 97.2%, Avg loss: 0.097372
#
# Test Error:
#  Accuracy: 96.6%, Avg loss: 0.112688
#
# Epoch 175
# -------------------------------
# Training Error:
#  Accuracy: 97.3%, Avg loss: 0.096726
#
# Test Error:
#  Accuracy: 96.6%, Avg loss: 0.112224
#
# Epoch 176
# -------------------------------
# Training Error:
#  Accuracy: 97.3%, Avg loss: 0.096087
#
# Test Error:
#  Accuracy: 96.6%, Avg loss: 0.111761
#
# Epoch 177
# -------------------------------
# Training Error:
#  Accuracy: 97.3%, Avg loss: 0.095452
#
# Test Error:
#  Accuracy: 96.6%, Avg loss: 0.111303
#
# Epoch 178
# -------------------------------
# Training Error:
#  Accuracy: 97.3%, Avg loss: 0.094822
#
# Test Error:
#  Accuracy: 96.6%, Avg loss: 0.110848
#
# Epoch 179
# -------------------------------
# Training Error:
#  Accuracy: 97.3%, Avg loss: 0.094198
#
# Test Error:
#  Accuracy: 96.6%, Avg loss: 0.110399
#
# Epoch 180
# -------------------------------
# Training Error:
#  Accuracy: 97.4%, Avg loss: 0.093581
#
# Test Error:
#  Accuracy: 96.6%, Avg loss: 0.109951
#
# Epoch 181
# -------------------------------
# Training Error:
#  Accuracy: 97.4%, Avg loss: 0.092970
#
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.109510
#
# Epoch 182
# -------------------------------
# Training Error:
#  Accuracy: 97.4%, Avg loss: 0.092363
#
# Test Error:
#  Accuracy: 96.7%, Avg loss: 0.109075
#
# Epoch 183
# -------------------------------
# Training Error:
#  Accuracy: 97.4%, Avg loss: 0.091760
#
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.108640
#
# Epoch 184
# -------------------------------
# Training Error:
#  Accuracy: 97.5%, Avg loss: 0.091161
#
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.108211
#
# Epoch 185
# -------------------------------
# Training Error:
#  Accuracy: 97.5%, Avg loss: 0.090569
#
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.107790
#
# Epoch 186
# -------------------------------
# Training Error:
#  Accuracy: 97.5%, Avg loss: 0.089980
#
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.107376
#
# Epoch 187
# -------------------------------
# Training Error:
#  Accuracy: 97.5%, Avg loss: 0.089396
#
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.106965
#
# Epoch 188
# -------------------------------
# Training Error:
#  Accuracy: 97.5%, Avg loss: 0.088818
#
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.106559
#
# Epoch 189
# -------------------------------
# Training Error:
#  Accuracy: 97.5%, Avg loss: 0.088244
#
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.106156
#
# Epoch 190
# -------------------------------
# Training Error:
#  Accuracy: 97.6%, Avg loss: 0.087677
#
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.105762
#
# Epoch 191
# -------------------------------
# Training Error:
#  Accuracy: 97.6%, Avg loss: 0.087113
#
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.105370
#
# Epoch 192
# -------------------------------
# Training Error:
#  Accuracy: 97.6%, Avg loss: 0.086551
#
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.104978
#
# Epoch 193
# -------------------------------
# Training Error:
#  Accuracy: 97.6%, Avg loss: 0.085995
#
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.104597
#
# Epoch 194
# -------------------------------
# Training Error:
#  Accuracy: 97.7%, Avg loss: 0.085443
#
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.104220
#
# Epoch 195
# -------------------------------
# Training Error:
#  Accuracy: 97.7%, Avg loss: 0.084896
#
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.103845
#
# Epoch 196
# -------------------------------
# Training Error:
#  Accuracy: 97.7%, Avg loss: 0.084354
#
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.103475
#
# Epoch 197
# -------------------------------
# Training Error:
#  Accuracy: 97.7%, Avg loss: 0.083813
#
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.103107
#
# Epoch 198
# -------------------------------
# Training Error:
#  Accuracy: 97.7%, Avg loss: 0.083278
#
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.102744
#
# Epoch 199
# -------------------------------
# Training Error:
#  Accuracy: 97.7%, Avg loss: 0.082750
#
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.102386
#
# Epoch 200
# -------------------------------
# Training Error:
#  Accuracy: 97.8%, Avg loss: 0.082222
#
# Test Error:
#  Accuracy: 96.9%, Avg loss: 0.102022

# %%
fig, ax = plt.subplots()
fig.set_size_inches(18.5, 10.5)
for m in models:
    epochs = m.epochs
    ax.plot(range(1, epochs+1), m.error_test, label = f"{m.name}: test loss")
    ax.plot(range(1, epochs+1), m.error_training, label = f"{m.name}: training loss")
ax.set_title("Avg error vs Number of Epochs")
ax.set_xlabel("Number of Epochs")
ax.set_ylabel("Average Error")
ax.legend()

# %% [markdown]
# <hr>
